# %% [markdown]
# Cài đặt BeautifulSoup

# %%
# %pip install beautifulsoup4
# %pip install requests
# Out:
# Collecting requestsNote: you may need to restart the kernel to use updated packages.
#
#   Obtaining dependency information for requests from https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl.metadata
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/57/ec/80c8d48ac8b1741d5b963797b7c0c869335619e13d4744ca2f67fc11c6fc/charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/c2/e7/a82b05cf63a603df6e68d59ae6a68bf5064484a0718ea5033660af4b54a9/idna-3.6-py3-none-any.whl.metadata
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/a2/73/a68704750a7679d0b6d3ad7aa8d4da8e14e151ae82e6fee774e6e0d05ec8/urllib3-2.2.1-py3-none-any.whl.metadata
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/ba/06/a07f096c664aeb9f01624f858c3add0a4e913d6c96257acb4fce61e7de14/certifi-2024.2.2-py3-none-any.whl.metadata
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#    ------ --------------------------------- 10.2/62.6 kB ? eta -:--:--
#    ---------------------------------------- 62.6/62.6 kB 830.7 kB/s eta 0:00:00
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ---------------------------------------- 0.0/163.8 kB ? eta -:--:--
#    --------- ----------------------------- 41.0/163.8 kB 991.0 kB/s eta 0:00:01
#    -------------- ------------------------ 61.4/163.8 kB 825.8 kB/s eta 0:00:01
#    --------------------- ----------------- 92.2/163.8 kB 585.1 kB/s eta 0:00:01
#    -------------------------- ----------- 112.6/163.8 kB 547.6 kB/s eta 0:00:01
#    --------------------------------- ---- 143.4/163.8 kB 568.9 kB/s eta 0:00:01
#    -------------------------------------- 163.8/163.8 kB 614.1 kB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl (99 kB)
#    ---------------------------------------- 0.0/99.9 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/99.9 kB ? eta -:--:--
#    ------------------------ --------------- 61.4/99.9 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 99.9/99.9 kB 1.1 MB/s eta 0:00:00
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.6 kB ? eta -:--:--
#    ---------------------------------------  61.4/61.6 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 61.6/61.6 kB 1.7 MB/s eta 0:00:00
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.1 kB ? eta -:--:--
#    --------- ----------------------------- 30.7/121.1 kB 660.6 kB/s eta 0:00:01
#    -------------------------- ------------ 81.9/121.1 kB 919.0 kB/s eta 0:00:01
#    ---------------------------------------- 121.1/121.1 kB 1.0 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.2.2 charset-normalizer-3.3.2 idna-3.6 requests-2.31.0 urllib3-2.2.1
#   WARNING: The script normalizer.exe is installed in 'c:\Users\Mai Xuan Truong\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Import thư viện

# %%
from bs4 import BeautifulSoup
import requests
import time
import csv

# %% [markdown]
# Đối tượng thể hiện mỗi bài tuyển dụng

# %%
class Job:
    def __init__(self, title, link, company, salary, locations, level, yearOfExperience, contractType, sex, skills):
        self.title = title
        self.link = link
        self.company = company
        self.salary = salary
        self.locations = locations
        self.level = level
        self.yearOfExperience = yearOfExperience
        self.contractType = contractType
        self.sex = sex
        self.skills = skills

# %% [markdown]
# Hàm lấy thông tin chi tiết của mỗi bài tuyển dụng

# %%
def get_jobs(item):
    print('********************* Start')
    try:
        title = item.find(class_='title').text.strip()
        print(title)
        link = item.find(class_='title').find('a')['href'].strip()
        print(link)
        company = item.find(class_='company').text.strip()
        print(company)
        salary = item.find(class_='title-salary').text.strip()
        print(salary)
        locations = item.find(class_='address').text.strip()
        print(locations)
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
        }

        # Số lần thử lại tối đa
        max_retries = 5
        retry_delay = 1  # Thời gian chờ giữa các lần thử lại, đơn vị là giây

        retry_count = 0
        while retry_count < max_retries:
            response2 = requests.get(link, headers=headers)
            if response2.status_code == 429:  # Nếu nhận được mã trạng thái 429
                print("Too many requests. Retrying after waiting...")
                retry_count += 1
                time.sleep(retry_delay)  # Chờ trước khi thử lại
            else:
                # Xử lý kết quả ở đây nếu cần
                # Ví dụ: print(response.text)
                break
        else:
            print("Max retries exceeded. Request unsuccessful.")
        print(response2.status_code)
        if response2.status_code == 200:
            print('********************* Success')
            soup2 = BeautifulSoup(response2.text, 'html.parser')
            try:
                top = item.find(class_='box-label-top').find_all('label')[0].text.strip()
            except:
                top = None
            if top == 'TOP':
                infos = soup2.find_all(class_='box-info')
                generals = infos[0].find_all('span')
                level = generals[3].text.strip()
                print(level)
                yearOfExperience = generals[5].text.strip()
                print(yearOfExperience)
                contractType = generals[2].text.strip()
                print(contractType)
                sex = generals[4].text.strip()
                print(sex)
                skills = infos[2].find(class_='content-tab').text.strip()
                print(skills)
            else:
                generals = soup2.find(class_='job-detail__box--right job-detail__body-right--item job-detail__body-right--box-general').find_all(class_='box-general-group-info-value')
                level = generals[0].text.strip()
                print(level)
                yearOfExperience = generals[1].text.strip()
                print(yearOfExperience)
                contractType = generals[3].text.strip()
                print(contractType)
                sex = generals[4].text.strip()
                print(sex)
                skills = soup2.find_all(class_='job-description__item--content')[1].text.strip()
                print(skills)
        else:
            level = None
            yearOfExperience = None
            contractType = None
            sex = None
            skills = None
        # Writing to CSV file
        with open('jobs.csv', mode='a', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            # Write header row if file is empty
            if file.tell() == 0:
                writer.writerow(['Title', 'Link', 'Company', 'Salary', 'Locations', 'Level', 'Year of Experience', 'Contract Type', 'Sex', 'Skills'])
            writer.writerow([title, link, company, salary, locations, level, yearOfExperience, contractType, sex, skills])
    except:
        print('********************* Fail')
    print('********************* End')

# %%
# URL của trang web bạn muốn crawl
url = 'https://www.topcv.vn/viec-lam-it?page=2'

# Gửi một yêu cầu GET đến URL và lấy nội dung HTML của trang
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
response = requests.get(url, headers=headers)

# %%
if response.status_code == 200:
    # Sử dụng BeautifulSoup để phân tích HTML
    soup = BeautifulSoup(response.text, 'html.parser')
    
    jobs = soup.find_all(class_='job-item-2')
    for job in jobs:
        get_jobs(job)              
else:
    print('Yêu cầu không thành công. Mã trạng thái:', response.status_code)
# Out:
# ********************* Start
# Product Owner - Sản Phẩm Mobile App, Lương Upto 35 Triệu - Edtech Số 1 Thị Trường
# https://www.topcv.vn/brand/educa/tuyen-dung/product-owner-san-pham-mobile-app-luong-upto-35-trieu-edtech-so-1-thi-truong-j1275455.html?ta_source=ITJobs_LinkDetail
# EDUPIA
# 22 - 35 triệu
# Hà Nội
# 200
# ********************* Success
# ********************* Fail
# ********************* End
# ********************* Start
# Lập Trình Viên Triển Khai Phần Mềm
# https://www.topcv.vn/viec-lam/lap-trinh-vien-trien-khai-phan-mem/704106.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH Thực Phẩm Thái Sơn
# Thoả thuận
# Hồ Chí Minh
# 200
# ********************* Success
# Nhân viên
# 3 năm
# Toàn thời gian
# Không yêu cầu
# - 3 năm triển khai hoặc duy trì giải pháp Local/Global ERP/Retail. - Khảo sát nghiệp vụ phân tích Gap List, thiết kế giải pháp và quy trình nghiệp vụ. Triển khai, đào tạo, duy trì. - Lập và quản lí kế hoạch (Timeline, HR, Budget) - Triển khai giải pháp thành sản phẩm, duy trì: Database (MySQL hoặc SQL), Win/Web form, report: .Net, XML Publiser - Kỹ năng lập trình tốt với ngôn ngữ PHP, Java, C++/C#- - Có kinh nghiệm làm việc với các hệ quản trị CSDL, My SQL, SQL
# ********************* End
# ********************* Start
# Lập Trình Viên C/C++ Tại Hà Nội - Lương Từ 20 - 35 Triệu
# https://www.topcv.vn/viec-lam/lap-trinh-vien-c-c-tai-ha-noi-luong-tu-20-35-trieu/1273032.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH CMC CYBER SECURITY
# 20 - 35 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# - Tốt nghiệp chuyên ngành CNTT, điện - điển tử viên thông...- Từ 1 đến 3 năm kinh nghiệm phát triển phầm mềm. Có khả năng triển khai và viết design documents cho nhiều loại modules của sản phẩm- Có kinh nghiệm với ngôn ngữ lập trình C/C++ - Có khả năng lập trình với Rust là lợi thế- Khả năng làm việc độc lập và làm việc nhóm tốt
# ********************* End
# ********************* Start
# Web Developer
# https://www.topcv.vn/viec-lam/web-developer/1282066.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN PHẦN MỀM VIỄN THÔNG MIỀN NAM
# 10 - 20 triệu
# Hồ Chí Minh
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# ● Have at least 1 year of experience.
# ● Good understanding of the TypeScript, HTML, CSS.
# ● Experience with React, React-Query, NextJS, Tailwind CSS, CSS Compiler (Scss/Less).
# ● Familiarity with RESTful APIs.
# ● Experience with common front-end development tools such as Vite, Babel, Webpack, NPM, etc.
# ● Good command of source code management such as Git.
# ● Ensure the technical feasibility of UI/UX designs.
# ● Develop web templates based on graphical web layout designs that follow the strict requirements.
# ● Knowing about SEO, NodeJS, MongoDB, React Native is an advantage.
# ● Có ít nhất 1 năm kinh nghiệm.● Hiểu biết tốt về TypeScript, HTML, CSS.● Có kinh nghiệm với React, React-Query, NextJS, Tailwind CSS, CSS Compiler (Scss/Less).● Làm quen với API RESTful.● Có kinh nghiệm với các công cụ phát triển front-end phổ biến như Vite, Babel, Webpack, NPM, v.v.● Khả năng quản lý mã nguồn tốt như Git.● Đảm bảo tính khả thi về mặt kỹ thuật của thiết kế UI/UX.● Phát triển các mẫu web dựa trên thiết kế bố cục web đồ họa tuân theo các yêu cầu nghiêm ngặt.● Biết về SEO, NodeJS, MongoDB, React Native là một lợi thế.
# ********************* End
# ********************* Start
# Kỹ Sư Giải Pháp Telco Cloud (VTNet) - Lương Thưởng Hấp Dẫn
# https://www.topcv.vn/brand/congnghiepvienthongquandoi/tuyen-dung/ky-su-giai-phap-telco-cloud-vtnet-luong-thuong-hap-dan-j1274246.html?ta_source=ITJobs_LinkDetail
# TẬP ĐOÀN CÔNG NGHIỆP - VIỄN THÔNG QUÂN ĐỘI
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# - Tốt nghiệp đại học chuyên ngành Điện tử viễn thông/Công nghệ thông tin hoặc các chuyên ngành có liên quan: loại Khá trở lên (chấp nhận hồ sơ của sinh viên mới tốt nghiệp)- Tiếng Anh: TOEIC 550 trở lên hoặc tương đương.- Có các chứng chỉ CCNA, LPIC, COA, CKA ... là một lợi thế- Sáng tạo, năng động, trách nhiệm, có khả năng làm việc độc lập và làm việc theo nhóm.- Trung thực, trách nhiệm, cẩn thận, tỉ mỉ, chịu được áp lực công việc cao.- Ưu tiên các ứng viên:+ Có kinh nghiệm, chuyên môn về Cloud, Hệ điều hành, Networking+ Có kinh nghiệm, chuyên môn về mạng lõi di động 2G/3G/4G/5G
# ********************* End
# ********************* Start
# Business Development Manager - Banking & Insurance
# https://www.topcv.vn/viec-lam/business-development-manager-banking-insurance/1283023.html?ta_source=ITJobs_LinkDetail
# SVTECH
# Thoả thuận
# Hồ Chí Minh
# 200
# ********************* Success
# Trưởng/Phó phòng
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# Bachelor’s degree in Business, Finance, IT, or related field.Proven experience in solution sales, preferably in the Banking or Insurance sector.Strong understanding of Data and Analytics solutions and their application in business contexts.Familiarity with banking and insurance business models, processes, data structures, and IT infrastructure.Excellent communication, presentation, and interpersonal skills.Ability to think strategically and understand the broader business implications of technology solutions.Fluent in Vietnamese and proficient in English.
# ********************* End
# ********************* Start
# Trưởng Phòng Kỹ Thuật Giải Pháp Lương + Thưởng Thu Nhập Hấp Dẫn
# https://www.topcv.vn/viec-lam/truong-phong-ky-thuat-giai-phap-luong-thuong-thu-nhap-hap-dan/1266181.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH CÔNG NGHỆ VÀ GIẢI PHÁP THÔNG MINH
# 15 - 30 triệu
# Hà Nội
# 200
# ********************* Success
# Trưởng/Phó phòng
# 2 năm
# Toàn thời gian
# Không yêu cầu
# - Nam Tốt nghiệp Đại học chuyên ngành CNTT.
# - Có từ 2 năm kinh nghiệm trở lên với công việc tương đương.
# - Tuổi từ 24 đến 36, có thể đi công tác nếu có yêu cầu.
# - Sử dụng thành thạo AutoCAD, Internet, tin học văn phòng ...- Có khả năng thuyết trình, huấn luyện công việc tốt.
# ********************* End
# ********************* Start
# Chuyên Viên Digital Marketing & Social - Đi Làm Ngay - Thu Nhập Từ 10 Triệu Trở Lên + Phụ Cấp
# https://www.topcv.vn/viec-lam/chuyen-vien-digital-marketing-social-di-lam-ngay-thu-nhap-tu-10-trieu-tro-len-phu-cap/1215717.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH Công nghệ Sao Vega
# Trên 10 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Có kinh nghiệm làm việc tại vị trí Digital Marketing, Growth Hack, Performance Marketing,...từ 1 năm trở lênCó kinh nghiệm, kiến thức về các phương pháp Inbound Marketing, hiểu biết về các nền tảng DSPsKhả năng nghiên cứu, phân tích dữ liệu tốtKỹ năng nghiên cứu, chủ động tìm tòi, tự họcTư duy chiến lược, hệ thống và logicAm hiểu các kênh social media như Facebook, Instagram, Twitter là một lợi thế. Có kỹ năng tìm kiếm, biên tập xử lý thông tin, thích đọc và theo dõi các fanpage, tạp chí quốc tế.Có kinh nghiệm từ 1 năm trở lên ở vị trí tương đương Sử dụng AI vào công việc là một lợi thếTôn trọng deadline
# ********************* End
# ********************* Start
# Nhân Viên Xử Lý Dữ Liệu Hình Ảnh (Dán Nhãn Dữ Liệu AI) - Không Yêu Cầu Kinh Nghiệm
# https://www.topcv.vn/viec-lam/nhan-vien-xu-ly-du-lieu-hinh-anh-dan-nhan-du-lieu-ai-khong-yeu-cau-kinh-nghiem/1127217.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH AI DATASET
# Trên 6.8 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# Không yêu cầu kinh nghiệmCó kinh nghiệm dán nhãn dữ liệu hình ảnh 2D, 3D là một lợi thếBắt buộc có laptop cá nhân và chuột máy tính.Chăm chỉ, cẩn thận, tỉ mỉ, nghiêm túc, có định hướng gắn bó lâu dài.
# ********************* End
# ********************* Start
# Unity Developer(1 Năm Kinh Nghiệm) - Lương Cứng Từ 14 - 25 Triệu/ Tháng + Chia Sẻ Lợi Nhuận Dự Án
# https://www.topcv.vn/viec-lam/unity-developer1-nam-kinh-nghiem-luong-cung-tu-14-25-trieu-thang-chia-se-loi-nhuan-du-an/1250299.html?ta_source=ITJobs_LinkDetail
# Công ty cổ phần 1pixel
# 14 - 25 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# • Có kinh nghiệm 1 năm lập trình Unity và mong muốn sử dụng Unity là công cụ chính để phát triển game• Yêu thích làm game
# • Có kiến thức với các khía cạnh trong phát triển game bao gồm OOP, UI, Animation...• Có khả năng đọc hiểu tài liệu Tiếng Anh và khả năng tự nghiên cứu, học hỏi công nghệ mới• Đã từng tham gia phát triển ít nhất 1 dự án game
# • Có sản phẩm được publish trên các kho ứng dụng là một lợi thế
# ********************* End
# ********************* Start
# Nhân Viên Thi Công Điện Mạng Camera (Thu Nhập Hấp Dẫn 10-15 Triệu)
# https://www.topcv.vn/viec-lam/nhan-vien-thi-cong-dien-mang-camera-thu-nhap-hap-dan-10-15-trieu/1161979.html?ta_source=ITJobs_LinkDetail
# Công ty Cổ phần I.P.L
# 8 - 10 triệu
# Hồ Chí Minh
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Nam
# - Ưu tiên ứng viên có kinh nghiệm trong lĩnh vực thi công điện, mạng, camera, thợ điện, ...- Nhanh nhẹn, hòa đồng, không ngại di chuyển, tăng ca,...- Ưu tiên các bạn chịu khó vì thường làm tăng ca nhiều (kịp tiến độ hoàn thành công trình)- Trình độ chuyên môn: Tốt nghiệp các ngành kỹ thuật, CNTT, Điện - Điện tử,...- Độ tuổi: Nam từ 20 - 35 tuổi
# ********************* End
# ********************* Start
# Kỹ Sư IT Vận Hành Bảo Trì SE/TE/MES
# https://www.topcv.vn/viec-lam/ky-su-it-van-hanh-bao-tri-se-te-mes/1278337.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH công nghệ Amtran Việt Nam
# Thoả thuận
# Hải Phòng
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# 理工學歷,中文或英文能溝通。Tốt nghiệp đại học chuyên ngành khoa học kỹ thuật, có thể giao tiếp bằng tiếng Trung hoặc tiếng Anh.熟悉程式語言C#、VB6.0和Python。Làm quen với các ngôn ngữ lập trình C#, VB6.0 và Python.
# ********************* End
# ********************* Start
# Kỹ Sư Công Nghệ Thông Tin - Thu Nhập 25 Triệu
# https://www.topcv.vn/viec-lam/ky-su-cong-nghe-thong-tin-thu-nhap-25-trieu/1206090.html?ta_source=ITJobs_LinkDetail
# Trung Tâm Nghiên Cứu Và Phát Triển Mobifone - Tổng Công Ty Viễn Thông Mobifone
# 20 - 25 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# Yêu cầu trình độ: Ứng viên đã tốt nghiệp Đại học (có bằng tốt nghiệp hoặc giấy chứng nhận tốt nghiệp tạm thời) chuyên ngành Công nghệ thông tin (ngành đúng hoặc ngành gần) thuộc các trường đại học công lập trong nước, hoặc tại các trường Đại học nước ngoài thuộc nhóm 1000 trường Đại học hàng đầu thế giới do các tổ chức/website có uy tín của Thế giới xếp hạng (bảng xếp hạng xác định tại năm tốt nghiệp của thí sinh dự tuyển).Yêu cầu kinh nghiệm:Lập trình ít nhất với Java hoặc C++ và một ngôn ngữ hướng đối tượng khácThành thạo ít nhất một trong những ngôn ngữ lập trình Java, .Net, PHP.Có kiến thức về phương pháp phân tích, thiết kế và lập trình hướng đối tượngLàm việc tối thiểu 1 năm ở vị trí tương đương Hoặc chấp nhận sinh viên mới ra trường (có kiến thức về Fullstack)Có kinh nghiệm về J2EE (JavaCore), Front End (JavaScript, HTML5, CSS, Jquery), SQL, mô hình MVC,MVVM, ...Yêu cầu chung khác:Ưu tiên Ngoại ngữ 450 Toeic hoặc tương đương trở lên.Có kĩ năng tư duy logic, phân tích và giải quyết vấn đề.Có tinh thần trách nhiệm, chịu áp lực công việc, có khả năng làm việc độc lập và làm việc nhómCó đam mê và liên tục cập nhật các xu thế công nghệ, giải pháp, dịch vụ mớiCó kĩ năng viết báo cáo tổng hợp và kĩ năng trình bày trước đám đông.
# ********************* End
# ********************* Start
# Kỹ Sư Giải Pháp Nghiệp Vụ (Ba)
# https://www.topcv.vn/viec-lam/ky-su-giai-phap-nghiep-vu-ba/261138.html?ta_source=ITJobs_LinkDetail
# Khối Công nghệ thông tin - Viettel Telecom
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# • Tốt nghiệp Đại học bằng khá trở lên chuyên ngành CNTT, ĐTVT, Toán tin Ứng dụng• Ít nhất 1 năm kinh nghiệm làm nghiệp vụ, tester
# • Có kiến thức tốt về quy trình phát triển phần mềm
# • Tiếng Anh tương đương TOEIC 550 trở lên
# • Có kỹ năng làm việc độc lập và làm việc theo nhóm tốt
# • Có kỹ năng giải quyết vấn đề tốt
# • Khả năng chịu áp lực cao
# • Năng động, sáng tạo, có khả năng đàm phán với khách hàng
# ********************* End
# ********************* Start
# Product Marketing (AI Product)
# https://www.topcv.vn/viec-lam/product-marketing-ai-product/1264622.html?ta_source=ITJobs_LinkDetail
# FPT Smart Cloud (FCI)
# 18 - 25 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Interested in technologies and B2B marketingBasic knowledge in IT and computing is an advantage Good writing and content development skill Bachelor’s degree in marketing or related field (Business, Professional Communication, ect.)At least 2-3 years of experience in product marketing, content creation. Good management, organization, and analysis skill.Fluent in EnglishGood at using Microsoft Office, Excel.Has experience and knowledge about software/ IT is a plus.
# ********************* End
# ********************* Start
# Kỹ Sư Vận Hành Ứng Dụng Java Mức Lương 1,500$
# https://www.topcv.vn/viec-lam/ky-su-van-hanh-ung-dung-java-muc-luong-1-500/1264034.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH sản xuất và thương mại Ninh Thanh
# 800 - 1,500 USD
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Kinh nghiệm từ 2 đến 3 năm làm việc trong vai trò vận hành và duy trì các ứng dụng Java.Hiểu biết về các công nghệ và framework Java như Spring, Hibernate.Kiến thức cơ bản về quản lý hệ thống Linux và mạng máy tính.Kinh nghiệm với các công cụ quản lý mã nguồn và triển khai như Git, Jenkins hoặc các công cụ CI/CD khác.Khả năng làm việc độc lập và trong môi trường làm việc đa nhóm.Sẵn lòng học hỏi và nắm bắt các công nghệ mới.
# ********************* End
# ********************* Start
# Middle Backend Dev (Java, Spring, SQL) - Thu Nhập 25 Triệu Đến 35 Triệu
# https://www.topcv.vn/viec-lam/middle-backend-dev-java-spring-sql-thu-nhap-25-trieu-den-35-trieu/1262907.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN CÔNG NGHỆ AIT
# 25 - 35 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 3 năm
# Toàn thời gian
# Không yêu cầu
# Tốt nghiệp ĐH (bắt buộc) chuyên ngành CNTT, Toán Tin, hoặc tương đương.• Có >=3 năm kinh nghiệm Java, Spring. • Nắm vững khái niệm Object Oriented Programming (OOP), MVC. • Nắm vững kiến thức về cấu trúc dữ liệu và giải thuật. • Đã sử dụng một trong các database: Oracle, MySQL, PostgresQL, MongoDB. • Có kiến thức và kinh nghiệm xây dựng RESTful web services, web services, event-driven message. • Sử dụng thành thạo một số công cụ: Git, Jira, ... • Có khả năng tự học tốt, tư duy tốt, chịu được áp lực công việc cao. • Có khả năng nghiên cứu và giải quyết công việc độc lập. • Đam mê công việc, tích cực tìm hiểu các kiến thức mới; • Ưu tiên có kiến thức và kinh nghiệm công nghệ Kafka, Microservice là một lợi thế; • Ưu tiên có kiến thức và kinh nghiệm triển khai về K8s, docker là một lợi thế;
# ********************* End
# ********************* Start
# DevOps Engineer - Tại Hà Nội - Thu Nhập Hấp Dẫn
# https://www.topcv.vn/viec-lam/devops-engineer-tai-ha-noi-thu-nhap-hap-dan/1223838.html?ta_source=ITJobs_LinkDetail
# Công Ty TNHH LG CNS VIỆT NAM
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 3 năm
# Toàn thời gian
# Không yêu cầu
# o Tốt nghiệp Đại học các chuyên ngành IT, Khoa học máy tính..., giao tiếp tiếng Anh cơ bản ( Toiec 550 trở lên hoặc tương đương)o Có kinh nghiệm xây dựng các hệ thống dựa trên đám mây công cộng (mạng ảo, VM, lưu trữ, sao lưu, v.v.)o Có kinh nghiệm vận hành hệ điều hành dựa trên Linuxo Có kinh nghiệm sử dụng các công cụ tự động hóa dựa trên IaC như Terraform và Packero Có kinh nghiệm xây dựng/vận hành CI/CD ToolChain như Gitlab, Jenkins, Nexus, v.v.o Thành thạo các ngôn ngữ script như Python và Bash ScriptƯu tiên• Có kinh nghiệm về Docker, K8S• Giao tiếp tiếng Hàn
# ********************* End
# ********************* Start
# Account Manager ( Hồ Chí Minh, Hà Nội)
# https://www.topcv.vn/viec-lam/account-manager-ho-chi-minh-ha-noi/1221748.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH CLOUD ACE
# Thoả thuận
# Hồ Chí Minh, Hà Nội
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Graduated from University with a major in Information Technology, International Economics, International Trade or equivalent;Have 3 years of experience in sales, B2B business;Have two years of working experience in IT: hardware (server, DELL server, HP, etc.), software (SAP, etc.);Good communication skills in English;Agile, proactive, persistent. Responsible for work, passionate about business;Ability to present at conferences and events.Prioritize:Experience in FSI and Cloud fields.Having a good understanding of Vietnam & International Cloud services. Especially having a good understanding of public Cloud services such as Google Cloud, AWS, etc.
# ********************* End
# ********************* Start
# Kỹ Sư Phát Triển Phần Mềm Nhúng Matlab/Simulink Tại HCM/ Nhật Bản - Lương Upto 70M
# https://www.topcv.vn/viec-lam/ky-su-phat-trien-phan-mem-nhung-matlab-simulink-tai-hcm-nhat-ban-luong-upto-70m/1261787.html?ta_source=ITJobs_LinkDetail
# CTY TNHH R TECHNO VIỆT NAM
# 30 - 66.4 triệu
# Hồ Chí Minh, Nước Ngoài
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# ◆Yêu cầu bắt buộc - Phát triển phần mềm nhúng sử dụng Matlab / Simulink- Kỹ năng tạo hồ sơ thiết kế phần mềm (thiết kế kiến trúc, thiết kế chi tiết)Trường hợp làm tại nhật : Tiếng nhật N3 trở lênTrường hợp làm tại Việt nam: Tiếng nhật N4◆Ưu tiên:- Phát triển phần mềm nhúng sử dụng ngôn ngữ C- Phát triển phần mềm nhúng cho các bộ phận trên xe (2 bánh, 4 bánh)- Phát triển phần mềm điều khiển quản lý pin hoặc là điều khiển động cơ- Kiến thức liên quan đến phần cứng- Có thể hiểu tài liệu hướng dẫn MPU (bộ vi xử lý)
# ********************* End
# ********************* Start
# Giảng Viên Digital Marketing
# https://www.topcv.vn/brand/fptedu/tuyen-dung/giang-vien-digital-marketing-j1247600.html?ta_source=ITJobs_LinkDetail
# TỔ CHỨC GIÁO DỤC FPT
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Tốt nghiệp đại học trở lên các chuyên ngành Thương mại điện tử, QTKD, Marketing, nhóm ngành kinh tế và công nghệ thông tin; Ưu tiên các ứng viên tốt nghiệp chuyên ngành TMĐT và MarketingKinh nghiệm làm việc thực tế trên 1 nămCó kinh nghiệm thực tế triển khai các hoạt động của Thương mại điện tử và Digital Marketing: làm SEO, PPC, Social media, Content marketing, Mobile marketing, Email marketing; Hoạch định chiến lược Marketing số; Quản trị website; Kinh doanh điện tửSử dụng được các công cụ hỗ trợ (Google Analytics, Google search console, Google ads, Facebook ads, công cụ nghiên cứu từ khoá, công cụ lắng nghe mạng xã hội,...)Có tư duy và kiến thức nền tảng về Marketing và kinh doanhCó kỹ năng sư phạmTận tâm, nhiệt huyết với công việc giảng dạy và môi trường sư phạmCập nhật thường xuyên các xu thế phát triển trong lĩnh vực Digital MarketingƯu tiên các ứng viên có kinh nghiệm thực tiễn và đang công tác trong lĩnh vực Thương mại điện tử, Digital Marketing
# ********************* End
# ********************* Start
# IT System Admin (On-Premise)
# https://www.topcv.vn/viec-lam/it-system-admin-on-premise/1226111.html?ta_source=ITJobs_LinkDetail
# Công Ty TNHH LG CNS VIỆT NAM
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Tốt nghiệp đại học , có chứng chỉ liên quanCó kiến thức và kinh nghiệm vận hành On-premise các server Windows, Linux, UnixCó kiến thức cơ bản về vận hành máy chủ và lưu trữCó kiến thức cơ bản và sử dụng hoạt động của phần mềm trung gian (WEB/WAS)Có khả năng sử dụng PowerShell, Bash, Python
# ********************* End
# ********************* Start
# Technical Support Engineer (IT Background)
# https://www.topcv.vn/viec-lam/technical-support-engineer-it-background/1255319.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH ITECHWX
# 800 - 1,200 USD
# Hồ Chí Minh
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# Proficient in English (4 skills) Available for night shifts At least 6 months of experience (Freshers are welcome with a good learning ability and working attitude) Experience or knowledge in SQL or Basic programming language skills is a must Customer service mindset
# ********************* End
# ********************* Start
# Fullstack Developer (Java, ReactJS)
# https://www.topcv.vn/viec-lam/fullstack-developer-java-reactjs/1237386.html?ta_source=ITJobs_LinkDetail
# Công Ty TNHH LG CNS VIỆT NAM
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Max retries exceeded. Request unsuccessful.
# 429
# ********************* End
# ********************* Start
# Rookie To Engineer (Manual & Automation Testing Trainee)
# https://www.topcv.vn/viec-lam/rookie-to-engineer-manual-automation-testing-trainee/1224695.html?ta_source=ITJobs_LinkDetail
# NashTech
# Thoả thuận
# Hồ Chí Minh, Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Thực tập sinh
# Không yêu cầu kinh nghiệm
# Thực tập
# Không yêu cầu
# Who Should Join The Program?Final year university students and fresh graduates majoring in Software Engineering Computer Science, Information Systems,... or IT-related fields;Can commit full-time throughout the three-month training period;Tech enthusiasts who are passionate, disciplined, responsible, and eager to learn;English capability is preferred.
# ********************* End
# ********************* Start
# Back End Developer ( Java, MySQL, Spring )
# https://www.topcv.vn/viec-lam/back-end-developer-java-mysql-spring/1234208.html?ta_source=ITJobs_LinkDetail
# Công Ty TNHH LG CNS VIỆT NAM
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Max retries exceeded. Request unsuccessful.
# 429
# ********************* End
# ********************* Start
# Project Manager
# https://www.topcv.vn/viec-lam/project-manager/1056691.html?ta_source=ITJobs_LinkDetail
# Công ty Cổ phần DMSpro
# Thoả thuận
# Hồ Chí Minh
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Trưởng nhóm
# 3 năm
# Toàn thời gian
# Không yêu cầu
# Tốt nghiệp Đại học chuyên ngành về IT, quản lý hệ thống thông tin.Tối thiểu có 2 năm kinh nghiệm về lĩnh vực DMS, ERP với vai trò Tư vấn.Có kinh nghiệm tối thiểu 2 năm về quản lý dự án.Có kiến thức tổng quan về hệ thống quản lý DMS, ERP, ...Có kiến thức cơ bản về các quy trình, tiêu chuẩn của thế giới về CNTT như CMMI, ITIL, ISO 27000...Đạt chứng chỉ PMP là một lợi thế.Tiếng Anh tốt.Kỹ năng giao tiếp, lãnh đạo và làm việc nhóm tốt.Kỹ năng quản lý dự án tốt, bao gồm ước tính, lập kế hoạch, tổ chức và lãnh đạo.Là người có trách nhiệm cao, tổ chức tốt, giao tiếp, năng động, dám đi đầu và chịu trách nhiệm cao.
# ********************* End
# ********************* Start
# Account Manager
# https://www.topcv.vn/viec-lam/account-manager/1092558.html?ta_source=ITJobs_LinkDetail
# Công ty Cổ phần DMSpro
# Thoả thuận
# Hồ Chí Minh
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 4 năm
# Toàn thời gian
# Không yêu cầu
# – Tốt nghiệp Cao Đẳng/ Đại Học, ưu tiên chuyên ngành Kinh tế, tài chính, CNTT
# – Có ít nhất 4 năm kinh nghiệm trong ngành sale, trong đó có ít nhất 2 năm kinh nghiệm tư vấn giải pháp phần mềm (Ưu tiên ERP, DMS)
# – Đã từng thực hiện ký kết và tham gia triển khai tối thiểu 5 dự án với KH có quy mô > 1,000 nhân sự.
# – Tiếng Anh tốt là một lợi thế
# – Kỹ năng lập kế hoạch – quản lý , thực hiện và kiểm soát kế hoạch
# – Kỹ năng thuyết trình
# – Kỹ năng đàm phán – thương lượng
# – Kỹ năng giao tiếp tốt, cởi mở, lịch thiệp.
# – Tin học văn phòng thành thạo
# – Có thể làm việc độc lập cũng như làm việc nhóm.
# ********************* End
# ********************* Start
# Lập Trình Viên Web Full Stack
# https://www.topcv.vn/viec-lam/lap-trinh-vien-web-full-stack/1198591.html?ta_source=ITJobs_LinkDetail
# Công ty Cổ Phần Symper Việt Nam
# 25 - 35 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 3 năm
# Toàn thời gian
# Không yêu cầu
# - Có kiến thức tốt về OOP, Clean architecture, ưu tiên có hiểu biết về các design patterns- Có trên 1 năm kinh nghiệm Golang hoặc PHP- Có trên 1 năm kinh nghiệm với lập trình front-end, thành thạo HTML, CSS, Javascript hoặc Typescript. Đã sử dụng một trong các Framework Vuejs, Angular, React- Có kinh nghiệm trong việc phân tích, thiết kế, tối ưu code- Có kinh nghiệm trong việc phân tích, thiết kế, tối ưu hệ thống- Có kinh nghiệm trong việc phân tích, thiết kế, tối ưu DB- Ứng viên có kinh nghiệm quản lý nhóm, đào tạo các thành viên khác trong nhóm là 1 lợi thế- Ưu tiên ứng viên có kinh nghiệm triển khai hoặc sử dụng Scrum trong quá trình làm việc- Ưu tiên ứng viên có kinh nghiệm làm việc trong công ty product với các techstack phức tạp (outsource ít ưu tiên hơn)
# ********************* End
# ********************* Start
# Manual Tester (E- Commerce)
# https://www.topcv.vn/viec-lam/manual-tester-e-commerce/1287293.html?ta_source=ITJobs_LinkDetail
# Công Ty Cổ Phần Đầu Tư Và Công Nghệ Vela
# 15 - 25 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Có 2 năm kinh nghiệm trở lên, có kinh nghiệm làm việc với các dự án e-commerce.Tư duy xây dựng test case.Ham học hỏi, có quan điểm rõ ràng về nghề nghiệp.Khả năng đọc tài liệu tiếng Anh tốt.Nhanh nhẹn, chủ động, có trách nhiệm cao với sản phẩm mình phát triển.Trung thực, nhân cách tốt.Có kiến thức cơ bản về lập trình.
# ********************* End
# ********************* Start
# Data Analyst
# https://www.topcv.vn/viec-lam/data-analyst/1287204.html?ta_source=ITJobs_LinkDetail
# Công Ty Cổ Phần Đầu Tư Và Công Nghệ Vela
# 15 - 20 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Bachelor’s Degree in Computer Science, Statistics, Mathematics, Economics, and other related courses.Strong data thinking & Analytics thinkingAt least 6 months of industry experience in the Business Intelligence or Data Analytics role.Experience working with cross-functional teams to gather requirements and define the right metrics to describe the state of the business - both on a macro-level and a micro-levelBeing able to understand and represent business and user needs, distilling insights to set strong road map that meet short and long-term needsAbility to work well in a fast-paced environment;SQL is requiredExperience with BI tools, and programming languages (Python, R, Java)
# ********************* End
# ********************* Start
# Backend Developer (NodeJS, PHP)
# https://www.topcv.vn/viec-lam/backend-developer-nodejs-php/1287259.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH GIẢI PHÁP CÔNG NGHỆ GOBIZ
# 20 - 35 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 3 năm
# Toàn thời gian
# Không yêu cầu
# Có ít nhất 3 năm kinh nghiệm làm việc với NodeJs, PHP.Kinh nghiệm làm việc với Laravel tối thiểu 2 năm.Có kinh nghiệm làm việc với React, VueJS, AngularJS tối thiểu 2 năm.Có kinh nghiệm làm việc với RESTFul API tối thiểu 3 năm.Có kinh nghiệm làm việc với Docker, Git flow (cả 2 là bắt buộc).Có kinh nghiệm làm việc teamwork với mô hình Agile Scrum.Làm việc được với HTML, CSS.Làm việc được với Kafka, Redis, SQS.Khả năng làm việc độc lập và giải quyết vấn đề là lợi thế.Có kinh nghiệm làm việc với AWS, Google Cloud là lợi thế.Có kỹ năng về Devops, CICD là một lợi thế.
# ********************* End
# ********************* Start
# Business Intelligence
# https://www.topcv.vn/viec-lam/business-intelligence/1287541.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH GIẢI PHÁP CÔNG NGHỆ GOBIZ
# 25 - 35 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Proficient with a variety of statistical analysis methods.Proficient in SQL: Bigquery, PostgreSQL, MySQL.Proficient in NoSQL: MongoDB.Proficient in reporting tool: Google data studio, Metabase..Python is required.Experienced with Linux as a plus point.Strong analytical skills with the ability to collect, organize, analyze, and disseminate significantamounts of information with attention to detail and accuracy.The ability to deliver under deadlines with high quality and no / low errors.
# ********************* End
# ********************* Start
# Data Analyst
# https://www.topcv.vn/viec-lam/data-analyst/1287255.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH GIẢI PHÁP CÔNG NGHỆ GOBIZ
# 15 - 20 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Bachelor’s Degree in Computer Science, Statistics, Mathematics, Economics, and other related courses.Strong data thinking & Analytics thinking.At least 6 months of industry experience in the Business Intelligence or Data Analytics role.Experience working with cross-functional teams to gather requirements and define the right metrics to describe the state of the business - both on a macro-level and a micro-level.Being able to understand and represent business and user needs, distilling insights to set strong road map that meet short and long-term needs.Ability to work well in a fast-paced environment.SQL is required.Experience with BI tools, and programming languages (Python, R, Java).
# ********************* End
# ********************* Start
# Flutter Developer (App)
# https://www.topcv.vn/viec-lam/flutter-developer-app/1284248.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH TD SOLUTION
# 15 - 20 triệu
# Hồ Chí Minh
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Nam
# Tối thiểu 1-2 năm kinh nghiệm làm việc trong lĩnh vực phát triển di độngHiểu biết tốt về kiến trúc dựa trên thành phần front-end.Có kinh nghiệm về một trong các framework / tool sau: Android studio, Xcode, Flutter...Hiểu biết thành thạo về các công cụ tạo và quản lý phiên bản source code, ví dụ GitCó kiến thức vững chắc về các phương pháp hay nhất về phát triển phần mềm, bao gồm các tiêu chuẩn mã hóa, đánh giá, quản lý kiểm soát mã nguồn, xây dựng quy trình, thử nghiệm và vận hànhBằng cử nhân về khoa học máy tính, kỹ thuật phần mềm, công nghệ thông tin hoặc kinh nghiệm tương đươngCó kinh nghiệm về Phát triển Agile và/hoặc có hiểu biết sâu sắc về phương pháp và thực tiễn AgileƯu tiên ứng viên có kinh nghiệm làm việc với Google map API, Geolocator
# ********************* End
# ********************* Start
# LG Track Program For 4th-Year IT Students
# https://www.topcv.vn/viec-lam/lg-track-program-for-4th-year-it-students/1287323.html?ta_source=ITJobs_LinkDetail
# LG Electronics Development Vietnam Company Limited
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# Thực tập sinh
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# - Sinh viên Đại Học năm cuối các chuyên ngành liên quan đến Công Nghệ Thông Tin, đang trong thời gian thực tập hoặc chờ bằng tốt nghiệp; - Có thể đi làm full time vào tháng 6 hoặc tháng 11/2024; - Điểm trung bình tích lũy (GPA) tính đến thời điểm hiện tại từ 3.2/4.0 trở lên; - Điểm cộng nếu bạn từng nhận được các giải thưởng hoặc tham gia các nghiên cứu khoa học. - Gửi CV tiếng Anh (Có ảnh chụp/ file scan chứng thực GPA tích lũy đến thời điểm hiện tại)
# ********************* End
# ********************* Start
# Thực Tập Sinh IT (Phần Cứng)
# https://www.topcv.vn/viec-lam/thuc-tap-sinh-it-phan-cung/460262.html?ta_source=ITJobs_LinkDetail
# Công Ty Cổ Phần Đầu Tư Công Nghệ Hacom
# Trên 3 triệu
# Hà Nội, Bắc Ninh
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Nam
# – Tốt nghiệp các Trường kỹ thuật về CNTT, Kỹ thuật, hoặc người đã ra trường mà chưa có kinh nghiệm về lĩnh vực Kỹ thuật IT phần cứng...– Trung thực, nhanh nhẹn và có tinh thần trách nhiệm trong công việc.LIÊN HỆ:Anh/chị vui lòng gửi CV đầy đủ về quá trình học tập, công tác, khả năng, năng lực bản thân về địa chỉ email hoặc xem thông tin tại website của công ty.
# ********************* End
# ********************* Start
# Middle-Senior Java Develop - Onsite Dự Án Bank
# https://www.topcv.vn/viec-lam/middle-senior-java-develop-onsite-du-an-bank/1129190.html?ta_source=ITJobs_LinkDetail
# Công Ty Cổ Phần GoGroup
# Tới 45 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 3 năm
# Toàn thời gian
# Không yêu cầu
# Kiến thứcTốt nghiệp Đại học trở lên chuyên ngành CNTT hoặc các ngành tương đương hoặc có các chứng chỉ tương đương được công nhận bởi các tổ chức uy tínKinh nghiệm≥ 1 năm kinh nghiệm làm việc thực tế tại các tổ chức CNTTNắm rõ quy trình xây dựng và triển khai phần mềmSử dụng thành thạo Java core, có kinh nghiệm phát triển trên framework Spring Boot.Có hiểu biết về cơ sở dữ liệu: SQL, noSQLCó hiểu biết về việc sử dụng các công cụ quản trị như: Jija, Git,...Ưu tiênƯu tiên kinh nghiệm làm việc trong lĩnh vực tài chính / ngân hàngƯu tiên ứng viên có kinh nghiệm về phát triển ứng dụng theo dạng Cloud Native như: Microservice, CICD, DepOps, Containerization...Ưu tiên Nhân sự đã từng tham gia triển khai các dự án theo mô hình Agile/ScrumƯu tiên nhân sự có kinh nghiệm về xử lý bất đồng bộ, xử lý đa nhiệm, event sourcing, có kinh nghiệm về các hệ thống Message Queue (Kafka, RabbitMQ), có hiểu biết về xử lý cache, job.Ngoại ngữCó khả năng đọc viết tiếng Anh (cơ bản) nghe nói (nếu có thể).Ưu tiên ứng viên có chứng chỉ Tiếng Anh quốc tế (TOEICS 450 trở lên hoặc tương đươngYêu cầu khácKỹ năng giao tiếp và làm việc nhóm tốtSẵn sàng làm việc ngoài giờ hành chínhTinh thần trách nhiệm, ham học hỏi
# ********************* End
# ********************* Start
# Senior IOS Developer (English)
# https://www.topcv.vn/viec-lam/senior-ios-developer-english/1287566.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN LOTUS TECHNOLOGY SERVICES
# Tới 3,000 USD
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 3 năm
# Toàn thời gian
# Không yêu cầu
# xtensive experience of the Swift & Objective C programming languages & the iOS SDK.Experience of developing multi threaded networked iOS mobile applications.Experience in developing custom iOS components.Good understanding on how to scale UI across multiple devices using size classes.Strong MVC/Object Oriented programming skills, demonstrable through past work examples.Unit testing and automation testing technologiesContinuous Integration.A knowledge of Video on demand technologies and workflows, including an understanding of streaming technologies & protocols (including delivery of HLS).Swift and Objective-CMVVMAVFoundationXCTestCOMMUNICATION SKILLSExcellent English communication and presentation skills.Able to effectively communicate technical information to a non-technical audience
# ********************* End
# ********************* Start
# Senior Front-End Developer ( React JS ) - English
# https://www.topcv.vn/viec-lam/senior-front-end-developer-react-js-english/1287573.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN LOTUS TECHNOLOGY SERVICES
# Tới 2,500 USD
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 3 năm
# Toàn thời gian
# Không yêu cầu
# At least 4 years of experience with Javascript Language.Deep knowledge of JS frameworks, especially the ReactJS framework and Redux,VueJS, Webpack, ES6.Strong experience working with Javascript LanguageAbility to work with agile processes & teamworkBe passionate about new technologies and be eager to learn them.Teamwork, Logical thinking, and Problem-solving skills.
# ********************* End
# ********************* Start
# Data Analyst Solution
# https://www.topcv.vn/viec-lam/data-analyst-solution/1136514.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN TƯ VẤN CÔNG NGHỆ NGS
# Tới 30 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Tốt nghiệp chuyên ngành các Khối ngành về Hệ thống thông tin, Cơ sở dữ liệu ...Có từ 2 - 3 năm kinh nghiệm làm việc thực tế trong lĩnh vực Data.Thành thạo phân tích, triển khai báo cáo trên Power BI và các công cụ ETL & DWH khác (SAP BW, Azure, SQL, Power Query,...).Ưu tiên ứng viên có hiểu biết về nghiệp vụ trong lĩnh vực sản xuất, Logistic.Thành thạo tiếng Anh trong công việc (giao tiếp và sử dụng tài liệu).Có khả năng phân tích, lập mô hình dữ liệu trong môi trường học tập dữ liệu lớn.Có kinh nghiệm làm việc với R và Python, Power Apps, Power Automate,.. là một lợi thế.Có kinh nghiệm làm việc với các công cụ và công nghệ quản lý dữ liệu chủ (MDM).Kỹ năng tư duy phân tích và khái niệm nâng cao.Có chứng chỉ về phân tích dữ liệu: Power BI là một lợi thếƯu tiên ứng viên có sự hiểu về biết về lĩnh vực dầu khí.
# ********************* End
# ********************* Start
# Chuyên Viên Kiểm Thử Phần Mềm
# https://www.topcv.vn/viec-lam/chuyen-vien-kiem-thu-phan-mem/1287326.html?ta_source=ITJobs_LinkDetail
# Công ty Cổ phần 1OFFICE
# 10 - 15 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Có từ 2 năm kinh nghiệm test về Web, App trở lên.Tốt nghiệp đại học ngành IT, CNTT hoặc tương đương.Biết phân tích yêu cầu để viết tài liệu và viết testcase đầy đủ.Có tư duy, khả năng phân tích, theo dõi công việcAm hiểu về quy trình testing sản phẩm, làm việc nhóm. Có kinh nghiệm làm việc theo mô hình Agile Scrum.Trách nhiệm và chủ động với công việc, có hiểu biết về các nguồn tự học để nâng cao chuyên môn testing. Hòa đồng vui vẻ, yêu nghề nghiệp, sẵn sàng học hỏi.Ưu tiên ứng viên đi làm ngay.
# ********************* End
# ********************* Start
# Back Office Manager
# https://www.topcv.vn/viec-lam/back-office-manager/1287603.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN CÔNG NGHỆ NAMI
# Thoả thuận
# Hồ Chí Minh
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Trưởng/Phó phòng
# 2 năm
# Toàn thời gian
# Không yêu cầu
# - Bachelor's degree in Business Administration, Accounting, Finance, or a related field.
# - 2+ years of progressive experience in operations management, with demonstrable experience in finance and HR.
# - Literacy in basic finance documents
# - Strong analytical, problem-solving, and decision-making abilities.
# - Excellent communication and interpersonal skills, with the ability to build positive relationships across teams.
# - Demonstrated ability to lead and motivate teams.- Experience in the technology industry
# - Familiarity with AI concepts and applications
# ********************* End
# ********************* Start
# Fresher AI
# https://www.topcv.vn/viec-lam/fresher-ai/1185769.html?ta_source=ITJobs_LinkDetail
# Công ty Cổ phần MISA
# Tới 4 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Thực tập sinh
# Không yêu cầu kinh nghiệm
# Thực tập
# Không yêu cầu
# - Là sinh viên năm cuối chuyên ngành CNTT, Công nghệ phần mềm, Toán Tin, Khoa học máy tính, ...- Điểm GPA > 2.5 - Ham học hỏi, tư duy logic tốt, trách nhiệm với công việc.- Yêu thích nghiên cứu AI, đam mê việc tạo ra sản phẩm đột phá, có ích cho xã hội.- Nắm được kiến thức, thuật toán cơ bản về Machine Learning, Deeplearning- Sử dụng được một số thư viện của ML như numpy, pandas, sklearn, tensorflow, pytorch, ...- Ứng viên sẽ có lợi thế nếu:+ Đã có nền tảng tốt về Giải tích, Xác suất, Thống kê, Đại số tuyến tính.+ Đạt giải thưởng tại các cuộc thi chuyên môn hoặc thành tích học tập tốt.+ Có khả năng giao tiếp tiếng Anh khá.
# ********************* End
# ********************* Start
# Chuyên Viên Dữ Liệu (Data Management)
# https://www.topcv.vn/viec-lam/chuyen-vien-du-lieu-data-management/1232456.html?ta_source=ITJobs_LinkDetail
# Công ty cổ phần Canifa
# 10 - 23 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# – Tốt nghiệp Đại học trở lên chuyên ngành CNTT, khoa học dữ liệu, hệ thống thông tin hoặc các chuyên ngành khác liên quan– Tối thiểu 1 năm kinh nghiệm trong lĩnh vực CNTT, phân tích dữ liệu; đã tham gia xây dựng 1 hệ thống Data Warehouse hoặc phát triển ETL trên nền tảng hoặc công cụ bất kỳ– Thành thạo ít nhất 1 trong những CSDL: MySQL, Postgresql, MongoDB, thành thạo ngôn ngữ truy vấn CSDL, sử dụng ít nhất 1 công cụ ETL hoặc nền tảng xây dựng Data Warehouse– Chứng chỉ Phân tích dữ liệu trong lĩnh vực bán lẻ hoặc thương mại điện tử là lợi thế– Yêu cầu khác: Làm việc nhóm, cẩn thận, tỉ mỉ, ham học hỏi
# ********************* End
# ********************* Start
# Lập Trình Viên Flutter
# https://www.topcv.vn/viec-lam/lap-trinh-vien-flutter/1119889.html?ta_source=ITJobs_LinkDetail
# Công ty cổ phần phần mềm REVOTECH
# Tới 30 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 4 năm
# Toàn thời gian
# Nam
# - Yêu cầu từ 04 năm kinh nghiệm phát triển mobile (flutter, reactnative)- Có kinh nghiệm sử dụng các tools: Android Studio, Xcode, Git, Jira, Trello....- Hiểu biết về Bloc, design parttern,...- Ưu tiên cao với những bạn đã từng tham gia publish app lên Google play, Apple store hoặc có app đã được publish trên Google play, Apple store.- Ưu tiên đã làm việc với quy trình Agile- Có thể onsite khi có dự án yêu cầu.- Có khả năng xử lý tình huống tốt, cẩn thận, trách nhiệm cao trong công việc - Có khả năng làm việc độc lập, làm việc nhóm, giao tiếp tốt và trình bày vấn đề logic
# ********************* End
# ********************* Start
# React Native Leader
# https://www.topcv.vn/viec-lam/react-native-leader/1286954.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN PHẦN MỀM MIRAI VIỆT NAM
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Trưởng nhóm
# 3 năm
# Toàn thời gian
# Không yêu cầu
# Có tối thiểu 3 năm kinh nghiệm lập trình mobile với React NativeCó ít nhât 1 năm làm vị trí teamlead hoặc tương đương.Có 1 năm kinh nghiệm làm việc với Flutter.Có kinh nghiệm làm việc với REST APIs.Sử dụng thành thạo JavaScript, TypeScript, HTML5, CSS3Tư duy logic tốt, chủ động, có tinh thần trách nhiêm với công việc được giaoĐam mê phát triển sản phẩm, đam mê và yêu thích lập trình
# ********************* End
# ********************* Start
# Tester QA
# https://www.topcv.vn/viec-lam/tester-qa/1287498.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH CÔNG NGHỆ FOOBLA
# 8 - 18 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# Có tối thiểu 03 năm kinh nghiệm trong vị trí TesterCó khả năng phân tích, đọc hiểu yêu cầuNắm vững các quy trình và kỹ thuật testCó khả năng lên kế hoạch cho giai đoạn testCó khả năng tạo test case, test script theo yêu cầu hệ thốngCó khả năng phối hợp với Developer trong quá trình fix bugCó khả năng làm việc độc lập hoặc theo nhómCẩn thận, chủ động, có trách nhiệm, có thái độ cầu tiếnCó tinh thần liên tục học hỏi và đổi mớiĐã có kinh nghiệm sử dụng Git, SVN và các công cụ quản trị dự án là một lợi thế.Kỹ năng ngoại ngữ: Đọc và hiểu tiếng Anh CNTT.
# ********************* End
# ********************* Start
# DevOps Developer
# https://www.topcv.vn/viec-lam/devops-developer/1287540.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH CÔNG NGHỆ FOOBLA
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# Ít nhất 01 năm kinh nghiệm với DevOps hoặc SRE.Có kiến thức tốt về Linux.Có kiến thức và hiểu về Docker.Có kinh nghiệm với CI & CD tools.Ưu tiên có kinh nghiệm (không bắt buộc, có hỗ trợ đào tạo) với Kubernetes và quản lý kiến trúc microservice.Ưu tiên có kinh nghiệm (không bắt buộc, có hỗ trợ đào tạo) với AWS services hoặc Google Cloud Platform.Ưu tiên có kinh nghiệm (không bắt buộc, có hỗ trợ đào tạo) sửa lỗi hệ thống, mạng và các vấn đề bảo mật trên các hệ thống có lượng nhánh lớn.Ưu tiên có kinh nghiệm (không bắt buộc, có hỗ trợ đào tạo) với việc cung cấp và phát triển các giải pháp để quản lý và cảnh báo.Ưu tiên có kinh nghiệm (không bắt buộc, có hỗ trợ đào tạo) tự động hóa các tác vụ với ngôn ngữ lập trình như Python, Bash hoặc JavaScript.Mong muốn học hỏi và làm việc với các dịch vụ cơ sở hạ tầng khác nhau được cung cấp bởi các nền tảng đám mây thương mại.
# ********************* End
# ********************* Start
# Intern Developer
# https://www.topcv.vn/viec-lam/intern-developer/1287585.html?ta_source=ITJobs_LinkDetail
# Công ty cổ phần HBLab (Hedspi Brothers Lab)
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Thực tập sinh
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# – Sinh viên năm cuối ngành CNTT các trường đại học ( có thể đi làm full-time), ký hợp đồng sau khi qua phỏng vấn. Ưu tiên ứng viên các trường ĐH Bách Khoa, ĐH Công Nghệ - ĐH Quốc Gia, Bưu chính Viễn Thông, FPT,...– Có kinh nghiệm thực tập tại các công ty IT là lợi thế– Nắm vững kiến thức về lập trình– Tư duy tốt và ham học hỏi
# ********************* End
