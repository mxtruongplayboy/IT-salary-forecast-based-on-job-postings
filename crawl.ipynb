# %% [markdown]
# Cài đặt BeautifulSoup

# %%
# %pip install beautifulsoup4
# %pip install requests
# Out:
# Collecting requestsNote: you may need to restart the kernel to use updated packages.
#
#   Obtaining dependency information for requests from https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl.metadata
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/57/ec/80c8d48ac8b1741d5b963797b7c0c869335619e13d4744ca2f67fc11c6fc/charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/c2/e7/a82b05cf63a603df6e68d59ae6a68bf5064484a0718ea5033660af4b54a9/idna-3.6-py3-none-any.whl.metadata
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/a2/73/a68704750a7679d0b6d3ad7aa8d4da8e14e151ae82e6fee774e6e0d05ec8/urllib3-2.2.1-py3-none-any.whl.metadata
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/ba/06/a07f096c664aeb9f01624f858c3add0a4e913d6c96257acb4fce61e7de14/certifi-2024.2.2-py3-none-any.whl.metadata
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#    ------ --------------------------------- 10.2/62.6 kB ? eta -:--:--
#    ---------------------------------------- 62.6/62.6 kB 830.7 kB/s eta 0:00:00
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ---------------------------------------- 0.0/163.8 kB ? eta -:--:--
#    --------- ----------------------------- 41.0/163.8 kB 991.0 kB/s eta 0:00:01
#    -------------- ------------------------ 61.4/163.8 kB 825.8 kB/s eta 0:00:01
#    --------------------- ----------------- 92.2/163.8 kB 585.1 kB/s eta 0:00:01
#    -------------------------- ----------- 112.6/163.8 kB 547.6 kB/s eta 0:00:01
#    --------------------------------- ---- 143.4/163.8 kB 568.9 kB/s eta 0:00:01
#    -------------------------------------- 163.8/163.8 kB 614.1 kB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl (99 kB)
#    ---------------------------------------- 0.0/99.9 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/99.9 kB ? eta -:--:--
#    ------------------------ --------------- 61.4/99.9 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 99.9/99.9 kB 1.1 MB/s eta 0:00:00
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.6 kB ? eta -:--:--
#    ---------------------------------------  61.4/61.6 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 61.6/61.6 kB 1.7 MB/s eta 0:00:00
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.1 kB ? eta -:--:--
#    --------- ----------------------------- 30.7/121.1 kB 660.6 kB/s eta 0:00:01
#    -------------------------- ------------ 81.9/121.1 kB 919.0 kB/s eta 0:00:01
#    ---------------------------------------- 121.1/121.1 kB 1.0 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.2.2 charset-normalizer-3.3.2 idna-3.6 requests-2.31.0 urllib3-2.2.1
#   WARNING: The script normalizer.exe is installed in 'c:\Users\Mai Xuan Truong\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Import thư viện

# %%
from bs4 import BeautifulSoup
import requests
import time
import csv

# %% [markdown]
# Đối tượng thể hiện mỗi bài tuyển dụng

# %%
class Job:
    def __init__(self, title, link, company, salary, locations, level, yearOfExperience, contractType, sex, skills):
        self.title = title
        self.link = link
        self.company = company
        self.salary = salary
        self.locations = locations
        self.level = level
        self.yearOfExperience = yearOfExperience
        self.contractType = contractType
        self.sex = sex
        self.skills = skills

# %% [markdown]
# Hàm ghi một đối tượng công việc vào 1 hàng trong file .CSV

# %%
def write_to_csv(job):
    with open('jobs.csv', mode='a', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            # Write header row if file is empty
            if file.tell() == 0:
                writer.writerow(['Title', 'Link', 'Company', 'Salary', 'Locations', 'Level', 'Year of Experience', 'Contract Type', 'Sex', 'Skills'])
            writer.writerow([job.title, job.link, job.company, job.salary, job.locations, job.level, job.yearOfExperience, job.contractType, job.sex, job.skills])

# %% [markdown]
# Hàm lấy thông tin chi tiết của mỗi bài tuyển dụng

# %%
def get_jobs(item):
    print('********************* Start')
    try:
        title = item.find(class_='title').text.strip()
        print(title)
        link = item.find(class_='title').find('a')['href'].strip()
        print(link)
        company = item.find(class_='company').text.strip()
        print(company)
        salary = item.find(class_='title-salary').text.strip()
        print(salary)
        locations = item.find(class_='address').text.strip()
        print(locations)
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
        }

        # Số lần thử lại tối đa
        max_retries = 5
        retry_delay = 1  # Thời gian chờ giữa các lần thử lại, đơn vị là giây

        retry_count = 0
        while retry_count < max_retries:
            response2 = requests.get(link, headers=headers)
            if response2.status_code == 429:  # Nếu nhận được mã trạng thái 429
                print("Too many requests. Retrying after waiting...")
                retry_count += 1
                time.sleep(retry_delay)  # Chờ trước khi thử lại
            else:
                # Xử lý kết quả ở đây nếu cần
                # Ví dụ: print(response.text)
                break
        else:
            print("Max retries exceeded. Request unsuccessful.")
        print(response2.status_code)
        if response2.status_code == 200:
            print('********************* Success')
            soup2 = BeautifulSoup(response2.text, 'html.parser')
            if link.startswith("https://www.topcv.vn/brand/"):
                infos = soup2.find_all(class_='box-info')
                generals = infos[0].find_all('span')
                level = generals[3].text.strip()
                print(level)
                yearOfExperience = generals[5].text.strip()
                print(yearOfExperience)
                contractType = generals[2].text.strip()
                print(contractType)
                sex = generals[4].text.strip()
                print(sex)
                skills = infos[2].find(class_='content-tab').text.strip()
                print(skills)
            else:
                generals = soup2.find(class_='job-detail__box--right job-detail__body-right--item job-detail__body-right--box-general').find_all(class_='box-general-group-info-value')
                level = generals[0].text.strip()
                print(level)
                yearOfExperience = generals[1].text.strip()
                print(yearOfExperience)
                contractType = generals[3].text.strip()
                print(contractType)
                sex = generals[4].text.strip()
                print(sex)
                skills = soup2.find_all(class_='job-description__item--content')[1].text.strip()
                print(skills)
        else:
            level = None
            yearOfExperience = None
            contractType = None
            sex = None
            skills = None
        job = Job(title, link, company, salary, locations, level, yearOfExperience, contractType, sex, skills)
        # Writing to CSV file
        write_to_csv(job)
    except:
        print('********************* Fail')
    print('********************* End')

# %% [markdown]
# Hiện tại khuyến khích crawl mỗi lần 1 trang sau 1 khoảng thời gian rồi crawl tiếp trang khác để tránh lỗi 429

# %% [markdown]
# Crawl 1 trang

# %%
url = 'https://www.topcv.vn/viec-lam-it'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}
response = requests.get(url, headers=headers)
if response.status_code == 200:
    # Sử dụng BeautifulSoup để phân tích HTML
    soup = BeautifulSoup(response.text, 'html.parser')
    jobs = soup.find_all(class_='job-item-2')
    for job in jobs:
        get_jobs(job)   
else:
    print('Yêu cầu không thành công. Mã trạng thái:', response.status_code)

# %% [markdown]
# Crawl toàn bộ trang

# %%
url = 'https://www.topcv.vn/viec-lam-it'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}
response = requests.get(url, headers=headers)
if response.status_code == 200:
    # Sử dụng BeautifulSoup để phân tích HTML
    soup = BeautifulSoup(response.text, 'html.parser')
    num_pages = int(soup.find(class_='pagination').find_all('li')[-2].text)
    print(num_pages)
    jobs = soup.find_all(class_='job-item-2')
    for job in jobs:
        get_jobs(job)
    for i in range(2, num_pages + 1):
        url = 'https://www.topcv.vn/viec-lam-it?page=' + str(i)
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            jobs = soup.find_all(class_='job-item-2')
            for job in jobs:
                get_jobs(job)
        else:
            print('Yêu cầu không thành công. Mã trạng thái:', response.status_code)              
else:
    print('Yêu cầu không thành công. Mã trạng thái:', response.status_code)
# Out:
# 64
# ********************* Start
# Trưởng Nhóm Triển Khai - Vận Hành Hệ Thống
# https://www.topcv.vn/viec-lam/truong-nhom-trien-khai-van-hanh-he-thong/1269618.html?ta_source=ITJobs_LinkDetail
# CHI NHÁNH CÔNG TY CỔ PHẦN PHẦN MỀM VIỄN THÔNG MIỀN NAM TẠI HÀ NỘI
# 15 - 20 triệu
# Hà Nội
# 200
# ********************* Success
# Trưởng nhóm
# 1 năm
# Toàn thời gian
# Không yêu cầu
# - Tốt nghiệp từ Cao đẳng trở lên chuyên ngành CNTT hoặc các chuyên ngành liên quan;
# - Có ít nhất 01 năm kinh nghiệm ở vị trí tương đương;
# - Có kiến thức nền tảng với HDH Linux (Ubuntu, CentOS, ...), Vmware
# - Có kiến thức nền tảng về Networking và hệ thống mạng LAN/WAN,Có kiến thức VoIP là lợi thế
# - Có kỹ năng phân tích, tổng hợp và xử lý thông tin, dữ liệu CNTT;
# - Có kỹ năng chẩn đoán và giải quyết vấn đề;
# ********************* End
# ********************* Start
# Unity Developer - Lương Từ 12 - 30 Triệu - Được Chia Sẻ Doanh Thu Của Các Dự Án
# https://www.topcv.vn/viec-lam/unity-developer-luong-tu-12-30-trieu-duoc-chia-se-doanh-thu-cua-cac-du-an/1272229.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH NGen
# 12 - 30 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Có tối thiểu 1 năm kinh nghiệm phát triển game trên nền tảng UnityTốt nghiệp trường đại học Bách Khoa Hà NộiĐam mê làm các sản phẩm gameNăng động, ham học hỏi.
# ********************* End
# ********************* Start
# Software Developer (C/C++)
# https://www.topcv.vn/viec-lam/software-developer-c-c/1282162.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH Shinhan DS Việt Nam
# Thoả thuận
# Hồ Chí Minh
# 200
# ********************* Success
# Nhân viên
# 3 năm
# Toàn thời gian
# Không yêu cầu
# From 3 years of experience in Software Development/Embedded DevelopmentProficiency in C/C++ based on Unix, Linux.Familiar with SQL/Oracle.Good to have: Pro C and Finance & Banking field.Good problem-solving & communication skills.Detail-oriented, proactive, and fast learner.Can communicate in English.
# ********************* End
# ********************* Start
# Nhân Viên Xử Lý Dữ Liệu Hình Ảnh Tại Hà Nội (6 - 8 Triệu) Không Yêu Cầu Kinh Nghiệm
# https://www.topcv.vn/viec-lam/nhan-vien-xu-ly-du-lieu-hinh-anh-tai-ha-noi-6-8-trieu-khong-yeu-cau-kinh-nghiem/1283047.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH LTS Global Digital Services
# 6 - 8 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# Tốt nghiệp các trường đại học/cao đẳng
# Kiên trì và cẩn thận
# Ưu tiên có kinh nghiệm về xử lý dữ liệu hình ảnh
# Độ tuổi: 18 - 25
# ********************* End
# ********************* Start
# Giáo Viên Tin Học
# https://www.topcv.vn/brand/fptedu/tuyen-dung/giao-vien-tin-hoc-j1270573.html?ta_source=ITJobs_LinkDetail
# TỔ CHỨC GIÁO DỤC FPT
# Thoả thuận
# Thanh Hoá
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Tốt nghiệp Đại học trở lên chuyên ngành Sư phạm Tin học hoặc các chuyên ngành có liên quan (Công nghệ thông tin, Khoa học máy tính, Kĩ thuật phần mềm, An toàn thông tin,...), có Chứng chỉ nghiệp vụ sư phạm (nếu chuyên ngành tốt nghiệp không thuộc khối ngành Sư phạm)Có kiến thức chuyên môn tốt, hiểu biết về lập trình, đặc biệt là lập trình dành cho lứa tuổi trẻ em (Scratch, Tynker, Minecraft, Python, Roblox, Robotics,...)Có tâm huyết với nghề, phẩm chất đạo đức tốtKỹ năng giao tiếp, thuyết trình, giải quyết tình huống sư phạm và làm việc nhóm tốtNhanh nhẹn, năng động, có tinh thần học hỏi và sẵn sàng đổi mới phương pháp dạy họcThành thạo các phần mềm, ứng dụng và các thiết bị hỗ trợ giảng dạyƯu tiên ứng viên có từ 02 năm kinh nghiệm trở lên ở vị trí tương đương, cựu học sinh trường chuyên, từng đạt giải trong các kì thi Học sinh Giỏi hoặc có kinh nghiệm hướng dẫn đội tuyển học sinh dự thi Học sinh Giỏi.
# ********************* End
# ********************* Start
# Data Scientist - Up To $2,500 Per Month Tại Hà Nội
# https://www.topcv.vn/viec-lam/data-scientist-up-to-2-500-per-month-tai-ha-noi/1274624.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH GIẢI PHÁP CÔNG NGHỆ ALETECH
# Trên 2,500 USD
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 5 năm
# Toàn thời gian
# Không yêu cầu
# 1. Educational Background: - Bachelor's or Master’s degree in Computer Science, Data Science, or a related field.2. Experience: - Minimum of 5 years of experience in data management, analytics, and visualization. - Demonstrated success in implementing data strategies within a business context.3. Technical Skills: - Proficiency in data analysis tools such as Python. - Familiarity with SQL Server, Azure Blob Storage, and other relevant data storage technologies. - Strong expertise in data visualization tools (e.g., Tableau, Power BI).4. Statistical Modeling and Machine Learning: - Profound understanding of statistical modeling and machine learning techniques. - Ability to apply advanced analytics to tackle complex business challenges.5. Language Proficiency: - Exceptional English language skills, both written and verbal. - Capacity to communicate technical concepts effectively to non-technical stakeholders.6. Leadership and Collaboration: - Proven leadership and team management capabilities. - Effective collaboration with cross-functional teams and outstanding interpersonal skills.7. Analytical Thinking: - Strong analytical and problem-solving skills, with meticulous attention to detail. - Ability to translate complex data into actionable insights.8. Innovation and Continuous Learning: - Commitment to staying abreast of industry trends and emerging technologies. - Track record of driving innovation in data management practices.
# ********************* End
# ********************* Start
# Fresher Software Developer
# https://www.topcv.vn/viec-lam/fresher-software-developer/1273298.html?ta_source=ITJobs_LinkDetail
# Công Ty TNHH LG CNS VIỆT NAM
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# Dưới 1 năm
# Toàn thời gian
# Không yêu cầu
# I. Theo vị trí1. Kỹ sư lập trình WebCó tư duy logic, thuật toán tốtCó kiến thức cơ bản về Java core, Spring, Spring BootCó hiểu biết về Rest APIHiểu biết chung về HTML / HTML5, CSS / CSS3Hiểu biết về UI/UX PrinciplesCó hiểu biết về json object (understand)Có kinh nghiệm sử dụng Visual Code Studio, Git, Git Flow2. Kỹ sư Cloud/ DevOpsCó kiến thức liên quan tới Window, Linux, Unix OSCó kiến thức liên quan tới private cloud, public cloud.Có hiểu biết liên quan tới CI/CD tools: Gitlab, Jenkins, Nexus, etc.Có khả năng sử dụng scripts: Python, Bash ScriptCó khả năng xử lý vấn đềII. Yêu cầu chungTốt nghiệp Đại học với các chuyên ngành liên quan tới Máy tính, phần mềm, vvTiếng Anh TOEIC 450 trở lênCó khả năng làm việc nhóm và giao tiếp với team memberCẩn thận, trách nhiệm, có tinh thần cầu tiến, ham học hỏi và khả năng tự học[Ưu tiên]Có hiểu biết về SASS, BEMCó hiểu biết về jquery, ajaxBiết sử dụng Adobe Photoshop, Figma, coding convension cleanCó thể giao tiếp tiếng Hàn
# ********************* End
# ********************* Start
# Tester Leader/Trưởng Nhóm Kiểm Thử - Lương Up To 25M
# https://www.topcv.vn/viec-lam/tester-leader-truong-nhom-kiem-thu-luong-up-to-25m/1283961.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH FIVE-STAR E-LEARNING
# 20 - 25 triệu
# Hà Nội
# 200
# ********************* Success
# Trưởng nhóm
# 3 năm
# Toàn thời gian
# Không yêu cầu
# Có ít nhất 3 năm kinh nghiệm Test phần mềm các dự ánCó kinh nghiệm ít nhất 1 năm kinh nghiệm Test leaderTốt nghiệp ĐH chuyên ngành CNTT, toán tin ứng dụng, phần mềm, ...Thành thạo kiến thức, kỹ thuật, kỹ năng Test : Hiểu biết về các Test process, Test Level, Test Types và các kỹ thuật kiểm thử phần mềmCó khả năng đọc hiểu, phân tích tốtCó khả năng giao tiếp tốtCó khả năng dẫn dắt, tạo động lực cho member;Có khả năng thích ứng nhanh, liên tục cải tiến.
# ********************* End
# ********************* Start
# Ecommerce Marketing
# https://www.topcv.vn/viec-lam/ecommerce-marketing/1273674.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH CÔNG NGHỆ THÔNG TIN AN PHÁT
# 9 - 12 triệu
# Hồ Chí Minh
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Tốt nghiệp đại học các chuyên ngành Kinh tế, QTKD, Marketing, hoặc các ngành nghề khác có liên quan.
# Có ít nhất 1 năm kinh nghiệm về ecommerce marketing/online marketing.
# Có khả năng phân tích, đánh giá và lập kế hoạch.
# Kỹ năng đàm phán tốt.
# Nhanh nhẹn, chủ động, chăm chỉ, cầu thị, trách nhiệm và có khả năng chịu áp lực công việc và áp lực
# ********************* End
# ********************* Start
# Front-End Developers Thu Nhập Upto 2,600USD
# https://www.topcv.vn/viec-lam/front-end-developers-thu-nhap-upto-2-600usd/1197636.html?ta_source=ITJobs_LinkDetail
# GEM MULTIMEDIA SDN. BHD
# 2,500 - 2,600 USD
# Nước Ngoài
# 200
# ********************* Success
# Trưởng nhóm
# 3 năm
# Toàn thời gian
# Không yêu cầu
# - Tốt nghiệp Đại học CNTT hoặc tương đương.- Có 03 năm kinh nghiệm lập trình Front - End.- Có kiến thức vững về HTML, CSS, JavaScript.- Sử dụng thành thạo Bootstrap, HTML5, CSS3, SCSS.- Nắm vững các thư viện như jQuery, LESS của Javascript.- Sử dụng thành thạo các framework của Javascript hiện nay như AngularJS, Backbone, Ember, ReactJS...- Có kiến thức về UX/UI, Responsive Design và thiết kế Mobile.- Có kinh nghiệm về xử lý Realtime, Client-Server (API, Socket).- Biết sử dụng các phần mềm đồ họa như Photoshop, AI.- Có kinh nghiệm làm việc API (sử dụng REST/SOAP, Microservices, ESB, SOA, GraphQL, Sockets, ...)- Có kinh nghiệm sử dụng các công cụ phát triển phần mềm (ví dụ: Git, Jenkins, JIRA)- Có kinh nghiệm phát triển ứng dụng web sử dụng NodeJS, AngularJS, Python, Java, A- Có tư duy lập trình tốt, có khả năng làm việc nhóm và độc lập, cẩn thận và sáng tạo.- Có khả năng tự nghiên cứu về công nghệ mới.- Đọc hiểu tài liệu tiếng Anh.
# ********************* End
# ********************* Start
# Nhân Viên IT Phần Mềm Tại Bắc Ninh
# https://www.topcv.vn/viec-lam/nhan-vien-it-phan-mem-tai-bac-ninh/877681.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH MPT Solution (Việt Nam)
# Thoả thuận
# Bắc Ninh
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# 1). Tốt nghiệp Cao đẳng trở lên các chuyên ngành công nghệ thông tin, công nghệ phần mềm.
# 2). Thành thạo các ngôn ngữ lập trình : C#, Java , Javascript , Dotnet...
# 3). Có hiểu biết về SQLSERVER、MYSQL, Oracle. Hiểu biết Oracle là một lợi thế
# 4) Tiếng Trung thành thạo
# ********************* End
# ********************* Start
# Nhân Viên IT Hệ Thống (Thu Nhập 18 - 25 Triệu + Hỗ Trợ Ăn Trưa)
# https://www.topcv.vn/viec-lam/nhan-vien-it-he-thong-thu-nhap-18-25-trieu-ho-tro-an-trua/1280663.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN TOMECO AN KHANG
# 18 - 25 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 5 năm
# Toàn thời gian
# Không yêu cầu
# - Đại học chuyên ngành liên quan: công nghệ thông tin
# - Có kiến thức về Công nghệ thông tin, máy văn phòng.
# - Am hiểu về hệ thống mạng Lan, Wan, internet;
# - Am hiểu về hệ điều hành Windows Server/Linux, ...;
# - Am hiểu quản trị cơ sở dữ liệu SQL Server;
# - Am hiểu hệ thống bảo mật: DLP; network security;
# - Nắm vững các quy định về bảo mật thông tin;
# - Quản lý các thiết bị công nghệ thông tin và công nghệ của công ty;
# ********************* End
# ********************* Start
# Chuyên Viên Digital Marketing Executive - Đi Làm Ngay
# https://www.topcv.vn/viec-lam/chuyen-vien-digital-marketing-executive-di-lam-ngay/1280870.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH DƯỢC PHẨM PRO CUỘC SỐNG XANH
# Trên 10 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# - Tốt nghiệp Đại học chuyên ngành marketing hoặc liên quan. Ưu tiên ứng viên nam.
# - Kinh nghiệm từ 2 năm ở vị trí Digital Marketing là một lợi thế.
# - Am hiểu về các công cụ Digital Marketing và sử dụng thành thạo, edit video để chạy quảng cáo/ thiết kế hình ảnh cơ bản
# - Có khả năng xây dựng chiến lược marketing và làm việc theo chỉ tiêu kế hoạch, tinh thần trách nhiệm cao, đúng tiến độ.
# - Kỹ năng viết và giao tiếp tốt.
# - Thái độ tích cực và suy nghĩ lạc quan trong công việc.
# - Ưu tiên ứng viên có khả năng quay dựng chụp hình và thiết kế cơ bản.
# ********************* End
# ********************* Start
# Nhân Viên Xử Lý Dữ Liệu Tiếng Nhật (Tiếng Nhật N3)
# https://www.topcv.vn/viec-lam/nhan-vien-xu-ly-du-lieu-tieng-nhat-tieng-nhat-n3/1286664.html?ta_source=ITJobs_LinkDetail
# CHI NHÁNH CÔNG TY TNHH PASONA TECH VIỆT NAM TẠI HÀ NỘI
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# - Tốt nghiệp đại học, cao đẳng.
# - Tiếng Nhật tương đương N3.
# - Thành thạo tin học văn phòng, đặc biệt là Excel, Word.
# - Có khả năng giao tiếp tốt, nhanh nhẹn, chăm chỉ và ham học hỏi.
# - Yêu thích làm việc trong môi trường công ty Nhật Bản.
# ********************* End
# ********************* Start
# Automotive Android App Developer
# https://www.topcv.vn/brand/boschglobalsoftwaretechnologies/tuyen-dung/automotive-android-app-developer-j1278575.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH BOSCH GLOBAL SOFTWARE TECHNOLOGIES
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# ********************* Fail
# ********************* End
# ********************* Start
# CTV Vận Hành Lớp Học Trực Tuyến Part Time
# https://www.topcv.vn/viec-lam/ctv-van-hanh-lop-hoc-truc-tuyen-part-time/1276247.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH PHÁT TRIỂN GIẢI PHÁP & CNTT DIỆP ANH
# 2.5 - 6 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Bán thời gian
# Không yêu cầu
# Độ tuổi: 18 - 21 tuổiCó kinh nghiệm và kỹ năng sử dụng các công cụ Microsoft OfficeCó kỹ năng sử dụng các phần mềm điều khiển máy tính từ xa : teamviewer, ultraviewer, anydesk...Chưa có kinh nghiệm sẽ được công ty đào tạo từ đầu.Có laptop cá nhân để phục vụ cho công việc.Có kinh nghiệm hoạt động đội nhóm.
# ********************* End
# ********************* Start
# Nhân Viên Cấp Cao Quản Lý Dữ Liệu Tài Sản (Thu Nhập 8 - 12 Triệu) Tại Hồ Chí Minh
# https://www.topcv.vn/brand/vus-etsc/tuyen-dung/nhan-vien-cap-cao-quan-ly-du-lieu-tai-san-thu-nhap-8-12-trieu-tai-ho-chi-minh-j1267798.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN QUỐC TẾ ANH VĂN HỘI VIỆT MỸ
# 8 - 12 triệu
# Hồ Chí Minh
# 200
# ********************* Success
# ********************* Fail
# ********************* End
# ********************* Start
# Trưởng Phòng Giải Pháp Tại Hà Nội Thu Nhập 30M-40M
# https://www.topcv.vn/viec-lam/truong-phong-giai-phap-tai-ha-noi-thu-nhap-30m-40m/1013348.html?ta_source=ITJobs_LinkDetail
# Công ty cổ phần Ecoit
# 30 - 40 triệu
# Hà Nội
# 200
# ********************* Success
# Trưởng/Phó phòng
# 5 năm
# Toàn thời gian
# Không yêu cầu
# – Tốt nghiệp Đại Học trở lên chuyên ngành CNTT, tin học ứng dụng, điện tử viễn thông hoặc tương đương. – Am hiểu rõ các vấn đề pháp lý liên quan đến đấu thầu. – Có chứng chỉ về quản lý dự án là một lợi thế. – Có tối thiểu từ 03 năm kinh nghiệm làm việc trong các dự án CNTT, ĐẶC BIỆT là các dự án đầu tư công. – Có kinh nghiệm trong việc lập Báo cáo nghiên cứu khả thi, Thiết kế thi công tổng dự toán, Đề cương và Dự toán chi tiết... và các hồ sơ liên quan trong các dự án CNTT. – Nắm vững các giải pháp ứng dụng CNTT, giải pháp chuyển đổi số doanh nghiệp. (Hệ thống quản lý văn bản điều hành, Hệ thống thông tin nội bộ, Cổng TTĐT, giải pháp số hóa tài liệu, giải pháp kho lưu trữ số...) – Nắm vững cơ sở pháp lý và các thủ tục tham gia đấu thầu. – Có tinh thần học hỏi, có khả năng xây dựng/ thiết lập và duy trì các mối quan hệ với đối tác/ khách hàng; – Thành thạo giao tiếp, đàm phán, phân tích dữ liệu. – Có khả năng làm việc độc lập và làm việc nhóm.- Trình độ tin học: Thành thạo các kỹ năng vi tính văn phòng (MS. Word, Excel, PowerPoint, Outlook, Internet Explorer); Biết sử dụng Project Manager, Mindjet Mind manager là điểm cộng.
# ********************* End
# ********************* Start
# Tester Nữ (Có Kinh Nghiệm) - Tại Hà Nội
# https://www.topcv.vn/viec-lam/tester-nu-co-kinh-nghiem-tai-ha-noi/1261111.html?ta_source=ITJobs_LinkDetail
# MochiMochi
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Nữ
# Đã có tối thiểu 1 năm kinh nghiệm trong các công việc tương tự Kỹ năng đọc hiểu tiếng Anh cơ bảnCởi mở và sẵn sàng học hỏiGửi kèm manual/automation testcase về UI/UX/Api/DB đã từng thực hiện trong CV ứng tuyển
# ********************* End
# ********************* Start
# IT Communicator (Japanese Speaking) Nhân Viên IT Tiếng Nhật
# https://www.topcv.vn/viec-lam/it-communicator-japanese-speaking-nhan-vien-it-tieng-nhat/1277713.html?ta_source=ITJobs_LinkDetail
# CHI NHÁNH CÔNG TY TNHH PASONA TECH VIỆT NAM TẠI ĐÀ NẴNG
# Thoả thuận
# Đà Nẵng
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Tốt nghiệp Đại họcKhả năng đọc, viết, tiếp thu và giao tiếp tiếng Nhật ở mức N2 trở lênCó từ 1 năm kinh nghiệm làm việc ở vị trí Communicator hoặc tương đươngNăng động và ham học hỏi (trong lĩnh vực kinh doanh, công nghệ thông tin, ngôn ngữ)Có tinh thần làm việc nhómƯu tiên:Kinh nghiệm trong lĩnh vực ITKinh nghiệm làm việc trong công ty Nhật Khả năng giao tiếp bằng tiếng Anh.
# ********************* End
# ********************* Start
# IT Comtor Tiếng Nhật -Thu Nhập Lên Tới 25 Triệu/Tháng
# https://www.topcv.vn/viec-lam/it-comtor-tieng-nhat-thu-nhap-len-toi-25-trieu-thang/1281141.html?ta_source=ITJobs_LinkDetail
# Beetechsoft
# 15 - 25 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Có trình độ cao đẳng trở lên. Tốt nghiệp các chuyên ngành liên quan đến tiếng Nhật. (N1, N2 hoặc tương đương)Có từ 1.5 năm kinh nghiệm với vị trí trí IT Comtor - Lĩnh vực phần mềm.Thành thạo vi tính văn phòng đặc biệt là word, excel, powerpoint.Kỹ năng xử lý công việc nhanh, chính xác.Kỹ năng giao tiếp, thuyết phục tốt.Cẩn thận, trung thực, kiên trì.Năng động, tự tin, sáng tạo, có khả năng làm việc độc lập và làm việc theo nhóm.Có khả năng hướng dẫn các member có ít kinh nghiệm.Ưu tiên những ứng viên luôn nỗ lực hết mình trong mọi hoàn cảnh và đưa ra những ý kiến đóng góp để phát triển công việc.Đã có kinh nghiệm làm việc tại các công ty Nhật Bản, Âu, Mỹ là một lợi thế.
# ********************* End
# ********************* Start
# Giáo Viên Tin Học - Tại Bắc Giang
# https://www.topcv.vn/brand/fptedu/tuyen-dung/giao-vien-tin-hoc-tai-bac-giang-j1270454.html?ta_source=ITJobs_LinkDetail
# TỔ CHỨC GIÁO DỤC FPT
# Thoả thuận
# Bắc Giang
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Tốt nghiệp Đại học trở lên chuyên ngành Sư phạm Tin học hoặc các chuyên ngành có liên quan (Công nghệ thông tin, Khoa học máy tính, Kĩ thuật phần mềm, An toàn thông tin,...), có Chứng chỉ nghiệp vụ sư phạm (nếu chuyên ngành tốt nghiệp không thuộc khối ngành Sư phạm)Có kiến thức chuyên môn tốt, hiểu biết về lập trình, đặc biệt là lập trình dành cho lứa tuổi trẻ em (Scratch, Tynker, Minecraft, Python, Roblox, Robotics,...)Có tâm huyết với nghề, phẩm chất đạo đức tốtKỹ năng giao tiếp, thuyết trình, giải quyết tình huống sư phạm và làm việc nhóm tốtNhanh nhẹn, năng động, có tinh thần học hỏi và sẵn sàng đổi mới phương pháp dạy họcThành thạo các phần mềm, ứng dụng và các thiết bị hỗ trợ giảng dạyƯu tiên ứng viên có từ 02 năm kinh nghiệm trở lên ở vị trí tương đương, cựu học sinh trường chuyên, từng đạt giải trong các kì thi Học sinh Giỏi hoặc có kinh nghiệm hướng dẫn đội tuyển học sinh dự thi Học sinh Giỏi.
# ********************* End
# ********************* Start
# Nhân Viên IT Helpdesk Nam Tại Vĩnh Phúc
# https://www.topcv.vn/viec-lam/nhan-vien-it-helpdesk-nam-tai-vinh-phuc/1281011.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH Phân Phối Synnex FPT
# Tới 9 triệu
# Vĩnh Phúc
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Nam
# Nam, tốt nghiệp Cao đẳng trở lên các ngành điện tử, viễn thông, CNTT.
# Có 02 năm kinh nghiệm trong lĩnh vực liên quan
# Hiểu biết về hệ thống mạng LAN, WAN
# Biết cài đặt mail Outlook, lưu trữ thông tin mail.
# Có khả năng quản trị các hệ thống của MS như AD, DNS, DHCP, file, TMG ...
# Có khả năng cài đặt và quản lý các ứng dụng
# Chịu được áp lực công việc, có khả năng làm việc độc lập và làm việc nhóm
# ********************* End
# ********************* Start
# Digital Marketing
# https://www.topcv.vn/viec-lam/digital-marketing/1278513.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH WELLNESS LIFESTYLE
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Max retries exceeded. Request unsuccessful.
# 429
# ********************* End
# ********************* Start
# UX Designer (Upto 30M)
# https://www.topcv.vn/viec-lam/ux-designer-upto-30m/1280602.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN SYSTEMATIC FUNCTIONS
# Tới 30 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Max retries exceeded. Request unsuccessful.
# 429
# ********************* End
# ********************* Start
# Quản Lý Dự Án (IT Project Manager) Làm Việc Tại Hà Nội
# https://www.topcv.vn/viec-lam/quan-ly-du-an-it-project-manager-lam-viec-tai-ha-noi/1273420.html?ta_source=ITJobs_LinkDetail
# Công Ty TNHH LG CNS VIỆT NAM
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Max retries exceeded. Request unsuccessful.
# 429
# ********************* End
# ********************* Start
# Unity Developer (Fresher)
# https://www.topcv.vn/viec-lam/unity-developer-fresher/1279020.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH BraveZone
# 400 - 600 USD
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Max retries exceeded. Request unsuccessful.
# 429
# ********************* End
# ********************* Start
# Kỹ Sư Phát Triển Phần Mềm (C/C++/Java/Golang/Android/IOS) - Lương Từ $650 - $2200++
# https://www.topcv.vn/brand/congnghiepvienthongquandoi/tuyen-dung/ky-su-phat-trien-phan-mem-c-c-java-golang-android-ios-luong-tu-650-2200-j1269191.html?ta_source=ITJobs_LinkDetail
# TẬP ĐOÀN CÔNG NGHIỆP - VIỄN THÔNG QUÂN ĐỘI
# 650 - 2,200 USD
# Hà Nội, Hồ Chí Minh
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# - Tốt nghiệp Đại học chính quy loại Khá trở lên chuyên ngành: Công nghệ thông tin, Khoa học máy tính, Toán – tin, Điện tử viễn thông,...hoặc các chuyên ngành kỹ thuật khác liên quan.- Trình độ tiếng Anh tương đương tối thiểu 550 điểm Toeic.- Có tối thiểu 02 năm kinh nghiệm liên quan đến vị trí ứng tuyển.- Sử dụng tốt ít nhất 1 ngôn ngữ lập trình (C/C++/Java/Golang/Android/iOS).- Có kiến thức nền tảng về công nghệ thông tin, ngôn ngữ mô hình hóa UML; quy trình phát triển phần mềm và toàn bộ vòng đời ứng dụng; mạng máy tính (các loại mạng, kiến trúc mạng, lập trình mạng, giao thức); ngôn ngữ truy vấn dữ liệu SQL, làm việc với hệ quản trị cơ sở dữ liệu, cấu trúc dữ liệu và giải thuật.
# ********************* End
# ********************* Start
# Kỹ Sư IT Network (CSR Firewall, Networking, English)
# https://www.topcv.vn/viec-lam/ky-su-it-network-csr-firewall-networking-english/1273727.html?ta_source=ITJobs_LinkDetail
# Công Ty TNHH LG CNS VIỆT NAM
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Bắt buộcTốt nghiệp đại học trở lên, ưu tiên các chuyên ngành liên quanCó kiến thức cơ bản về Network(Hiểu về Switch, Routing, Port v.v)Có kinh nghiệm xử lí task về Firewall (thêm, sửa, xóa policy ...)Ưu tiênCó kính nghiệm vận hành Firewall như Fortinet, PaloaltoCó chứng chỉ về Network như CCNA, CCNPCó kinh nghiệm nhiều về vận hành NetworkGiao tiếp cơ bản bằng tiếng anh (Toiec 450 hoặc tương đương)
# ********************* End
# ********************* Start
# Penetration Tester
# https://www.topcv.vn/brand/boschglobalsoftwaretechnologies/tuyen-dung/penetration-tester-j1239754.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH BOSCH GLOBAL SOFTWARE TECHNOLOGIES
# Thoả thuận
# Hồ Chí Minh
# 200
# ********************* Success
# ********************* Fail
# ********************* End
# ********************* Start
# Nhân Viên Tester (Ba/ QC/ Tester)
# https://www.topcv.vn/viec-lam/nhan-vien-tester-ba-qc-tester/1279780.html?ta_source=ITJobs_LinkDetail
# Công ty Cổ phần Công nghệ Tin học và Dịch vụ Goline
# 12 - 18 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# - Tốt nghiệp đại học chuyên ngành CNTT.
# - Skills yêu cầu
# + Kinh nghiệm test ít nhất 1 năm
# + Có khả năng lên Testcase
# + Có khả năng test qua API
# - Skill lợi thế
# + Ưu tiên đã từng triển khai dự án phần mềm chứng khoán, có kinh nghiệm về lĩnh vực chứng khoán
# + Có chứng chỉ ISTQB
# ********************* End
# ********************* Start
# Android Developer (Junior) Thu Nhập 12-15 Triệu/ Tháng
# https://www.topcv.vn/viec-lam/android-developer-junior-thu-nhap-12-15-trieu-thang/1283867.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH NEKO SOFT
# 12 - 15 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Tối thiểu 01 năm kinh nghiệm làm việc với Java Android.Có kinh nghiệm phát triển ứng dụng Android.Có kiến thức về Kotlin và làm việc với những công nghệ mới RxJava,...Có thể sử dụng thành thạo một số công cụ như SVN, Git,...Khả năng đọc hiểu tài liệu (Tiếng Việt/Tiếng Anh) phục vụ vị trí công việc.Khả năng làm việc độc lập, làm việc nhóm.Tinh thần trách nhiệm cao, có khả năng chịu được áp lực công việc.Yêu thích làm sản phẩm ứng dụng.
# ********************* End
# ********************* Start
# Trưởng Bộ Phận Phụ Trách Ứng Dụng Công Nghệ, Phần Mềm Trong Doanh Nghiệp - Thu Nhập Hấp Dẫn Thoả Thuận Theo Năng Lực (TPHCM, Bình Dương)
# https://www.topcv.vn/viec-lam/truong-bo-phan-phu-trach-ung-dung-cong-nghe-phan-mem-trong-doanh-nghiep-thu-nhap-hap-dan-thoa-thuan-theo-nang-luc-tphcm-binh-duong/1285414.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH DU HỌC DU LỊCH THƯƠNG MẠI DỊCH VỤ Á ÂU
# Thoả thuận
# Hồ Chí Minh, Bình Dương
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Trưởng/Phó phòng
# 5 năm
# Toàn thời gian
# Nam
# - Kinh nghiệm: 05 năm kinh nghiệm ở vị trí tương đương trong lĩnh vực ứng dụng Công nghệ, phần mềm trong doanh nghiệp.- Độ tuổi: Từ 27 tuổi trở lên- Giới tính: Nam
# - Kiến thức:
# + Hiểu biết về nền tảng Công nghệ thông tin
# + Hiểu biết về các quy trình phát triển phần mềm; Các công cụ quản trị dự án, môi trường phát triển ứng dụng, ngôn ngữ lập trình ứng dụng, cơ sở dữ liệu
# + Hiểu biết về các quy trình vận hành bảo trì các hệ thống CNTT; Các công cụ quản trị giám sát hệ thống CNTT.
# ********************* End
# ********************* Start
# Nhân Viên Kỹ Thuật Truyền Hình Cáp- Không Yêu Cầu Kinh Nghiệm (TP. Thủ Đức-HCM, Bình Dương, Bình Phước)
# https://www.topcv.vn/viec-lam/nhan-vien-ky-thuat-truyen-hinh-cap-khong-yeu-cau-kinh-nghiem-tp-thu-duc-hcm-binh-duong-binh-phuoc/1283964.html?ta_source=ITJobs_LinkDetail
# CHI NHÁNH 4 - CÔNG TY TNHH TRUYỀN HÌNH CÁP SAIGONTOURIST
# 7 - 10 triệu
# Bình Dương & 2 nơi khác
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Nam
# - Chiều cao : 1m60 trở lên- Yêu cầu giới tính : Nam- Độ tuổi : 25 - 35- Tốt nghiệp từ trung cấp trở lên
# - Ngành nghề : Bưu chính viễn thông, Công nghệ thông tin, Điện/Điện tử/Điện lạnh, Điện tử viễn thông CHÚ Ý: Chỉ tuyển khoa- CNTT, Điện tử viễn thông, bưu chính viễn thông (không tuyển nghành khác)
# ********************* End
# ********************* Start
# Chuyên Viên Phân Tích Nghiệp Vụ (Lương Từ 12.000.000 Đến 18.000.000đ/Tháng)
# https://www.topcv.vn/viec-lam/chuyen-vien-phan-tich-nghiep-vu-luong-tu-12-000-000-den-18-000-000d-thang/1275713.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH sản xuất và thương mại Ninh Thanh
# 12 - 18 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Tốt nghiệp hệ chính quy các Trường Đại học trong nước hoặc nước ngoàiCó ít nhất 02 năm kinh nghiệm trong công việc phân tích nghiệp vụ, phát triển sản phẩm cho các Ngân hàng, Tổ chức Tài chính, Tập đoàn & Công ty về CNTT, Startup/FintechƯu tiên ứng viên có kinh nghiệm triển khai, quản lý dự ánCó kiến thức tổng quan, hiểu biết/kinh nghiệm và phương pháp làm việc Agile.Đã từng làm việc với các hệ thống quản lý định danh và truy cập (Oracle IAM, SailPoint...) là một lợi thế
# ********************* End
# ********************* Start
# Flutter Developer (Salary Up To 40M)
# https://www.topcv.vn/viec-lam/flutter-developer-salary-up-to-40m/1279028.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN SYSTEMATIC FUNCTIONS
# Tới 40 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 3 năm
# Toàn thời gian
# Không yêu cầu
# a, Kỹ năng chuyên môn ● Có ít nhất 3 năm kinh nghiệm về lập trình Mobile trong đó ít nhất 2 năm phát triển sản phẩm trên đa nền tảng Flutter. b, Về kiến thức ● Có kinh nghiệm phát triển ứng dụng đa nền tảng Flutter (ưu tiên các ứng viên có kinh nghiệm thuần Mobile). ● Có kinh nghiệm với GIT source control, Agile process. ● Hiểu biết về OOP, thiết kế hệ thống. Hiểu biết về cấu trúc dữ liệu giải thuật là lợi thế. ● Có kinh nghiệm về Firebase. ● Có hiểu biết về CI/CD. d, Kỹ năng khác ● Có kỹ năng giao tiếp hiệu quả, làm việc nhóm. ● Có khả năng đóng góp, xây dựng cải thiện UIUX.
# ********************* End
# ********************* Start
# Chuyên Viên Kiểm Thử Manual Tester (Lương Từ 10tr Đến 15tr/Tháng)
# https://www.topcv.vn/viec-lam/chuyen-vien-kiem-thu-manual-tester-luong-tu-10tr-den-15tr-thang/1275714.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH sản xuất và thương mại Ninh Thanh
# 10 - 15 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# 2 năm kinh nghiệm làm việc trong các dự án phát triển phầnCó kinh nghiệm trong việc xác định khi nào cần triển khai kiểm thử từ các yêu cầu chức năng và trong thử nghiệm trên nhiều trình duyệt / môi trườngCó kinh nghiệm sử dụng các công cụ và quy trình dùng trong kiểm thử phần mềm webCó kinh nghiệm làm việc trên các tiêu chuẩn và công nghệ web bao gồm cả việc tuân thủ khả năng truy cập
# ********************* End
# ********************* Start
# Nhân Viên Marketing Google Ads Tại Agency (Thu Nhập 10 - 20 Triệu)
# https://www.topcv.vn/viec-lam/nhan-vien-marketing-google-ads-tai-agency-thu-nhap-10-20-trieu/940589.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN ĐẦU TƯ QUỐC TẾ TOPTO HOLDING
# 10 - 20 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Về chuyên môn:Có ít nhất 2 - 3 năm kinh nghiệm trong ngànhThành thạo các loại hình quảng cáo của Google. Trong đó bắt buộc nắm vững: Google Search, Google Remarketing, Google Shopping, GDN, Youtube AdsCó tính chủ động CAO. Khi làm việc không cần phải có người khác nhắc việcCó khả năng chịu được áp lực công việc và kỹ năng teamwork tốtCó thể viết mô tả về cấu trúc và nội dung các landingpage (các trang đích) quảng cáo cho Design hoặc bộ phận lập trình webCó khả năng chạy các chiến dịch chuyển đổi và cách setup chuyển đổiSử dụng thành thạo các công cụ nghiên cứu từ khóaƯu tiên ứng vên có khả năng tự xây dựng landingpage bằng wordpress hay các nền tảng tạo landingpage (được đào tạo nhưng cần nắm cơ bản)Sử dụng thuần thục các công cụ phân tích, thống kê để tối ưu hiệu quả chiến dịch quảng cáo: Google Ads, Google Analytics, Google Tag Manager.Hiểu rõ rõ cơ chế targeting, retargeting của Google và đề xuất kết hợp với các kênh thuộc nền tảng khácƯu tiên từng chạy ngân sách lớnAm hiểu về hành vi khách hàng.Có tư duy logic tốt.Giao tiếp tốt, chịu khó học hỏi cái mới.Có chứng nhận về năng lực sử dụng Google Ads (thi trên Skillshop)Có khả năng đọc hiểu tiếng Anh. Điểm TOEIC từ 450 (không bắt buộc) Về con người:Hướng đến kết quả và Sẵn sàng chịu trách nhiệmLà người sống TỬ TẾ, trung thựcKhả năng học hỏi nhanhBiết lắng nghe, chia sẻLuôn mong muốn phấn đấu và phát triển bản thân.Hồ sơ ứng tuyển gồm:Một số case hoặc chiến dịch đã tham gia triển khai có kết quả tốt (nếu có, có thể gửi thông tin sơ bộ nếu thông tin dự án không tiện tiết lộ chi tiết)Một số trang đích đã tham gia xây dựng (nếu có)
# ********************* End
# ********************* Start
# Phó Phòng Phát Triển Đối Tác Mảng Fintech (Thu Nhập Hấp Dẫn)
# https://www.topcv.vn/viec-lam/pho-phong-phat-trien-doi-tac-mang-fintech-thu-nhap-hap-dan/1267767.html?ta_source=ITJobs_LinkDetail
# Công ty cổ phần Công nghệ Sapo
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Trưởng/Phó phòng
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# Có tối thiểu 5 năm kinh nghiệm quản lý trong lĩnh vực tài chính, ưu tiên ứng viên đã làm việc tạicác ngân hàng TMCP, công ty fintech.Hiểu biết về hoạt động thương mại số và các nền tảng quản lý bán hàngTầm nhìn chiến lược tốt và kinh nghiệm quản lý team có quy mô nhân sự từ 5 người trởlên.Kỹ năng giao tiếp, đàm phán tốt, có kinh nghiệm làm partnership là một lợi thế.Tiếng Anh giao tiếp tương đương TOIEC từ 650 trở lênCó tư duy logic, phản biện và khả năng tập trung cao.Có tư duy đổi mới liên tục và thích ứng nhanh chóng với sự thay đổi trên thị trường.
# ********************* End
# ********************* Start
# Fullstack Developer Lương Upto 35 Triệu
# https://www.topcv.vn/viec-lam/fullstack-developer-luong-upto-35-trieu/1250886.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN MIA RETAIL
# Tới 35 triệu
# Hồ Chí Minh
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 4 năm
# Toàn thời gian
# Không yêu cầu
# - Hiểu biết về quy trình phát triển phần mềm - Có kinh nghiệm từ 4 năm về một hoặc nhiều công nghệ sau: + Backend: PHP, Nodejs, Typescript, Nestjs, Cloud (Plus Python) + Frontend: Reactjs, Vuejs, Nextjs - Có kinh nghiệm với DevOps, cơ sở hạ tầng đám mây AWS và các biện pháp bảo mật- Team work tốt và nhiệt tình học hỏi các kỹ năng/nền tảng mới.- Có khả năng phân tích yêu cầu, thiết kế được cấu trúc API, UI, UX là lợi thế - Có kinh nghiệm xử lý Big Data là một lợi thế lớn- Kiến thức chuyên môn về .Js và Python- 4 Năm kinh nghiệm lập trình
# ********************* End
# ********************* Start
# Embedded Android Developer (2 Yoe, C/C++)
# https://www.topcv.vn/viec-lam/embedded-android-developer-2-yoe-c-c/1280406.html?ta_source=ITJobs_LinkDetail
# MARUSYS VINA CO.,LTD
# Tới 50 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# EducationUniversity degree or above in Computer Science/Electronics/Industrial Engineering or equivalent.Working Experience and Knowledge[Mandatory] Have at least 2 years of experience in software development in C/C++[Mandatory] Have understanding and experience in Embedded Android/LinuxHave good knowledge of Object-Oriented Programming (OOP)and Design PatternsHave hands-on experience in using JIRA, SVN, GITExperiences related to multi-thread, multi-process programming (IPC)[Preferred] Knowledge about Android Platform, Related Product[Preferred] Have experience with STB product[Preferred] Have experience in Media Service (OTT), Android TV Input Framework (TIF)[Preferred] Experiences related to Open Source porting & development & customizingSkills and AbilitiesGood English skills in both verbal and writtenThorough, sincere, responsible, understanding mindsetStrong motivation to develop a career in automotive software and car automationActive communication internally and externallyGood ability in teamwork and working independentlyAbility to take business trip/ travel (e.g. Korea, UK, ect.)SupervisionPart Manager/ Team leader of Automotive team of MARUSYS VINAProject Manager in Korea
# ********************* End
# ********************* Start
# Nhân Viên IT (PHP + JAVASCRIPT)
# https://www.topcv.vn/viec-lam/nhan-vien-it-php-javascript/1278024.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH CHYANG SHENG VIỆT NAM
# Thoả thuận
# Bình Dương
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Nam
# - Có kiến thức cơ bản về lập trình WEB (PHP, JAVASCRIPT) để tạo trang web- Có kiến thức về các hệ quản trị cơ sở dữ liệu MARIADB- Trao đổi thêm khi phỏng vấn
# ********************* End
# ********************* Start
# Frontend Developer ( Vuejs Từ 2 Năm Kinh Nghiệm, Thành Thạo Javascript, Thu Nhập Lên Đến 30 Triệu Tại Hà Nội )
# https://www.topcv.vn/viec-lam/frontend-developer-vuejs-tu-2-nam-kinh-nghiem-thanh-thao-javascript-thu-nhap-len-den-30-trieu-tai-ha-noi/1277173.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN DỊCH VỤ VÀ PHÁT TRIỂN CÔNG NGHỆ BEAE VIỆT NAM
# 18 - 30 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Nam
# - Hiểu và sử dụng thành thạo framework Vuejs, kinh nghiệm tối thiểu 2 năm kinh nghiệm làm việc với các dự án.
# - Thành thạo các ngôn ngữ như JavaScript, HTML, CSS và ít nhất một ngôn ngữ phía máy chủ (ví dụ: Nodejs, PHP, Go).
# - Có kinh nghiệm với các framework backend như Nest JS, Laravel.
# - Quen thuộc với các hệ thống cơ sở dữ liệu như MySQL, MongoDB hoặc SQL Server.
# - Có kinh nghiệm kiểm soát mã nguồn như: Git, SVN, ...
# - Có kinh nghiệm với Security Audit (không bắt buộc).
# - Làm việc nhóm, giao tiếp tốt và có trách nhiệm cao.
# - Sẵn sàng học hỏi các công nghệ mới.
# ********************* End
# ********************* Start
# Kỹ Sư An Ninh Mạng Lương Từ 40 Triệu / Tháng
# https://www.topcv.vn/viec-lam/ky-su-an-ninh-mang-luong-tu-40-trieu-thang/1026763.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH sản xuất và thương mại Ninh Thanh
# Trên 40 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Nam
# - Kinh nghiệm hơn 2 năm về an toàn thông tin, kiểm thử bảo mật, tìm kiếm lỗ hổng.- Có một trong các chứng chỉ bảo mật sau sẽ là một lợi thế: OSCP, OSWE, CEH, AWS- Có kiến thức, kinh nhiệm penetration test ứng dụng web, mobile, desktop app- Có khả năng đọc hiểu các ngôn ngữ lập trình: Java, .Net, Node js- Hiểu về kiến trúc ứng dụng, hệ thống.- Hiểu, nắm rõ các tiêu chuẩn ANTT ứng dụng, tiêu chuẩn ANTT cho lĩnh vực Ngân hàng, tài chính.- Hiểu về các giải pháp ANTT ứng dụng như web application firewall, API security
# ********************* End
# ********************* Start
# Kỹ Sư Phát Triển Phần Mềm Nhúng (Ngôn Ngữ Lập Trình C/C++) - Lương Từ $650 - $2200++
# https://www.topcv.vn/brand/congnghiepvienthongquandoi/tuyen-dung/ky-su-phat-trien-phan-mem-nhung-ngon-ngu-lap-trinh-c-c-luong-tu-650-2200-j1269217.html?ta_source=ITJobs_LinkDetail
# TẬP ĐOÀN CÔNG NGHIỆP - VIỄN THÔNG QUÂN ĐỘI
# 650 - 2,200 USD
# Hà Nội, Hồ Chí Minh
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# - Tốt nghiệp Đại học chính quy loại Khá trở lên chuyên ngành: Công nghệ thông tin, Điện tử viễn thông,...hoặc các chuyên ngành kỹ thuật khác liên quan.- Trình độ tiếng Anh tương đương tối thiểu 550 điểm Toeic.- Có tối thiểu 02 năm kinh nghiệm liên quan đến vị trí ứng tuyển.- Có kiến thức nền tảng về kỹ thuật vi xử lý và kỹ thuật điện tử (điện tử tương tự, điện tử số, mạch logic...), kiến trúc máy tính, hệ điều hành, kỹ thuật lập trình.- Sử dụng tốt ít nhất 01 công cụ lập trình nhúng cho vi điều khiển, vi xử lý cao cấp (ARM, DSP, ASIC).- Sử dụng tốt ngôn ngữ lập trình C/C++. - Có kinh nghiệm làm việc trên hệ điều hành Linux.- Có kinh nghiệm lập trình ngoại vi, giao tiếp bộ nhớ, giao tiếp số (UART/SPI/I2C/CAN...).
# ********************* End
# ********************* Start
# Lập Trình Viên Back-End (NestJS)
# https://www.topcv.vn/viec-lam/lap-trinh-vien-back-end-nestjs/1278060.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH The Human
# 20 - 30 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# - Kinh nghiệm ít nhất 2 năm với NestJS.- Hiểu biết về Node.js và các framework liên quan.- Kỹ năng làm việc nhóm tốt.- Kinh nghiệm với cơ sở dữ liệu SQL và NoSQL.- Kỹ năng giao tiếp và làm việc nhóm tốt.- Ưu tiên có kinh nghiệm với các dự án về logistic hoặc hệ thống quản lý chuỗi cung ứng.
# ********************* End
# ********************* Start
# IT Data Architect
# https://www.topcv.vn/viec-lam/it-data-architect/1251660.html?ta_source=ITJobs_LinkDetail
# Công Ty TNHH LG CNS VIỆT NAM
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# Trên 5 năm
# Toàn thời gian
# Không yêu cầu
# Có kinh nghiệm liên quan đến các công việc sau• Quản trị dữ liệu (data standards/meta, Er-model, big data/DW model, distributed model,, v.v.)• Triển khai DBMS (Oracle, MySQL series, MS SQL, DB2, v.v. RDBMS)• Triển khai NoSQL (Key Column Type, Document Type, Time Series Type, v.v.)• Triển khai xử lý và lưu trữ dữ liệu trên public cloud hoặc big data platform (RDS, Redshift, BigQuery, v.v.)• Giao tiếp tiếng Anh trung bình (có khả năng thực hiện công việc bằng tiếng Anh)[Ưu tiên]• Tính cách chủ động trong công việc, hòa đồng với đồng nghiệp• Giao tiếp tiếng Hàn
# ********************* End
# ********************* Start
# DEV Unity - Senior Fulltime Lương Đến 40 Triệu
# https://www.topcv.vn/viec-lam/dev-unity-senior-fulltime-luong-den-40-trieu/1282022.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH NTADA
# Tới 40 triệu
# Hồ Chí Minh
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 4 năm
# Toàn thời gian
# Không yêu cầu
# Tối thiểu 4 năm kinh nghiệm trong mảng Dev Unity.
# Có kinh nghiệm sử dụng Cocos là một điểm cộng.
# Có kinh nghiệm xử lý những công việc liên quan Backend, Database.
# Có kinh nghiệm phát triển nhiều thể loại các tựa game hyper, casual, hybrid, mid.
# Tư duy logic, khả năng nghiên cứu công nghệ tốt.
# Làm việc đạt đúng tiến độ, chỉ tiêu được bàn giao, tinh thần trách nhiệm làm việc độc lập cao.
# Có khả năng chịu áp lực cao trong công việc.
# Làm OT khi công ty yêu cầu đẩy nhanh tiến độ công việc.
# ********************* End
# ********************* Start
# Kỹ Sư Lập Trình PLC
# https://www.topcv.vn/viec-lam/ky-su-lap-trinh-plc/1271281.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH hệ thống Saishunkan Việt Nam
# Tới 20 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# - Tốt nghiệp cao đẳng, Đại học chuyên ngành Tự động hoá/ Điện tử. - Có kinh nghiệm trong việc lập trình PLC - Có khả năng đọc hiểu tài liệu kỹ thuật ( datasheet, technical documentation v.v..) - Có khả năng đọc hiểu tài liệu yêu cầu bằng tiếng Anh  - Hiểu biết về Ethernet TCP/IP, EtherNet/IP - Có kỹ năng làm việc theo nhóm, chịu được áp lực trong công việc và tinh thần trách nhiệm cao. - Có thể giải quyết vấn đề độc lập, kỹ năng phân tích yêu cầu và đưa ra giải pháp để giải quyết các vấn đề khó khăn trong công việc. - Sẵn sàng đi công tác Nhật ngắn hạn, dài hạn theo yêu cầu dự án
# ********************* End
# ********************* Start
# Backend Developer (PHP)
# https://www.topcv.vn/viec-lam/backend-developer-php/1278296.html?ta_source=ITJobs_LinkDetail
# Lampart
# Thoả thuận
# Hồ Chí Minh
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# • Vui lòng chú ý kiểm tra Inbox và cả Spam mail để nhận phản hồi từ Lampart nhé.• Ứng viên vui lòng cập nhật và gửi 2 CV (Tiếng Anh và Tiếng Việt) để được xử lý nhanh chóng.Yêu cầu kỹ thuật:Tốt nghiệp các ngành Khoa học máy tính, công nghệ thông tin, ...Kinh nghiệm 1 - 5 năm (tuỳ theo level) trong việc phát triển ứng dụng web, lập trình back end bằng ngôn ngữ PHP.· Framework Lavarel, CodeIgniter, CakePHP, Zend, ...· JavaScript và JS Frameworks (jQuery, AngularJS, Vuejs...).· MySQL và thiết kế Database.Yêu cầu khác:Tích cực, chủ động chia sẻ ý kiến, suy nghĩ của bản thân.Kỹ năng làm việc nhóm và giao tiếp tốt.Kỹ năng quản lý thời gian.Kỹ năng giải quyết vấn đề.Lợi thế:Có kinh nghiệm về phát triển ứng dụng di động là một lợi thế.Từng làm việc hoặc yêu thích môi trường Nhật Bản là một điểm cộng.Kỹ năng tạo & tổng hợp báo cáo tốt.Kỹ năng tiếp cận và học hỏi công nghệ mới nhanh chóng.Kiên trì, không từ bỏ khi gặp khó khăn – “Không gì là không thể”.
# ********************* End
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# ********************* Start
# Chuyên Viên Kiểm Thử Phần Mềm
# https://www.topcv.vn/viec-lam/chuyen-vien-kiem-thu-phan-mem/1285861.html?ta_source=ITJobs_LinkDetail
# TỔNG CÔNG TY BƯU ĐIỆN VIỆT NAM
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# - Độ tuổi dưới 30- Tốt nghiệp Đại học chuyên ngành CNTT, Tin học quản lý, Hệ thống thông tin- Có kinh nghiệm kiểm thử phần mềm từ 1 năm trở lên.- Có kỹ năng viết kịch bản kiểm thử, thực hiện kiểm thử, lập kế hoạch và ước lượng thời gian kiểm thử, log lỗi, lập báo cáo kiểm thử.- Có kỹ năng làm việc độc lập và làm việc theo nhóm tốt.- Có thể làm việc với cơ sở dữ liệu như MySQL, Oracle, SQL Server...- Có kinh nghiệm test API, Database, Web, Mobile.- Có hiểu biết về các giai đoạn kiểm thử (Unit Test, Integration Test, System Test v.v...), và các kỹ thuật kiểm thử phần mềm.- Có khả năng thu thập, phân tích, tổng hợp thông tin.
# ********************* End
# ********************* Start
# Lập Trình Viên
# https://www.topcv.vn/viec-lam/lap-trinh-vien/1286558.html?ta_source=ITJobs_LinkDetail
# Công ty Cổ phần Navee
# Thoả thuận
# Hồ Chí Minh
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Kinh nghiệm: 2 nămKhả năng học hỏi nhanh và sẵn sàng tiếp thu các kiến thức, khái niệm mới, khả năng giải quyết vấn đề nhanh trong phạm vi công việc được giaoKiến thức chuyên sâu về lập trình web/app, thông thạo một số ngôn ngữ lập trình phổ biến: C#/.Net, Java, ABAPAm hiểu hệ quản trị cơ sở dữ liệu: MS SQL/Azure, Oracle, DBA Tuning...Kỹ năng về an toàn bảo mậtKỹ năng làm việc với dataKỹ năng thuyết trình
# ********************* End
# ********************* Start
# AI Engineer/ GPTs (Python)
# https://www.topcv.vn/viec-lam/ai-engineer-gpts-python/1286669.html?ta_source=ITJobs_LinkDetail
# C-UNIT SQUARE CO., LTD
# Thoả thuận
# Hồ Chí Minh
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Max retries exceeded. Request unsuccessful.
# 429
# ********************* End
# ********************* Start
# Chuyên Viên IT
# https://www.topcv.vn/viec-lam/chuyen-vien-it/1285636.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN AN VIỆT SÔNG HỒNG
# 9 - 13 triệu
# Hồ Chí Minh
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Max retries exceeded. Request unsuccessful.
# 429
# ********************* End
# ********************* Start
# Intern Project Manager
# https://www.topcv.vn/viec-lam/intern-project-manager/1286890.html?ta_source=ITJobs_LinkDetail
# POWERGATE AUSTRALIA (CÔNG TY CỔ PHẦN TẬP ĐOÀN POWERGATE)
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# Thực tập sinh
# Không yêu cầu kinh nghiệm
# Thực tập
# Không yêu cầu
# ...
# Trình độ tiếng Nhật từ N2 hoặc tương đương trở lênCó ít nhất 1 năm kinh nghiệm ở vị trí ComtorTự tin về khả năng giao tiếp.Khả năng phân tích, tư duy logic, xử lý vấn đề tốt và chịu được áp lực công việc.Tốt nghiệp Trung cấp trở lên
# ********************* End
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# Yêu cầu không thành công. Mã trạng thái: 429
# ********************* Start
# Fullstack Developer (TypeScript, ReactJS, NodeJS)
# https://www.topcv.vn/viec-lam/fullstack-developer-typescript-reactjs-nodejs/1256736.html?ta_source=ITJobs_LinkDetail
# Nichietsu
# Tới 30 triệu
# Hồ Chí Minh
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Our Requirements:- Strong proficiency with TypeScript, ReactJS, NodeJS.- 1-3 years of relevant experience with a bachelor’s degree in computer science.- Experience in developing frontend web applications, with expertise in deep optimization of end-user experience, stability & scalability, code modularity, and rendering latency.- Strong Typescript/HTML/CSS frontend engineering experience and deep understanding of the underlying design philosophy and implementation ofcommon web frameworks, including ReactJS/NodeJS.- Experience with Babel, Webpack, HTTP2, or other TypeScript building tools.- Knowledge of database technologies and agile development methodologies.- Experience working with databases, such as MySQL or PostgreSQL.- Understanding of microservices architecture.- Experience building large-scale web applications and optimizing front-end performance in a fast-moving team environment (Caching/CDN/Service Worker...).- Experience with API Integration (REST/JSON).- Experience with DevOps, On Premise, AWS (CloudFront S3), CI/CD is a plus- English communication is a plus.- Excellent problem-solving and management skills.
# ********************* End
# ********************* Start
# UX/UI Designer Website, Web App, Mobile
# https://www.topcv.vn/brand/monamedia/tuyen-dung/ux-ui-designer-website-web-app-mobile-j694748.html?ta_source=ITJobs_LinkDetail
# Mona Media
# 8 - 30 triệu
# Hồ Chí Minh
# 200
# ********************* Success
# ********************* Fail
# ********************* End
# ********************* Start
# Bridge Engineer (BrSE)
# https://www.topcv.vn/viec-lam/bridge-engineer-brse/1256176.html?ta_source=ITJobs_LinkDetail
# Nichietsu
# Tới 40 triệu
# Hồ Chí Minh
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Max retries exceeded. Request unsuccessful.
# 429
# ********************* End
# ********************* Start
# Kỹ Sư Vận Hành Khai Thác Hệ Thống
# https://www.topcv.vn/viec-lam/ky-su-van-hanh-khai-thac-he-thong/1256484.html?ta_source=ITJobs_LinkDetail
# Viettel Software
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# 1. Trình độ - Tốt nghiệp đại học chính quy chuyên ngành công nghệ thông tin/điện tử viễn thông. 2. Yêu cầu kiến thức: - Nắm, hiểu bản chất các kiến thức cơ bản lý thuyết về điện tử viễn thông, công nghệ thông tin. - Hiểu biết cơ bản các hệ quản trị CSDL như CSDL SQL server, Oracle, MySQL, NoSQL - Có kiến thức về Bigdata và Cloud computing là lợi thế. - Có kinh nghiệm lập trình java/python là lợi thế. - Có tố chất tốt, đam mê công việc, năng động, sáng tạo, tư duy phân tích, tổng hợp. Trung thực, trách nhiệm, cẩn thận, tỉ mỉ. - Ưu tiên có chứng chỉ về mạng, Linux, Oracle (CCNA, CCNP, LPIC, OCA, OCP), MariaDB, kubenates (k8s), DevOps 3. Yêu cầu về kỹ năng - Có tinh thần tỉ mỉ, cẩn thận, trách nhiệm. - Có kinh nghiệm làm việc và triển khai các hệ thống trên Linux là lợi thế. - Có kĩ năng lập trình với 1 trong các ngôn ngữ như Bash/Shell, Python, Java, Scala... - Có kinh nghiệm làm việc với nginx, apache, mysql, docker, k8s,...(Ưu tiên ứng viên Nam, từ 22-30 tuổi)
# ********************* End
# ********************* Start
# Thực Tập Sinh Digital Marketing
# https://www.topcv.vn/viec-lam/thuc-tap-sinh-digital-marketing/1256379.html?ta_source=ITJobs_LinkDetail
# Công ty cổ phần Giải pháp EZ
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Max retries exceeded. Request unsuccessful.
# 429
# ********************* End
# ********************* Start
# Solution Architect
# https://www.topcv.vn/viec-lam/solution-architect/1256407.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH RABILOO
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# Trên 5 năm
# Toàn thời gian
# Không yêu cầu
# Bachelor's Degree in Computing Science or equivalentMinimum 8 years of relevant experience in IT/ Consulting domainMinimum 4 years of working experience in an Architect role including designing, building, and maintaining complex, cloud-based solutionsExperienced in designing and delivering complex web-based applications using Java, GoogleGWT, HTML/Javascript, Angular, Vue.js or other relevant technology stack.Experienced with frameworks such as Spring, Springboot, Hibernate, JPA... Experienced in the following database servers: Oracle, MSSQL, NoSQL.Experience leading a team of engineers to deliver application solutions in a cloud environment.GCP/AWS Solutions Architect certification (Professional level preferred)Knowledge of MVC design, Data modeling, Deployment & Build management, Data migration.Possess working experience in Cloud Native Architecture with Microservices, Docker, Docker Swarm/Kubernetes, container-based orchestration, CI/CD, Domain Driven Design (DDD), API Design Working experience with other public Clouds (AWS or GCP)Demonstrated scripting skills (PowerShell, Python, or Shell)Excellent oral and written communications skills and experience interacting with both business and IT individuals at all levels including the executive level
# ********************* End
# ********************* Start
# Kỹ Sư Hệ Thống (System Engineer)
# https://www.topcv.vn/viec-lam/ky-su-he-thong-system-engineer/1256487.html?ta_source=ITJobs_LinkDetail
# Viettel Software
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Max retries exceeded. Request unsuccessful.
# 429
# ********************* End
# ********************* Start
# Chuyên Viên Đào Tạo & Phát Triển
# https://www.topcv.vn/viec-lam/chuyen-vien-dao-tao-phat-trien/1256688.html?ta_source=ITJobs_LinkDetail
# Viettel Software
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 3 năm
# Toàn thời gian
# Không yêu cầu
# - Có kinh nghiệm từ 3 năm trong lĩnh vực đào tạo và phát triển con người đặc biệt là trong việc thiết kế và triển khai các chương trình năng lực lãnh đạo và quản lý.-Tốt nghiệp Đại học ngành Quản trị nguồn nhân lực, kinh tế, quản trị kinh doanh, kinh tế quốc tế... hoặc các ngành có liên quan.-Tiếng Anh tương đương Toeic 750 - Có kiến thức sâu rộng về các phương pháp đào tạo hiện đại và các xu hướng mới nhất trong lĩnh vực phát triển năng lực lãnh đạo và quản lý.- Thành thạo các bước TNA, thiết kế chương trình, lập kế hoạch, triển khai, đánh giá và cải tiến chương trình đào tạo.- Có khả năng tư duy phân tích, thiết kế chương trình đào tạo, và đánh giá hiệu quả của chương trình.- Có khả năng giải quyết vấn đề phức tạp, giao tiếp và tương tác hiệu quả với các bộ phận khác trong công ty.-Ưu tiên ứng viên có kinh nghiệm làm việc tại các công ty công nghệ.
# ********************* End
# ********************* Start
# Junior Backend Developer
# https://www.topcv.vn/viec-lam/junior-backend-developer/1256249.html?ta_source=ITJobs_LinkDetail
# WebProvise - Creative Commerce Solutions
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Max retries exceeded. Request unsuccessful.
# 429
# ********************* End
# ********************* Start
# Magento Developer
# https://www.topcv.vn/brand/monamedia/tuyen-dung/magento-developer-j954632.html?ta_source=ITJobs_LinkDetail
# Mona Media
# 10 - 35 triệu
# Hồ Chí Minh
# 200
# ********************* Success
# ********************* Fail
# ********************* End
# ********************* Start
# Nhân Viên Code Lua (Mảng Game)
# https://www.topcv.vn/viec-lam/nhan-vien-code-lua-mang-game/1256603.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN THƯƠNG MẠI TRUYỀN THÔNG ALOHA MEDIA
# 7 - 9 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# Dưới 1 năm
# Toàn thời gian
# Không yêu cầu
# Có 03 tháng - 06 tháng kinh nghiệm.Đam mê chơi game và hiểu biết sâu sắc về cơ chế trò chơi dòng game võ lâm.Có kiến thức về C++, Lua.Nhanh nhẹn, chịu khó học hỏi, có trách nhiệm, đảm bảo công việc đúng deadline.
# ********************* End
# ********************* Start
# Flutter Developer
# https://www.topcv.vn/viec-lam/flutter-developer/1256665.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN SYSTEMATIC FUNCTIONS
# Tới 40 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Max retries exceeded. Request unsuccessful.
# 429
# ********************* End
# ********************* Start
# React Native
# https://www.topcv.vn/viec-lam/react-native/1256745.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN CÔNG NGHỆ AIT
# 15 - 35 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# • Tối thiểu 2 năm làm việc thực tế tại các công ty, dự án về lập trình Mobile.• Có kiến thức và kinh nghiệm về lập trình React Native (Bắt buộc), Objective C/Swift hoặc Android java, Kotlin.• Tích hợp SDK Native cho iOS và Android App• Có kinh nghiệm: JavaScript , Restful API, JSON, XML, UNIT TEST.• Có kinh nghiêm làm việc API có dùng JWT• Có kinh nghiệm và hiểu biết về ReactJS là 1 lợi thế.• Có kiến thức và kinh nghiệm sử dụng thành thạo IDE XCode, Android Studio, các công cụ hỗ trợ (Simulator, Instrument).• Có khả năng nắm vững các khái niệm OOP, MVC, MVVM, Layout, API,...• Có các kỹ năng lập trình tốt như: phân tích, đưa giải pháp để giải quyết các vấn đề; • Có kiến thức tốt về OOP, hiểu và áp dụng các nguyên lý SOLID, Design Pattern.· Có kiến thức tốt về cấu trúc dữ liệu và giải thuật.· Khả năng phân tích tình huống và xử lý vấn đề nhanh, kinh nghiệm về UI/UX.
# ********************* End
# ********************* Start
# Automotive Tester (All Level)
# https://www.topcv.vn/viec-lam/automotive-tester-all-level/1256558.html?ta_source=ITJobs_LinkDetail
# INFINIQ Vietnam Co.,ltd
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Max retries exceeded. Request unsuccessful.
# 429
# ********************* End
# ********************* Start
# Nhân Viên Backend Developer
# https://www.topcv.vn/viec-lam/nhan-vien-backend-developer/1256490.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH TRUYỀN THÔNG VÀ DỊCH VỤ DU LỊCH CẢM XÚC VIỆT
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# . Từ 2 năm kinh nghiệm lập trình backend.• Có kiến thức sâu về Golang, Python, NodeJS, Java, C# hoặc các ngôn ngữ BE tươngđương khác.• Có kiến thức về OOP, microservices, Design pattern và thiết kế hệ thống.• Có kinh nghiệm tối ưu hệ thống hoặc tham gia phát triển dự án lớn, số lượng người dùngđáng kể. Biết sử dụng công nghệ Database (SQL, NoSQL), Redis, Message Queue(Kafka, RabbitMQ), các công cụ DevOps (Docker, Docker Compose, K8s)• Có khả năng viết clean & maintainable code, tập trung vào hiệu suất, có thể tái sử dụngvà dễ hiểu với kiểm thử đơn vị (unit test).• Có định hướng rõ ràng, sẵn sàng học hỏi những điều mới và yêu thích sản phẩm• Tư duy logic và giải quyết vấn đề tốt, nắm bắt công nghệ nhanh.
# ********************* End
# ********************* Start
# Nhân Viên UI/UX Designer
# https://www.topcv.vn/viec-lam/nhan-vien-ui-ux-designer/1256479.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH TRUYỀN THÔNG VÀ DỊCH VỤ DU LỊCH CẢM XÚC VIỆT
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# ********************* Fail
# ********************* End
# ********************* Start
# Senior Data Analyst
# https://www.topcv.vn/viec-lam/senior-data-analyst/1055926.html?ta_source=ITJobs_LinkDetail
# Công ty Cổ phần công nghệ Prep
# 25 - 30 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Too many requests. Retrying after waiting...
# Max retries exceeded. Request unsuccessful.
# 429
# ********************* End
# ********************* Start
# Senior Machine Learning Engineer
# https://www.topcv.vn/viec-lam/senior-machine-learning-engineer/1255047.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH EARABLE VIỆT NAM
# 40 - 70 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 3 năm
# Toàn thời gian
# Không yêu cầu
# Bachelor's, Master's degree (Ph.D. preferred) or higher in Computer Science, data science, machine learning, or a related field.At least 3 years of experience in building machine learning models and applying machine learning techniques in the industryStrong programming skills in Python (and/or C/C++) and experience with deep learning frameworks such as TensorFlow, PyTorch, or KerasOptional 1: Strong knowledge of signal processing techniques and/or experience working with EEG brain signalsOptional 2: Experience with natural language processing (c), chatbot and/or recommendation systems,...Strong analytical and problem-solving skills & good communication and collaboration skills
# ********************* End
# ********************* Start
# Lập Trình Viên .Net (Không Cần Kinh Nghiệm)
# https://www.topcv.vn/viec-lam/lap-trinh-vien-net-khong-can-kinh-nghiem/572524.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH Công Nghệ Vĩnh Hy
# 7 - 10 triệu
# Hồ Chí Minh
# Too many requests. Retrying after waiting...
