# %% [markdown]
# Cài đặt BeautifulSoup

# %%
# %pip install beautifulsoup4
# %pip install requests
# Out:
# Collecting requestsNote: you may need to restart the kernel to use updated packages.
#
#   Obtaining dependency information for requests from https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl.metadata
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/57/ec/80c8d48ac8b1741d5b963797b7c0c869335619e13d4744ca2f67fc11c6fc/charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/c2/e7/a82b05cf63a603df6e68d59ae6a68bf5064484a0718ea5033660af4b54a9/idna-3.6-py3-none-any.whl.metadata
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/a2/73/a68704750a7679d0b6d3ad7aa8d4da8e14e151ae82e6fee774e6e0d05ec8/urllib3-2.2.1-py3-none-any.whl.metadata
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/ba/06/a07f096c664aeb9f01624f858c3add0a4e913d6c96257acb4fce61e7de14/certifi-2024.2.2-py3-none-any.whl.metadata
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#    ------ --------------------------------- 10.2/62.6 kB ? eta -:--:--
#    ---------------------------------------- 62.6/62.6 kB 830.7 kB/s eta 0:00:00
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ---------------------------------------- 0.0/163.8 kB ? eta -:--:--
#    --------- ----------------------------- 41.0/163.8 kB 991.0 kB/s eta 0:00:01
#    -------------- ------------------------ 61.4/163.8 kB 825.8 kB/s eta 0:00:01
#    --------------------- ----------------- 92.2/163.8 kB 585.1 kB/s eta 0:00:01
#    -------------------------- ----------- 112.6/163.8 kB 547.6 kB/s eta 0:00:01
#    --------------------------------- ---- 143.4/163.8 kB 568.9 kB/s eta 0:00:01
#    -------------------------------------- 163.8/163.8 kB 614.1 kB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl (99 kB)
#    ---------------------------------------- 0.0/99.9 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/99.9 kB ? eta -:--:--
#    ------------------------ --------------- 61.4/99.9 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 99.9/99.9 kB 1.1 MB/s eta 0:00:00
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.6 kB ? eta -:--:--
#    ---------------------------------------  61.4/61.6 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 61.6/61.6 kB 1.7 MB/s eta 0:00:00
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.1 kB ? eta -:--:--
#    --------- ----------------------------- 30.7/121.1 kB 660.6 kB/s eta 0:00:01
#    -------------------------- ------------ 81.9/121.1 kB 919.0 kB/s eta 0:00:01
#    ---------------------------------------- 121.1/121.1 kB 1.0 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.2.2 charset-normalizer-3.3.2 idna-3.6 requests-2.31.0 urllib3-2.2.1
#   WARNING: The script normalizer.exe is installed in 'c:\Users\Mai Xuan Truong\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Import thư viện

# %%
from bs4 import BeautifulSoup
import requests
import time
import csv

# %% [markdown]
# Đối tượng thể hiện mỗi bài tuyển dụng

# %%
class Job:
    def __init__(self, title, link, company, salary, locations, level, yearOfExperience, contractType, sex, skills):
        self.title = title
        self.link = link
        self.company = company
        self.salary = salary
        self.locations = locations
        self.level = level
        self.yearOfExperience = yearOfExperience
        self.contractType = contractType
        self.sex = sex
        self.skills = skills

# %% [markdown]
# Hàm ghi một đối tượng công việc vào 1 hàng trong file .CSV

# %%
def write_to_csv(job):
    with open('jobs.csv', mode='a', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            # Write header row if file is empty
            if file.tell() == 0:
                writer.writerow(['Title', 'Link', 'Company', 'Salary', 'Locations', 'Level', 'Year of Experience', 'Contract Type', 'Sex', 'Skills'])
            writer.writerow([job.title, job.link, job.company, job.salary, job.locations, job.level, job.yearOfExperience, job.contractType, job.sex, job.skills])

# %% [markdown]
# Hàm lấy thông tin chi tiết của mỗi bài tuyển dụng

# %%
def get_jobs(item):
    print('********************* Start')
    try:
        title = item.find(class_='title').text.strip()
        print(title)
        link = item.find(class_='title').find('a')['href'].strip()
        print(link)
        company = item.find(class_='company').text.strip()
        print(company)
        salary = item.find(class_='title-salary').text.strip()
        print(salary)
        locations = item.find(class_='address').text.strip()
        print(locations)
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
        }

        # Số lần thử lại tối đa
        max_retries = 5
        retry_delay = 6  # Thời gian chờ giữa các lần thử lại, đơn vị là giây

        retry_count = 0
        while retry_count < max_retries:
            response2 = requests.get(link, headers=headers)
            if response2.status_code == 429:  # Nếu nhận được mã trạng thái 429
                print("Too many requests. Retrying after waiting...")
                retry_count += 1
                time.sleep(retry_delay)  # Chờ trước khi thử lại
            else:
                # Xử lý kết quả ở đây nếu cần
                # Ví dụ: print(response.text)
                break
        else:
            print("Max retries exceeded. Request unsuccessful.")
        print(response2.status_code)
        if response2.status_code == 200:
            print('********************* Success')
            soup2 = BeautifulSoup(response2.text, 'html.parser')
            if link.startswith("https://www.topcv.vn/brand/"):
                infos = soup2.find_all(class_='box-info')
                generals = infos[0].find_all('span')
                level = generals[3].text.strip()
                print(level)
                yearOfExperience = generals[5].text.strip()
                print(yearOfExperience)
                contractType = generals[2].text.strip()
                print(contractType)
                sex = generals[4].text.strip()
                print(sex)
                skills = infos[2].find(class_='content-tab').text.strip()
                print(skills)
            else:
                generals = soup2.find(class_='job-detail__box--right job-detail__body-right--item job-detail__body-right--box-general').find_all(class_='box-general-group-info-value')
                level = generals[0].text.strip()
                print(level)
                yearOfExperience = generals[1].text.strip()
                print(yearOfExperience)
                contractType = generals[3].text.strip()
                print(contractType)
                sex = generals[4].text.strip()
                print(sex)
                skills = soup2.find_all(class_='job-description__item--content')[1].text.strip()
                print(skills)
        else:
            level = None
            yearOfExperience = None
            contractType = None
            sex = None
            skills = None
        job = Job(title, link, company, salary, locations, level, yearOfExperience, contractType, sex, skills)
        # Writing to CSV file
        write_to_csv(job)
    except:
        print('********************* Fail')
    print('********************* End')

# %% [markdown]
# Hiện tại khuyến khích crawl mỗi lần 1 trang sau 1 khoảng thời gian rồi crawl tiếp trang khác để tránh lỗi 429

# %% [markdown]
# Crawl 1 trang

# %%
url = 'https://www.topcv.vn/viec-lam-it'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}
response = requests.get(url, headers=headers)
if response.status_code == 200:
    # Sử dụng BeautifulSoup để phân tích HTML
    soup = BeautifulSoup(response.text, 'html.parser')
    jobs = soup.find_all(class_='job-item-2')
    for job in jobs:
        get_jobs(job)   
        time.sleep(5)
else:
    print('Yêu cầu không thành công. Mã trạng thái:', response.status_code)

# %% [markdown]
# Crawl toàn bộ trang

# %%
url = 'https://www.topcv.vn/viec-lam-it'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}
response = requests.get(url, headers=headers)
if response.status_code == 200:
    # Sử dụng BeautifulSoup để phân tích HTML
    soup = BeautifulSoup(response.text, 'html.parser')
    # num_pages = int(soup.find(class_='pagination').find_all('li')[-2].text)
    num_pages = 20
    print(num_pages)
    jobs = soup.find_all(class_='job-item-2')
    for job in jobs:
        get_jobs(job)
        time.sleep(5)
    for i in range(2, num_pages + 1):
        url = 'https://www.topcv.vn/viec-lam-it?page=' + str(i)
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            jobs = soup.find_all(class_='job-item-2')
            for job in jobs:
                get_jobs(job)
                time.sleep(5)
        else:
            print('Yêu cầu không thành công. Mã trạng thái:', response.status_code)   
        time.sleep(10)           
else:
    print('Yêu cầu không thành công. Mã trạng thái:', response.status_code)
# Out:
# 20
# ********************* Start
# Nhân Viên Xử Lý Dữ Liệu Tiếng Nhật (Tiếng Nhật N3)
# https://www.topcv.vn/viec-lam/nhan-vien-xu-ly-du-lieu-tieng-nhat-tieng-nhat-n3/1286664.html?ta_source=ITJobs_LinkDetail
# CHI NHÁNH CÔNG TY TNHH PASONA TECH VIỆT NAM TẠI HÀ NỘI
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# - Tốt nghiệp đại học, cao đẳng.
# - Tiếng Nhật tương đương N3.
# - Thành thạo tin học văn phòng, đặc biệt là Excel, Word.
# - Có khả năng giao tiếp tốt, nhanh nhẹn, chăm chỉ và ham học hỏi.
# - Yêu thích làm việc trong môi trường công ty Nhật Bản.
# ********************* End
# ********************* Start
# Java Core Backend Developer -Lương Từ 16 - 25 Triệu
# https://www.topcv.vn/brand/congnghiepvienthongquandoi/tuyen-dung/java-core-backend-developer-luong-tu-16-25-trieu-j1289408.html?ta_source=ITJobs_LinkDetail
# TẬP ĐOÀN CÔNG NGHIỆP - VIỄN THÔNG QUÂN ĐỘI
# 16 - 25 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# 1. Trình độ: Tốt nghiệp đại học loại khá trở lên các ngành Công nghệ thông tin, Kỹ thuật phần mềm hoặc các ngành liên quan2. Trình độ tiếng Anh: chứng chỉ TOEIC, TOEFL hoặc IELTS tương đương với điểm TOEIC – 550 điểm trở lên.3. Kinh nghiệm: Có trên 1 năm kinh nghiệm về thiết kế, phát triển và triển khai hệ thống phần mềm sử dụng ngôn ngữ lập trình Java core4. Kỹ năng- Có khả năng phát triển 1 ứng dụng hoàn chỉnh bằng ngôn ngữ lập trình Java core, framework spring boot- Có khả năng tối ưu hiệu năng dựa trên hiểu biết sâu về ngôn ngữ lập trình Java- Có kiến thức chuyên sâu về phân tích thiết kế hệ thống, thành thạo các công cụ thiết kế như UML, ER studio,...- Có kiến thức về Database design & query, query tuning. Sử dụng được các loại DB: redis, elasticsearch, mongo, mariadb- Có kiến thức về cơ chế xác thực, mã hóa dữ liệu, cơ chế xử lý tuần tự, song song, đa luồng, đa tiến trình- Có khả năng triển khai trên các nền tảng khác nhau: Linux, Windows, K8S/Docker- Có hiểu biết và áp dụng thành thục quy trình phát triển phần mềm bằng phương pháp Agile; phương pháp phát triển và tích hợp liên tục (CI/CD).
# ********************* End
# ********************* Start
# QC Tester/Manual Tester Tiếng Anh Cơ Bản - Lương Upto 45M, Tại Phú Nhuận
# https://www.topcv.vn/viec-lam/qc-tester-manual-tester-tieng-anh-co-ban-luong-upto-45m-tai-phu-nhuan/1287905.html?ta_source=ITJobs_LinkDetail
# Công Ty TNHH Mediastep Software Việt Nam
# 30 - 43 triệu
# Hồ Chí Minh
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Good at English.At least 2 years hands-on experience as a manual QC. Solid knowledge of functional, integration and regression testing. Knowledge of API, performance and security testing is a plus.Dynamic, proactive and high team spirit in a dynamic environment with international colleagues and in a continuous integration/delivery process.Willing to learn, ready to ask team members and clients proactively about issues or problems.Have in-depth understanding of the project and life cycle of testing, phase testing objectives, acceptance criteria and risk-based approaches to testing.Ability to manage and prioritize multiple, diverse features simultaneously.Carefulness, Strong logical thinking and analytical skills.Good at Time management.
# ********************* End
# ********************* Start
# Automotive Android App Developer
# https://www.topcv.vn/brand/boschglobalsoftwaretechnologies/tuyen-dung/automotive-android-app-developer-j1278575.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH BOSCH GLOBAL SOFTWARE TECHNOLOGIES
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# ********************* Fail
# ********************* End
# ********************* Start
# Trưởng Phòng Kỹ Thuật Giải Pháp Lương + Thưởng Thu Nhập Hấp Dẫn
# https://www.topcv.vn/viec-lam/truong-phong-ky-thuat-giai-phap-luong-thuong-thu-nhap-hap-dan/1266181.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH CÔNG NGHỆ VÀ GIẢI PHÁP THÔNG MINH
# 15 - 30 triệu
# Hà Nội
# 200
# ********************* Success
# Trưởng/Phó phòng
# 2 năm
# Toàn thời gian
# Không yêu cầu
# - Nam Tốt nghiệp Đại học chuyên ngành CNTT.
# - Có từ 2 năm kinh nghiệm trở lên với công việc tương đương.
# - Tuổi từ 24 đến 36, có thể đi công tác nếu có yêu cầu.
# - Sử dụng thành thạo AutoCAD, Internet, tin học văn phòng ...- Có khả năng thuyết trình, huấn luyện công việc tốt.
# ********************* End
# ********************* Start
# Tester Leader/Trưởng Nhóm Kiểm Thử - Lương Up To 25M
# https://www.topcv.vn/viec-lam/tester-leader-truong-nhom-kiem-thu-luong-up-to-25m/1283961.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH FIVE-STAR E-LEARNING
# 20 - 25 triệu
# Hà Nội
# 200
# ********************* Success
# Trưởng nhóm
# 3 năm
# Toàn thời gian
# Không yêu cầu
# Có ít nhất 3 năm kinh nghiệm Test phần mềm các dự ánCó kinh nghiệm ít nhất 1 năm kinh nghiệm Test leaderTốt nghiệp ĐH chuyên ngành CNTT, toán tin ứng dụng, phần mềm, ...Thành thạo kiến thức, kỹ thuật, kỹ năng Test : Hiểu biết về các Test process, Test Level, Test Types và các kỹ thuật kiểm thử phần mềmCó khả năng đọc hiểu, phân tích tốtCó khả năng giao tiếp tốtCó khả năng dẫn dắt, tạo động lực cho member;Có khả năng thích ứng nhanh, liên tục cải tiến.
# ********************* End
# ********************* Start
# Lập Trình Viên Web Full Stack
# https://www.topcv.vn/viec-lam/lap-trinh-vien-web-full-stack/1198591.html?ta_source=ITJobs_LinkDetail
# Công ty Cổ Phần Symper Việt Nam
# 25 - 35 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 3 năm
# Toàn thời gian
# Không yêu cầu
# - Có kiến thức tốt về OOP, Clean architecture, ưu tiên có hiểu biết về các design patterns- Có trên 1 năm kinh nghiệm Golang hoặc PHP- Có trên 1 năm kinh nghiệm với lập trình front-end, thành thạo HTML, CSS, Javascript hoặc Typescript. Đã sử dụng một trong các Framework Vuejs, Angular, React- Có kinh nghiệm trong việc phân tích, thiết kế, tối ưu code- Có kinh nghiệm trong việc phân tích, thiết kế, tối ưu hệ thống- Có kinh nghiệm trong việc phân tích, thiết kế, tối ưu DB- Ứng viên có kinh nghiệm quản lý nhóm, đào tạo các thành viên khác trong nhóm là 1 lợi thế- Ưu tiên ứng viên có kinh nghiệm triển khai hoặc sử dụng Scrum trong quá trình làm việc- Ưu tiên ứng viên có kinh nghiệm làm việc trong công ty product với các techstack phức tạp (outsource ít ưu tiên hơn)
# ********************* End
# ********************* Start
# Nhân Viên SEO Website
# https://www.topcv.vn/viec-lam/nhan-vien-seo-website/949616.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH ĐẦU TƯ VÀ PHÁT TRIỂN CATI VIỆT NAM
# 9 - 15 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Sử dụng thành thạo các công cụ phân tích dữ liệu của Google/SEO.Ưu tiên tốt nghiệp các ngành học liên quan đến Marketing, công nghệ thông tin, truyền thông.Ưu tiên ứng viên đã hoàn thành khóa học về SEO và có kinh nghiệm SEO trên 2 năm.
# ********************* End
# ********************* Start
# Software Developer (C/C++)
# https://www.topcv.vn/viec-lam/software-developer-c-c/1282162.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH Shinhan DS Việt Nam
# Thoả thuận
# Hồ Chí Minh
# 200
# ********************* Success
# Nhân viên
# 3 năm
# Toàn thời gian
# Không yêu cầu
# From 3 years of experience in Software Development/Embedded DevelopmentProficiency in C/C++ based on Unix, Linux.Familiar with SQL/Oracle.Good to have: Pro C and Finance & Banking field.Good problem-solving & communication skills.Detail-oriented, proactive, and fast learner.Can communicate in English.
# ********************* End
# ********************* Start
# Technology Young Talent – Khối Công Nghệ Thông Tin
# https://www.topcv.vn/viec-lam/technology-young-talent-khoi-cong-nghe-thong-tin/1289492.html?ta_source=ITJobs_LinkDetail
# Ngân Hàng TMCP Việt Nam Thịnh Vượng (VPBank)
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# Sinh viên năm cuối, mới tốt nghiệp Đại học hoặc dưới 2 năm kinh nghiệm làm việc. Tốt nghiệp loại Giỏi trở lên từ các trường ĐH trong và ngoài nước (ưu tiên các trường ĐH top đầu) với chuyên ngành Toán tin/Toán ứng dụng/Tin học/CNTT/Khoa học máy tính/Dữ liệu/Điện tử viễn thông/Ngân hàng/Kinh tế Quốc dân/Ngoại thương. Tham gia Chương trình VPBank Hackathon 2024 (Ưu tiên các thành viên có thành tích cao từ cuộc thi)Vượt qua bài test nghiệp vụ đầu vào dành cho đối tượng Young Talents.Ưu tiên các ứng viên có thành tích cao trong các kỳ thi học thuật trong nước và Quốc tế hoặc Đạt các Chứng chỉ nghề nghiệp chuyên môn đặc thù về nghiệp vụ CNTT (CCNP, CCIE, Juniper, CheckPoint, F5, Fortigate, Citrix, ITL, ITSM, TOGAF, CISSP, CISM, PMP) hoặc ngôn ngữ phát triển CNTT cập nhật (Node.js, Python, Go, Java, pattern design, TCP/IP, Database,AI, ML), kỹ năng/Công nghệ thuộc xu thế (Network, WAN, SDWAN, LAN, ATM/CDM, DC/CR SQL, Oracle, Database, Cloud, Azure, GCP: EC2,EKS, ECS, RDS, Container, D/DNS, O365/Microsoft Exchange, PowerBI, VBA powershell, web/app java, devops, Embedding, Vector Store, LLM model, finetune, pretrain model như GPT, Bard, Vietnamese model... huggingface). Kỹ năng giao tiếp tốt, tư duy logic tốt, có khả năng học hỏi nhanh, sáng tạo, có thói quen nghiên cứu tài liệu, cập nhật thông tin và xu thế công nghệ thường xuyên.Có khả năng sử dụng tiếng Anh (nghe, nói, đọc, viết) thành thạo hoặc IELTS từ 6.5.Trong trường hợp trúng tuyển, sau thời gian hoàn thành đào tạo cần cam kết thời gian công tác tối thiểu 2 năm tại Ngân hàng theo lộ trình phát triển.
# ********************* End
# ********************* Start
# Họa Viên Kiến Trúc/Kết Cấu Không Yêu Cầu Kinh Nghiệm (Fresher)
# https://www.topcv.vn/viec-lam/hoa-vien-kien-truc-ket-cau-khong-yeu-cau-kinh-nghiem-fresher/1287148.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH MITEK VIỆT NAM
# 7 - 10 triệu
# Hồ Chí Minh
# 200
# ********************* Success
# Thực tập sinh
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# • Bạn đã tốt nghiệp từ các ngành kỹ thuật như Môi trường, Cơ khí, Địa chất, Công nghệ sinh học, Điện điện tử, Hóa học, Khối ngành Xây dựng, Kiến Trúc, vv ...
# • Chúng tôi chào đón các ứng viên chưa có kinh nghiệm làm việc.
# • Có kiến thức cơ bản về phần mềm thiết kế (Auto CAD) là một điểm cộng
# • Hiểu biết về tính dự toán và bốc tách khối lượng, hình tượng 3D – vẽ được các hình chiếu bằng, đứng, cạnh.
# • Khả năng đọc hiểu bản vẽ xây dựng.
# • Có khả năng giao tiếp và sử dụng Tiếng Anh trong môi trường làm việc.
# • Có tinh thần trách nhiệm trong công việc.
# • Khả năng làm việc nhóm
# ********************* End
# ********************* Start
# Back Office Manager (Trưởng Phòng Hành Chính Nhân Sự) Tại Hồ Chí Minh
# https://www.topcv.vn/viec-lam/back-office-manager-truong-phong-hanh-chinh-nhan-su-tai-ho-chi-minh/1287603.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN CÔNG NGHỆ NAMI
# Thoả thuận
# Hồ Chí Minh
# 200
# ********************* Success
# Trưởng/Phó phòng
# 3 năm
# Toàn thời gian
# Không yêu cầu
# - Bachelor's degree in Business Administration, Accounting, Finance, or a related field.
# - 3+ years of progressive experience in operations management, with demonstrable experience in finance and HR.
# - Literacy in basic finance documents
# - Strong analytical, problem-solving, and decision-making abilities.
# - Excellent communication and interpersonal skills, with the ability to build positive relationships across teams.
# - Demonstrated ability to lead and motivate teams.- Experience in the technology industry
# - Familiarity with AI concepts and applications
# ********************* End
# ********************* Start
# ReactJS SmartTV Developer - Lương Từ 16 -25 Triệu
# https://www.topcv.vn/brand/congnghiepvienthongquandoi/tuyen-dung/reactjs-smarttv-developer-luong-tu-16-25-trieu-j1289444.html?ta_source=ITJobs_LinkDetail
# TẬP ĐOÀN CÔNG NGHIỆP - VIỄN THÔNG QUÂN ĐỘI
# 16 - 25 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# 1. Trình độ: Tốt nghiệp đại học loại khá trở lên các ngành Công nghệ thông tin, Kỹ thuật phần mềm hoặc các ngành liên quan2. Trình độ tiếng Anh: chứng chỉ TOEIC, TOEFL hoặc IELTS tương đương với điểm TOEIC – 550 điểm trở lên.3. Kinh nghiệm: Có trên 1 năm kinh nghiệm về thiết kế, phát triển và triển khai ứng dụng phần mềm trên nền tảng Tizen/WebOS4. Kỹ năng- Có khả năng phát triển 1 ứng dụng hoàn chỉnh trên nền tảng smartTV Tizen/WebOS bằng ngôn ngữ lập trình ReactJS- Có khả năng tối ưu hiệu năng dựa trên hiểu biết sâu về ngôn ngữ lập trình ReactJS cho các dòng smartTV Tizen/WebOS- Có kiến thức về cơ chế xác thực, mã hóa dữ liệu, cơ chế xử lý tuần tự, song song, đa luồng, đa tiến trình- Có kiến thức về UI/UX của ứng dụng trên nền tảng smartTV Tizen/WebOS- Có khả năng triển khai ứng dụng lên môi trường test và môi trường public qua kho ứng dụng tương ứng.- Có hiểu biết và áp dụng thành thục quy trình phát triển phần mềm bằng phương pháp Agile"
# ********************* End
# ********************* Start
# Nhân Viên Thiết Kế Đồ Họa / Graphic Design (Lương 9 - 15 Triệu, Thủ Đức)
# https://www.topcv.vn/viec-lam/nhan-vien-thiet-ke-do-hoa-graphic-design-luong-9-15-trieu-thu-duc/1290153.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH May Mặc GFC
# 9 - 15 triệu
# Hồ Chí Minh
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# - Tốt nghiệp cao đẳng trở lên.
# - Có ít nhất 2 năm kinh nghiệm làm designer, đã từng làm việc với các nhãn hàng thời trang là 1 lợi thế.
#  - Sử dụng thành thạo các phần mềm như: Photoshop, Illustrator là điều bắt buộc.
# - Có khả năng tư duy sáng tạo, phân tích nội dung thiết kế, tạo mẫu thiết kế, lên mẫu, phát triển ý tưởng thiết kế.
# - Có kinh nghiệm thiết kế in ấn - quảng cáo.
# - Ưu tiên ứng viên biết thêm các công việc như: Marketing, viết content, SEO web, quản trị fanpage và website.
# - Kỹ năng chụp hình, quay video tốt là một lợi thế.
# 3. QUYỀN LỢI ĐƯỢC HƯỞNG
# ********************* End
# ********************* Start
# Tester Nữ (Có Kinh Nghiệm) - Tại Hà Nội
# https://www.topcv.vn/viec-lam/tester-nu-co-kinh-nghiem-tai-ha-noi/1261111.html?ta_source=ITJobs_LinkDetail
# MochiMochi
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Nữ
# Đã có tối thiểu 1 năm kinh nghiệm trong các công việc tương tự Kỹ năng đọc hiểu tiếng Anh cơ bảnCởi mở và sẵn sàng học hỏiGửi kèm manual/automation testcase về UI/UX/Api/DB đã từng thực hiện trong CV ứng tuyển
# ********************* End
# ********************* Start
# Java Android Developer - Lương Từ 16 - 25 Triệu
# https://www.topcv.vn/brand/congnghiepvienthongquandoi/tuyen-dung/java-android-developer-luong-tu-16-25-trieu-j1289420.html?ta_source=ITJobs_LinkDetail
# TẬP ĐOÀN CÔNG NGHIỆP - VIỄN THÔNG QUÂN ĐỘI
# 16 - 25 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# 1. Trình độ: Tốt nghiệp đại học loại khá trở lên các ngành Công nghệ thông tin, Kỹ thuật phần mềm hoặc các ngành liên quan2. Trình độ tiếng Anh: chứng chỉ TOEIC, TOEFL hoặc IELTS tương đương với điểm TOEIC – 550 điểm trở lên.3. Kinh nghiệm: Có trên 1 năm kinh nghiệm về thiết kế, phát triển và triển khai ứng dụng phần mềm trên nền tảng Android4. Kỹ năng- Có khả năng phát triển 1 ứng dụng hoàn chỉnh trên nền tảng Android bằng ngôn ngữ lập trình Java- Có khả năng tối ưu hiệu năng dựa trên hiểu biết sâu về ngôn ngữ lập trình- Có kiến thức về cơ chế xác thực, mã hóa dữ liệu, cơ chế xử lý tuần tự, song song, đa luồng, đa tiến trình- Có hiểu biết về UI/UX của ứng dụng trên nền tảng android (mobile và smartTV)- Có khả năng triển khai ứng dụng lên kho ứng dụng Playstore, triển khai được theo môi trường test, enterprise, public.- Có hiểu biết về tối ưu kết quả tìm kiếm ứng dụng trên kho ứng dụng của Google (ASO)- Có hiểu biết và áp dụng thành thục quy trình phát triển phần mềm bằng phương pháp Agile"
# ********************* End
# ********************* Start
# Back-End Developer (Node.JS/ JavaScript)
# https://www.topcv.vn/viec-lam/back-end-developer-node-js-javascript/1286570.html?ta_source=ITJobs_LinkDetail
# EM&AI
# Trên 30 triệu
# Đà Nẵng
# 200
# ********************* Success
# Nhân viên
# 3 năm
# Toàn thời gian
# Không yêu cầu
# - 5+ years of programming experience;
# - 3+ years of JavaScript and Node.js experience;
# - Experience with REST, WebSocket, MySQL/PostgreSQL, MongoDB, Redis;
# - Experience with Docker and AWS Infrastructure;
# - Understanding of asynchronous development and data security principles;
# - Ability to write readable, well-documented code;
# - Self-motivation, goal-oriented approach.
# ********************* End
# ********************* Start
# Nhân Viên Xử Lý Dữ Liệu Hình Ảnh Tại Hà Nội (6 - 8 Triệu) Không Yêu Cầu Kinh Nghiệm
# https://www.topcv.vn/viec-lam/nhan-vien-xu-ly-du-lieu-hinh-anh-tai-ha-noi-6-8-trieu-khong-yeu-cau-kinh-nghiem/1283047.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH LTS Global Digital Services
# 6 - 8 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# Tốt nghiệp các trường đại học/cao đẳng
# Kiên trì và cẩn thận
# Ưu tiên có kinh nghiệm về xử lý dữ liệu hình ảnh
# Độ tuổi: 18 - 25
# ********************* End
# ********************* Start
# Code Game Roblox
# https://www.topcv.vn/viec-lam/code-game-roblox/1289855.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN YOTEL - YO NETWORK
# Thoả thuận
# Hồ Chí Minh
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# – Thành thạo Roblox Studio và thông thạo ngôn ngữ lập trình liên quan (Lua).
# – Có kinh nghiệm xây map, animation bằng Roblox Studio.
# – Có sự sáng tạo, góc nhìn trong Roblox.
# – Am hiểu các khung hình trong game Roblox để tạo ra video như kênh Lututu.
# ********************* End
# ********************* Start
# Kỹ Sư An Ninh Mạng Lương Từ 40 Triệu / Tháng
# https://www.topcv.vn/viec-lam/ky-su-an-ninh-mang-luong-tu-40-trieu-thang/1026763.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH sản xuất và thương mại Ninh Thanh
# Trên 40 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Nam
# - Kinh nghiệm hơn 2 năm về an toàn thông tin, kiểm thử bảo mật, tìm kiếm lỗ hổng.- Có một trong các chứng chỉ bảo mật sau sẽ là một lợi thế: OSCP, OSWE, CEH, AWS- Có kiến thức, kinh nhiệm penetration test ứng dụng web, mobile, desktop app- Có khả năng đọc hiểu các ngôn ngữ lập trình: Java, .Net, Node js- Hiểu về kiến trúc ứng dụng, hệ thống.- Hiểu, nắm rõ các tiêu chuẩn ANTT ứng dụng, tiêu chuẩn ANTT cho lĩnh vực Ngân hàng, tài chính.- Hiểu về các giải pháp ANTT ứng dụng như web application firewall, API security
# ********************* End
# ********************* Start
# Swift IOS Developer- Lương Từ 16 - 25 Triệu
# https://www.topcv.vn/brand/congnghiepvienthongquandoi/tuyen-dung/swift-ios-developer-luong-tu-16-25-trieu-j1289438.html?ta_source=ITJobs_LinkDetail
# TẬP ĐOÀN CÔNG NGHIỆP - VIỄN THÔNG QUÂN ĐỘI
# 16 - 25 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# 1. Trình độ: Tốt nghiệp đại học loại khá trở lên các ngành Công nghệ thông tin, Kỹ thuật phần mềm hoặc các ngành liên quan2. Trình độ tiếng Anh: chứng chỉ TOEIC, TOEFL hoặc IELTS tương đương với điểm TOEIC – 550 điểm trở lên.3. Kinh nghiệm: Có trên 1 năm kinh nghiệm về thiết kế, phát triển và triển khai ứng dụng phần mềm trên nền tảng iOS4. Kỹ năng- Có khả năng phát triển 1 ứng dụng hoàn chỉnh trên nền tảng iOS bằng ngôn ngữ lập trình Swift- Có khả năng tối ưu hiệu năng dựa trên hiểu biết sâu về ngôn ngữ lập trình- Có kiến thức về cơ chế xác thực, mã hóa dữ liệu, cơ chế xử lý tuần tự, song song, đa luồng, đa tiến trình- Có kiến thức về UI/UX của ứng dụng trên nền tảng mobile iOS và AppleTV- Có khả năng triển khai ứng dụng lên các môi trường testflight, enterprise, public. Có hiểu biết về tối ưu kết quả tìm kiếm ứng dụng trên appstore (ASO)- Có hiểu biết và áp dụng thành thục quy trình phát triển phần mềm bằng phương pháp Agile
# ********************* End
# ********************* Start
# IT Comtor Tiếng Nhật Thu Nhập Lên Đến 35Triệu/Tháng
# https://www.topcv.vn/viec-lam/it-comtor-tieng-nhat-thu-nhap-len-den-35trieu-thang/1283457.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH BTC STUDIO
# 15 - 35 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Tiếng Nhật N2 giao tiếp tốt - Có tiếng Nhật IT là 1 lợi thếCó ít nhất từ 1 năm kinh nghiệm làm IT Comtor - Ưu tiên ứng viên có nền tảng về ITKhả năng phân tích yêu cầu và nhận biết vấn đề nhanhKhả năng giao tiếp tốtCó ý thức trách nhiệm cao, có tinh thần làm việc teamworkCó kinh nghiệm quản lý dự án hoặc hỗ trợ quản lý dự ánKhả năng chịu được áp lực cao trong công việc.Có kiến thức IT mức độ cơ bản (hiểu hệ thống, phần mềm, phát triển app...)Ưu tiên kinh nghiệm tham gia và follow dự án từ lúc start đến khi kết thúc (chuyển giao)Nếu có là lợi thế:Kỹ năng quản lý tốt.Ứng viên có kinh nghiệm học tập, làm việc tại Nhật Bản.
# ********************* End
# ********************* Start
# Nhân Viên Video Editor - Level Fresher (Lương Từ 7-10 Triệu Đồng + Phụ Cấp)
# https://www.topcv.vn/viec-lam/nhan-vien-video-editor-level-fresher-luong-tu-7-10-trieu-dong-phu-cap/1285289.html?ta_source=ITJobs_LinkDetail
# Công ty cổ phần công nghệ Suga
# 7 - 10 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# Dưới 1 năm
# Toàn thời gian
# Không yêu cầu
# - Có tối thiểu 6 tháng kinh nghiệm tại vị trí Video Editor. - Sử dụng thành thạo một trong các phần mềm dựng phim: Premiere; After Effect; Photoshop... Biết làm Animation là 1 lợi thế. - Có khả năng làm các video motion 2D cơ bản. Đính kèm sản phẩm đã edit (gửi cùng CV).- Tư duy bố cục, màu sắc trong thiết kế.- Khả năng sáng tạo, bắt trend, ứng dụng AI trong công việc.- Thái độ làm việc tích cực, năng động, kỷ luật, cầu tiến.- Ưu tiên sinh viên tốt nghiệp các trường dạy chuyên sâu đồ họa: Mỹ thuật công nghiệp, Đại học FPT, Arena Multimedia, FPT Arena, Monster Lab...
# ********************* End
# ********************* Start
# AI Engineer
# https://www.topcv.vn/viec-lam/ai-engineer/1289345.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH THƯ VIỆN PHÁP LUẬT
# Thoả thuận
# Hồ Chí Minh
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# 1 - Có ít nhất 1 năm kinh nghiệm trong lĩnh vực AI/ML.
# 2 - Tốt nghiệp Đại học các ngành có liên quan như Khoa học máy tính, Công nghệ thông tin, ưu tiên học chuyên về AI
# 3 - Có kinh nghiệm về MachineLearning, NPL, LLM, DeepLearning.
# 4 - Có kinh nghiệm với các mô hình AI sinh dữ liệu như GPT.
# 5 - Khả năng đọc hiểu tài liệu chuyên ngành, ứng dụng công nghệ mới để nâng cao hiệu quả công việc.
# 6 - Khả năng nghiên cứu và ứng dụng các nguồn mở AI.
# 7 - Đọc và hiểu tài liệu tiếng Anh chuyên ngành.
# 8 - Độ tuổi: 1995 - 2002
# ********************* End
# ********************* Start
# Data Talent – Khối Quản Trị Và Phân Tích Dữ Liệu
# https://www.topcv.vn/viec-lam/data-talent-khoi-quan-tri-va-phan-tich-du-lieu/1287882.html?ta_source=ITJobs_LinkDetail
# Ngân Hàng TMCP Việt Nam Thịnh Vượng (VPBank)
# Thoả thuận
# Hà Nội, Miền Bắc
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Tốt nghiệp Đại học hoặc cao hơn liên quan đến 1 trong các chuyên nghành toán, thống kê, kinh tế, ngân hàng, tài chính, khoa học máy tính, kỹ thuật phần mềmTối thiểu 2-3 năm kinh nghiệm làm việc trong lĩnh vực dữ liên quan đến 1 trong các chuyên môn phân tích dữ liệu, mô hình học máy, quản trị dữ liệu, quản lý dữ liệu, kiến trúc dữ liệu, vận hành nền tảng dữ liệu,....Ưu tiên Có kiến thức về dữ liệu, nghiệp vụ tài chính ngân hàngThành thạo SQL, Excel và ngôn ngữ phân tích dữ liệu R hoặc PythonƯu tiên ứng viên có kinh nghiệm với AWS cloudSẵn lòng học hỏi và tham gia vào các dự án công nghệ của VPBank...
# ********************* End
# ********************* Start
# Nhân Viên Kỹ Thuật Tại Hà Nội Không Yêu Cầu Kinh Nghiệm Thu Nhập Lên Đến 10 Triệu
# https://www.topcv.vn/viec-lam/nhan-vien-ky-thuat-tai-ha-noi-khong-yeu-cau-kinh-nghiem-thu-nhap-len-den-10-trieu/1245464.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN THƯƠNG MẠI VÀ GIẢI PHÁP KỸ THUẬT TRƯỜNG PHÁT
# 7 - 10 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Nam
# - Nam
# - Tốt nghiệp cao đẳng, đại học chuyên ngành điện/cơ khí
# - Biết vẽ và đọc bản vẽ Autocad (Có thể học trong quá trình thử việc)
# - Biết tiếng Anh là 1 lợi thế.
# - Không yêu cầu kinh nghiệm, sẽ được đào tạo.
# ********************* End
# ********************* Start
# Senior Business Analyst (Có Kinh Nghiệm Banking - Finance)
# https://www.topcv.vn/viec-lam/senior-business-analyst-co-kinh-nghiem-banking-finance/1288303.html?ta_source=ITJobs_LinkDetail
# Công ty CP Kinh doanh F88
# 20 - 40 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 3 năm
# Toàn thời gian
# Không yêu cầu
# Học vấn: Tốt nghiệp Đại học ngành CNTT, Hệ thống thông tin hoặc các chuyên ngành có liên quanCó tối thiểu 03 năm kinh nghiệm về BA tại các Ngân hàng/Công ty tài chính, đặc biệt có kinh nghiệm tham gia triển khai dự án sản phẩm lending cho Ngân hàng/Công ty tài chính (Điều kiện bắt buộc). Ưu tiên có kinh nghiệm tham gia các dự án về Tổng đài (POL), Vay (LOS)...Am hiểu về lĩnh vực tài chính/ngân hàng, am hiểu về lĩnh vực ngành/nghề đang cung cấpĐề cao trách nhiệm trong công việc, ý thức chất lượng sản phẩm tốt; đam mê tìm tòi nghiên cứu học hỏi công nghệ mới, phát triển bản thânƯu tiên ứng viên có thể đọc hiểu tài liệu tiếng AnhHiểu biết và mong muốn làm việc trong một môi trường phát triển Agile, chuyên nghiệp
# ********************* End
# ********************* Start
# Nhân Viên IT Phần Mềm Tại Bắc Ninh
# https://www.topcv.vn/viec-lam/nhan-vien-it-phan-mem-tai-bac-ninh/877681.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH MPT Solution (Việt Nam)
# Thoả thuận
# Bắc Ninh
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# 1). Tốt nghiệp Cao đẳng trở lên các chuyên ngành công nghệ thông tin, công nghệ phần mềm.
# 2). Thành thạo các ngôn ngữ lập trình : C#, Java , Javascript , Dotnet...
# 3). Có hiểu biết về SQLSERVER、MYSQL, Oracle. Hiểu biết Oracle là một lợi thế
# 4) Tiếng Trung thành thạo
# ********************* End
# ********************* Start
# Nhân Viên SEO Youtube (Lương + Phụ Cấp + Thưởng Theo Doanh Thu Kênh Upto 100 Triệu)
# https://www.topcv.vn/viec-lam/nhan-vien-seo-youtube-luong-phu-cap-thuong-theo-doanh-thu-kenh-upto-100-trieu/1273024.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH CÔNG NGHỆ VÀ TRUYỀN THÔNG IGC VIỆT NAM
# 6 - 9 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# - Nam / Nữ tốt nghiệp CĐ/ ĐH chuyên ngành liên quan: Marketing, Đồ họa,...
# - Biết sử dụng cơ bản các phần mềm chỉnh sửa ảnh, edit video như Adobe Photoshop, Premiere, After Effect (Chấp nhận đào tạo thêm)
# - Hiểu biết cơ bản về SEO từ khóa (Chấp nhận đào tạo thêm)
# - Ưu tiên độ tuổi 1996 - 2001
# - Yêu thích âm nhạc
# - Có tư duy hình ảnh, bố cục và thẩm mỹ tốt, khả năng tự tìm tòi nghiên cứu.
# - Làm việc nhanh nhẹn, chủ động trong công việc.
# - Kiên trì, chăm chỉ, tự giác có trách nhiệm với công việc
# - Có khả năng chịu áp lực cao, kỹ năng giải quyết vấn đề.
# - Gửi các sản phẩm đã làm kèm với CV
# ********************* End
# ********************* Start
# Nhân Viên IT Hệ Thống (Thu Nhập 18 - 25 Triệu + Hỗ Trợ Ăn Trưa)
# https://www.topcv.vn/viec-lam/nhan-vien-it-he-thong-thu-nhap-18-25-trieu-ho-tro-an-trua/1280663.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN TOMECO AN KHANG
# 18 - 25 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 5 năm
# Toàn thời gian
# Không yêu cầu
# - Đại học chuyên ngành liên quan: công nghệ thông tin
# - Có kiến thức về Công nghệ thông tin, máy văn phòng.
# - Am hiểu về hệ thống mạng Lan, Wan, internet;
# - Am hiểu về hệ điều hành Windows Server/Linux, ...;
# - Am hiểu quản trị cơ sở dữ liệu SQL Server;
# - Am hiểu hệ thống bảo mật: DLP; network security;
# - Nắm vững các quy định về bảo mật thông tin;
# - Quản lý các thiết bị công nghệ thông tin và công nghệ của công ty;
# ********************* End
# ********************* Start
# Kỹ Sư IT Network (CSR Firewall, Networking, English)
# https://www.topcv.vn/viec-lam/ky-su-it-network-csr-firewall-networking-english/1273727.html?ta_source=ITJobs_LinkDetail
# Công Ty TNHH LG CNS VIỆT NAM
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Bắt buộcTốt nghiệp đại học trở lên, ưu tiên các chuyên ngành liên quanCó kiến thức cơ bản về Network(Hiểu về Switch, Routing, Port v.v)Có kinh nghiệm xử lí task về Firewall (thêm, sửa, xóa policy ...)Ưu tiênCó kính nghiệm vận hành Firewall như Fortinet, PaloaltoCó chứng chỉ về Network như CCNA, CCNPCó kinh nghiệm nhiều về vận hành NetworkGiao tiếp cơ bản bằng tiếng anh (Toiec 450 hoặc tương đương)
# ********************* End
# ********************* Start
# IT Communicator (Japanese Speaking) Nhân Viên IT Tiếng Nhật
# https://www.topcv.vn/viec-lam/it-communicator-japanese-speaking-nhan-vien-it-tieng-nhat/1277713.html?ta_source=ITJobs_LinkDetail
# CHI NHÁNH CÔNG TY TNHH PASONA TECH VIỆT NAM TẠI ĐÀ NẴNG
# Thoả thuận
# Đà Nẵng
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Tốt nghiệp Đại họcKhả năng đọc, viết, tiếp thu và giao tiếp tiếng Nhật ở mức N2 trở lênCó từ 1 năm kinh nghiệm làm việc ở vị trí Communicator hoặc tương đươngNăng động và ham học hỏi (trong lĩnh vực kinh doanh, công nghệ thông tin, ngôn ngữ)Có tinh thần làm việc nhómƯu tiên:Kinh nghiệm trong lĩnh vực ITKinh nghiệm làm việc trong công ty Nhật Khả năng giao tiếp bằng tiếng Anh.
# ********************* End
# ********************* Start
# Nhân Viên Nghiên Cứu Và Phát Triển Công Nghệ [Hà Nội] - Nhiều Đãi Ngộ Hấp Dẫn, Phỏng Vấn Đi Làm Ngay
# https://www.topcv.vn/viec-lam/nhan-vien-nghien-cuu-va-phat-trien-cong-nghe-ha-noi-nhieu-dai-ngo-hap-dan-phong-van-di-lam-ngay/1272392.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN SỞ GIAO DỊCH HÀNG HÓA VIỆT NAM
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# Dưới 1 năm
# Toàn thời gian
# Không yêu cầu
# Về trình độ: Tốt nghiệp Đại học, Cao đẳng chuyên ngành Công nghệ thông tin.Có khả năng đọc hiểu tiếng Anh chuyên ngành tốt.Về kỹ năng:Chuyên ngành Công nghệ thông tin.Nhiệt huyết, chủ động, sáng tạo trong công việc, ham học hỏi, có khả năng chịu áp lực công việc cao. Có khả năng làm việc độc lập và làm việc theo nhóm.Thành thạoReactNative, HTML+CSS, lập trình ứng dụng mobile Android/IOS là lợi thế.Có kinh nghiệm đối với SQL Server, Oracle SQL, React, Mobile App.Có kinh nghiệm làm việc với các hệ điều hành Window Server/Linux/ Unix.Có tư duy logic và có khả năng phân tích xử lý các vấn đề của hệ thống.Kỹ năng quản lý dự án.Kỹ năng trình bày, giao tiếp, lắng nghe.Sử dụng thành thạo các phần mềm văn phòng.
# ********************* End
# ********************* Start
# Business Development Manager - Banking & Insurance
# https://www.topcv.vn/viec-lam/business-development-manager-banking-insurance/1283023.html?ta_source=ITJobs_LinkDetail
# SVTECH
# Thoả thuận
# Hồ Chí Minh
# 200
# ********************* Success
# Trưởng/Phó phòng
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# Bachelor’s degree in Business, Finance, IT, or related field.Proven experience in solution sales, preferably in the Banking or Insurance sector.Strong understanding of Data and Analytics solutions and their application in business contexts.Familiarity with banking and insurance business models, processes, data structures, and IT infrastructure.Excellent communication, presentation, and interpersonal skills.Ability to think strategically and understand the broader business implications of technology solutions.Fluent in Vietnamese and proficient in English.
# ********************* End
# ********************* Start
# Content Marketing (Blockchain , Crypto) - Lương Cao Tại Hà Nội
# https://www.topcv.vn/viec-lam/content-marketing-blockchain-crypto-luong-cao-tai-ha-noi/1288991.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN CÔNG NGHỆ MOONLAB
# 10 - 15 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Tiếng Anh thành thạo, có khả năng viết Content bằng tiếng Anh.
# Có ít nhất 1 năm kinh nghiệm ở vị trí Content.
# Có hiểu biết về Crypto và công nghệ Blockchain.
# Có kinh nghiệm viết Content về lĩnh vực Crypto, Blockchain là lợi thế.
# Nhiệt tình, có trách nhiệm, có tư duy logic và sẵn sàng làm việc cùng startup.
# Ưu tiên ứng viên nam.
# ********************* End
# ********************* Start
# Penetration Tester
# https://www.topcv.vn/brand/boschglobalsoftwaretechnologies/tuyen-dung/penetration-tester-j1239754.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH BOSCH GLOBAL SOFTWARE TECHNOLOGIES
# Thoả thuận
# Hồ Chí Minh
# 200
# ********************* Success
# ********************* Fail
# ********************* End
# ********************* Start
# Unity Developer - Lương Từ 12 - 30 Triệu - Được Chia Sẻ Doanh Thu Của Các Dự Án
# https://www.topcv.vn/viec-lam/unity-developer-luong-tu-12-30-trieu-duoc-chia-se-doanh-thu-cua-cac-du-an/1272229.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH NGen
# 12 - 30 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Có tối thiểu 1 năm kinh nghiệm phát triển game trên nền tảng UnityTốt nghiệp trường đại học Bách Khoa Hà NộiĐam mê làm các sản phẩm gameNăng động, ham học hỏi.
# ********************* End
# ********************* Start
# Quản Lý Dự Án (IT Project Manager) Làm Việc Tại Hà Nội
# https://www.topcv.vn/viec-lam/quan-ly-du-an-it-project-manager-lam-viec-tai-ha-noi/1273420.html?ta_source=ITJobs_LinkDetail
# Công Ty TNHH LG CNS VIỆT NAM
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# Quản lý / Giám sát
# Trên 5 năm
# Toàn thời gian
# Không yêu cầu
# Từ 3 năm kinh nghiệm thực tế ở vị trí Developer, thành thạo 1 ngôn ngữ Backend (Java, PHP, NodeJS v.v)Từ 3 năm kinh nghiệm ở vị trí Technical Leader, Team LeaderCó kinh nghiệm làm việc với Developer và BA để thực hiện các dự án Có kiến thức và kinh nghiệm về quản lý Source Code, Unit Testing và Intergrated TestingCó kinh nghiệm phát triển hoặc quản lý Agile SprintsCó khả năng giao tiếp bằng Tiếng AnhCó kinh nghiệm vận hành/sử dụng Jira/Confluence Ưu Tiên Có khả năng giao tiếp bằng tiếng HànCó kinh nghiệm làm việc với toàn bộ quy trình Service bao gồm lập kế hoạch, phát triển và vận hành các dịch vụ ứng dụng mới Có khả năng sử dụng tool Figma
# ********************* End
# ********************* Start
# CTV Vận Hành Lớp Học Trực Tuyến Part Time
# https://www.topcv.vn/viec-lam/ctv-van-hanh-lop-hoc-truc-tuyen-part-time/1276247.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH PHÁT TRIỂN GIẢI PHÁP & CNTT DIỆP ANH
# 2.5 - 6 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Bán thời gian
# Không yêu cầu
# Độ tuổi: 18 - 21 tuổiCó kinh nghiệm và kỹ năng sử dụng các công cụ Microsoft OfficeCó kỹ năng sử dụng các phần mềm điều khiển máy tính từ xa : teamviewer, ultraviewer, anydesk...Chưa có kinh nghiệm sẽ được công ty đào tạo từ đầu.Có laptop cá nhân để phục vụ cho công việc.Có kinh nghiệm hoạt động đội nhóm.
# ********************* End
# ********************* Start
# Ecommerce Marketing
# https://www.topcv.vn/viec-lam/ecommerce-marketing/1273674.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH CÔNG NGHỆ THÔNG TIN AN PHÁT
# 9 - 12 triệu
# Hồ Chí Minh
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Tốt nghiệp đại học các chuyên ngành Kinh tế, QTKD, Marketing, hoặc các ngành nghề khác có liên quan.
# Có ít nhất 1 năm kinh nghiệm về ecommerce marketing/online marketing.
# Có khả năng phân tích, đánh giá và lập kế hoạch.
# Kỹ năng đàm phán tốt.
# Nhanh nhẹn, chủ động, chăm chỉ, cầu thị, trách nhiệm và có khả năng chịu áp lực công việc và áp lực
# ********************* End
# ********************* Start
# Nhân Viên Tester (Ba/ QC/ Tester)
# https://www.topcv.vn/viec-lam/nhan-vien-tester-ba-qc-tester/1279780.html?ta_source=ITJobs_LinkDetail
# Công ty Cổ phần Công nghệ Tin học và Dịch vụ Goline
# 12 - 18 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# - Tốt nghiệp đại học chuyên ngành CNTT.
# - Skills yêu cầu
# + Kinh nghiệm test ít nhất 1 năm
# + Có khả năng lên Testcase
# + Có khả năng test qua API
# - Skill lợi thế
# + Ưu tiên đã từng triển khai dự án phần mềm chứng khoán, có kinh nghiệm về lĩnh vực chứng khoán
# + Có chứng chỉ ISTQB
# ********************* End
# ********************* Start
# IT Comtor Tiếng Nhật -Thu Nhập Lên Tới 25 Triệu/Tháng
# https://www.topcv.vn/viec-lam/it-comtor-tieng-nhat-thu-nhap-len-toi-25-trieu-thang/1281141.html?ta_source=ITJobs_LinkDetail
# Beetechsoft
# 15 - 25 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Có trình độ cao đẳng trở lên. Tốt nghiệp các chuyên ngành liên quan đến tiếng Nhật. (N1, N2 hoặc tương đương)Có từ 1.5 năm kinh nghiệm với vị trí trí IT Comtor - Lĩnh vực phần mềm.Thành thạo vi tính văn phòng đặc biệt là word, excel, powerpoint.Kỹ năng xử lý công việc nhanh, chính xác.Kỹ năng giao tiếp, thuyết phục tốt.Cẩn thận, trung thực, kiên trì.Năng động, tự tin, sáng tạo, có khả năng làm việc độc lập và làm việc theo nhóm.Có khả năng hướng dẫn các member có ít kinh nghiệm.Ưu tiên những ứng viên luôn nỗ lực hết mình trong mọi hoàn cảnh và đưa ra những ý kiến đóng góp để phát triển công việc.Đã có kinh nghiệm làm việc tại các công ty Nhật Bản, Âu, Mỹ là một lợi thế.
# ********************* End
# ********************* Start
# Fresher Software Developer
# https://www.topcv.vn/viec-lam/fresher-software-developer/1273298.html?ta_source=ITJobs_LinkDetail
# Công Ty TNHH LG CNS VIỆT NAM
# Thoả thuận
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# Dưới 1 năm
# Toàn thời gian
# Không yêu cầu
# I. Theo vị trí1. Kỹ sư lập trình WebCó tư duy logic, thuật toán tốtCó kiến thức cơ bản về Java core, Spring, Spring BootCó hiểu biết về Rest APIHiểu biết chung về HTML / HTML5, CSS / CSS3Hiểu biết về UI/UX PrinciplesCó hiểu biết về json object (understand)Có kinh nghiệm sử dụng Visual Code Studio, Git, Git Flow2. Kỹ sư Cloud/ DevOpsCó kiến thức liên quan tới Window, Linux, Unix OSCó kiến thức liên quan tới private cloud, public cloud.Có hiểu biết liên quan tới CI/CD tools: Gitlab, Jenkins, Nexus, etc.Có khả năng sử dụng scripts: Python, Bash ScriptCó khả năng xử lý vấn đềII. Yêu cầu chungTốt nghiệp Đại học với các chuyên ngành liên quan tới Máy tính, phần mềm, vvTiếng Anh TOEIC 450 trở lênCó khả năng làm việc nhóm và giao tiếp với team memberCẩn thận, trách nhiệm, có tinh thần cầu tiến, ham học hỏi và khả năng tự học[Ưu tiên]Có hiểu biết về SASS, BEMCó hiểu biết về jquery, ajaxBiết sử dụng Adobe Photoshop, Figma, coding convension cleanCó thể giao tiếp tiếng Hàn
# ********************* End
# ********************* Start
# Trưởng Phòng Giải Pháp Tại Hà Nội Thu Nhập 30M-40M
# https://www.topcv.vn/viec-lam/truong-phong-giai-phap-tai-ha-noi-thu-nhap-30m-40m/1013348.html?ta_source=ITJobs_LinkDetail
# Công ty cổ phần Ecoit
# 30 - 40 triệu
# Hà Nội
# 200
# ********************* Success
# Trưởng/Phó phòng
# 5 năm
# Toàn thời gian
# Không yêu cầu
# – Tốt nghiệp Đại Học trở lên chuyên ngành CNTT, tin học ứng dụng, điện tử viễn thông hoặc tương đương. – Am hiểu rõ các vấn đề pháp lý liên quan đến đấu thầu. – Có chứng chỉ về quản lý dự án là một lợi thế. – Có tối thiểu từ 03 năm kinh nghiệm làm việc trong các dự án CNTT, ĐẶC BIỆT là các dự án đầu tư công. – Có kinh nghiệm trong việc lập Báo cáo nghiên cứu khả thi, Thiết kế thi công tổng dự toán, Đề cương và Dự toán chi tiết... và các hồ sơ liên quan trong các dự án CNTT. – Nắm vững các giải pháp ứng dụng CNTT, giải pháp chuyển đổi số doanh nghiệp. (Hệ thống quản lý văn bản điều hành, Hệ thống thông tin nội bộ, Cổng TTĐT, giải pháp số hóa tài liệu, giải pháp kho lưu trữ số...) – Nắm vững cơ sở pháp lý và các thủ tục tham gia đấu thầu. – Có tinh thần học hỏi, có khả năng xây dựng/ thiết lập và duy trì các mối quan hệ với đối tác/ khách hàng; – Thành thạo giao tiếp, đàm phán, phân tích dữ liệu. – Có khả năng làm việc độc lập và làm việc nhóm.- Trình độ tin học: Thành thạo các kỹ năng vi tính văn phòng (MS. Word, Excel, PowerPoint, Outlook, Internet Explorer); Biết sử dụng Project Manager, Mindjet Mind manager là điểm cộng.
# ********************* End
# ********************* Start
# Data Scientist - Up To $2,500 Per Month Tại Hà Nội
# https://www.topcv.vn/viec-lam/data-scientist-up-to-2-500-per-month-tai-ha-noi/1274624.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH GIẢI PHÁP CÔNG NGHỆ ALETECH
# Trên 2,500 USD
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 5 năm
# Toàn thời gian
# Không yêu cầu
# 1. Educational Background: - Bachelor's or Master’s degree in Computer Science, Data Science, or a related field.2. Experience: - Minimum of 5 years of experience in data management, analytics, and visualization. - Demonstrated success in implementing data strategies within a business context.3. Technical Skills: - Proficiency in data analysis tools such as Python. - Familiarity with SQL Server, Azure Blob Storage, and other relevant data storage technologies. - Strong expertise in data visualization tools (e.g., Tableau, Power BI).4. Statistical Modeling and Machine Learning: - Profound understanding of statistical modeling and machine learning techniques. - Ability to apply advanced analytics to tackle complex business challenges.5. Language Proficiency: - Exceptional English language skills, both written and verbal. - Capacity to communicate technical concepts effectively to non-technical stakeholders.6. Leadership and Collaboration: - Proven leadership and team management capabilities. - Effective collaboration with cross-functional teams and outstanding interpersonal skills.7. Analytical Thinking: - Strong analytical and problem-solving skills, with meticulous attention to detail. - Ability to translate complex data into actionable insights.8. Innovation and Continuous Learning: - Commitment to staying abreast of industry trends and emerging technologies. - Track record of driving innovation in data management practices.
# ********************* End
# ********************* Start
# Nhân Viên Marketing Google Ads Tại Agency (Thu Nhập 10 - 20 Triệu)
# https://www.topcv.vn/viec-lam/nhan-vien-marketing-google-ads-tai-agency-thu-nhap-10-20-trieu/940589.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN ĐẦU TƯ QUỐC TẾ TOPTO HOLDING
# 10 - 20 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Về chuyên môn:Có ít nhất 2 - 3 năm kinh nghiệm trong ngànhThành thạo các loại hình quảng cáo của Google. Trong đó bắt buộc nắm vững: Google Search, Google Remarketing, Google Shopping, GDN, Youtube AdsCó tính chủ động CAO. Khi làm việc không cần phải có người khác nhắc việcCó khả năng chịu được áp lực công việc và kỹ năng teamwork tốtCó thể viết mô tả về cấu trúc và nội dung các landingpage (các trang đích) quảng cáo cho Design hoặc bộ phận lập trình webCó khả năng chạy các chiến dịch chuyển đổi và cách setup chuyển đổiSử dụng thành thạo các công cụ nghiên cứu từ khóaƯu tiên ứng vên có khả năng tự xây dựng landingpage bằng wordpress hay các nền tảng tạo landingpage (được đào tạo nhưng cần nắm cơ bản)Sử dụng thuần thục các công cụ phân tích, thống kê để tối ưu hiệu quả chiến dịch quảng cáo: Google Ads, Google Analytics, Google Tag Manager.Hiểu rõ rõ cơ chế targeting, retargeting của Google và đề xuất kết hợp với các kênh thuộc nền tảng khácƯu tiên từng chạy ngân sách lớnAm hiểu về hành vi khách hàng.Có tư duy logic tốt.Giao tiếp tốt, chịu khó học hỏi cái mới.Có chứng nhận về năng lực sử dụng Google Ads (thi trên Skillshop)Có khả năng đọc hiểu tiếng Anh. Điểm TOEIC từ 450 (không bắt buộc) Về con người:Hướng đến kết quả và Sẵn sàng chịu trách nhiệmLà người sống TỬ TẾ, trung thựcKhả năng học hỏi nhanhBiết lắng nghe, chia sẻLuôn mong muốn phấn đấu và phát triển bản thân.Hồ sơ ứng tuyển gồm:Một số case hoặc chiến dịch đã tham gia triển khai có kết quả tốt (nếu có, có thể gửi thông tin sơ bộ nếu thông tin dự án không tiện tiết lộ chi tiết)Một số trang đích đã tham gia xây dựng (nếu có)
# ********************* End
# ********************* Start
# Web Developer
# https://www.topcv.vn/viec-lam/web-developer/1282066.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN PHẦN MỀM VIỄN THÔNG MIỀN NAM
# 10 - 20 triệu
# Hồ Chí Minh
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# ● Have at least 1 year of experience.
# ● Good understanding of the TypeScript, HTML, CSS.
# ● Experience with React, React-Query, NextJS, Tailwind CSS, CSS Compiler (Scss/Less).
# ● Familiarity with RESTful APIs.
# ● Experience with common front-end development tools such as Vite, Babel, Webpack, NPM, etc.
# ● Good command of source code management such as Git.
# ● Ensure the technical feasibility of UI/UX designs.
# ● Develop web templates based on graphical web layout designs that follow the strict requirements.
# ● Knowing about SEO, NodeJS, MongoDB, React Native is an advantage.
# ● Có ít nhất 1 năm kinh nghiệm.● Hiểu biết tốt về TypeScript, HTML, CSS.● Có kinh nghiệm với React, React-Query, NextJS, Tailwind CSS, CSS Compiler (Scss/Less).● Làm quen với API RESTful.● Có kinh nghiệm với các công cụ phát triển front-end phổ biến như Vite, Babel, Webpack, NPM, v.v.● Khả năng quản lý mã nguồn tốt như Git.● Đảm bảo tính khả thi về mặt kỹ thuật của thiết kế UI/UX.● Phát triển các mẫu web dựa trên thiết kế bố cục web đồ họa tuân theo các yêu cầu nghiêm ngặt.● Biết về SEO, NodeJS, MongoDB, React Native là một lợi thế.
# ********************* End
# ********************* Start
# Chuyên Viên Digital Marketing Executive - Đi Làm Ngay
# https://www.topcv.vn/viec-lam/chuyen-vien-digital-marketing-executive-di-lam-ngay/1280870.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH DƯỢC PHẨM PRO CUỘC SỐNG XANH
# Trên 10 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# - Tốt nghiệp Đại học chuyên ngành marketing hoặc liên quan. Ưu tiên ứng viên nam.
# - Kinh nghiệm từ 2 năm ở vị trí Digital Marketing là một lợi thế.
# - Am hiểu về các công cụ Digital Marketing và sử dụng thành thạo, edit video để chạy quảng cáo/ thiết kế hình ảnh cơ bản
# - Có khả năng xây dựng chiến lược marketing và làm việc theo chỉ tiêu kế hoạch, tinh thần trách nhiệm cao, đúng tiến độ.
# - Kỹ năng viết và giao tiếp tốt.
# - Thái độ tích cực và suy nghĩ lạc quan trong công việc.
# - Ưu tiên ứng viên có khả năng quay dựng chụp hình và thiết kế cơ bản.
# ********************* End
# ********************* Start
# UX Designer (Upto 30M)
# https://www.topcv.vn/viec-lam/ux-designer-upto-30m/1280602.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN SYSTEMATIC FUNCTIONS
# Tới 30 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Không yêu cầu
# ● Có kinh nghiệm làm việc trong lĩnh vực thiết kế giao diện người dùng và trải nghiệm người dùng. ● Sử dụng thành thạo các công cụ thiết kế như Figma. Đã sử dụng Sketch, Adobe XD, Figma, hoặc Illustrator là lợi thế. ● Hiểu biết về nguyên tắc thiết kế tương tác và đáp ứng. ● Hiểu biết về Material Design là lợi thế. ● Khả năng làm việc hiệu quả trong môi trường đa chức năng và làm việc nhóm. ● Có kiến thức về quy trình phát triển phần mềm (Agile, Scrum) là lợi thế. ● Có kỹ năng giao tiếp hiệu quả, làm việc nhóm. ● Có khả năng đóng góp, xây dựng sản phẩm.
# ********************* End
# ********************* Start
# Nhân Viên Kỹ Thuật Truyền Hình Cáp- Không Yêu Cầu Kinh Nghiệm (TP. Thủ Đức-HCM, Bình Dương, Bình Phước)
# https://www.topcv.vn/viec-lam/nhan-vien-ky-thuat-truyen-hinh-cap-khong-yeu-cau-kinh-nghiem-tp-thu-duc-hcm-binh-duong-binh-phuoc/1283964.html?ta_source=ITJobs_LinkDetail
# CHI NHÁNH 4 - CÔNG TY TNHH TRUYỀN HÌNH CÁP SAIGONTOURIST
# 7 - 10 triệu
# Bình Dương & 2 nơi khác
# 200
# ********************* Success
# Nhân viên
# Không yêu cầu kinh nghiệm
# Toàn thời gian
# Nam
# - Chiều cao : 1m60 trở lên- Yêu cầu giới tính : Nam- Độ tuổi : 25 - 35- Tốt nghiệp từ trung cấp trở lên
# - Ngành nghề : Bưu chính viễn thông, Công nghệ thông tin, Điện/Điện tử/Điện lạnh, Điện tử viễn thông CHÚ Ý: Chỉ tuyển khoa- CNTT, Điện tử viễn thông, bưu chính viễn thông (không tuyển nghành khác)
# ********************* End
# ********************* Start
# Trưởng Bộ Phận Phụ Trách Ứng Dụng Công Nghệ, Phần Mềm Trong Doanh Nghiệp / Trưởng Phòng Công Nghệ Phần Mềm / Trưởng Phòng Ứng Dụng Công Nghệ - Thu Nhập Hấp Dẫn Thoả Thuận Theo Năng Lực (TPHCM, Bình Dương)
# https://www.topcv.vn/viec-lam/truong-bo-phan-phu-trach-ung-dung-cong-nghe-phan-mem-trong-doanh-nghiep-truong-phong-cong-nghe-phan-mem-truong-phong-ung-dung-cong-nghe-thu-nhap-hap-dan-thoa-thuan-theo-nang-luc-tphcm-binh-duong/1285414.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH DU HỌC DU LỊCH THƯƠNG MẠI DỊCH VỤ Á ÂU
# Thoả thuận
# ...
# Không yêu cầu
# Bắt buộc:Kinh nghiệm làm việc trong vai trò lập trình viên Python có từ 1-3 năm kinh nghiệm trở lên.Kiến thức chuyên môn về Python và các framework liên quan Django hoặc Flask.Hiểu và có thể lập kiến trúc đa quy trình cũng như các giới hạn phân luồng của Python.Quen thuộc với các ngôn ngữ tạo mẫu phía server như Jinja 2 và Mako.Quen thuộc với các công nghệ front-end (như JavaScript và HTML5).Khả năng tích hợp nhiều nguồn dữ liệu vào một hệ thống duy nhất.Điểm cộng:Có kinh nghiệm tự làm các dự án về Golang hoặc Java.Có kinh nghiệm làm việc với các dự án kiểu agile.Đối với ứng viên trên 2 năm có khả năng làm việc độc lập và hỗ trợ đào tạo thực tập sinh là một điểm cộng.
# ********************* End
# ********************* Start
# AI Engineer
# https://www.topcv.vn/viec-lam/ai-engineer/1281041.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN KALAPA
# Tới 30 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 3 năm
# Toàn thời gian
# Không yêu cầu
# Tối thiểu 03 năm kinh nghiệm làm việc với các thư viện và công cụ phổ biến trong lĩnh vực AI (TensorFlow, PyTorch, scikit-learn, v.v.).Kỹ năng lập trình mạnh mẽ, đặc biệt là trong Python.Hiểu biết tốt về các thuật toán AI, đặc biệt là trong thị giác máy tính. Kinh nghiệm làm việc với dữ liệu không cân bằng là một lợi thế.Kinh nghiệm làm việc với các framework API như Flask/FastAPI/Django.Kỹ năng giải quyết vấn đề mạnh mẽ, có khả năng làm việc độc lập hoặc hiệu quả trong một nhóm 2-3 người.Kỹ năng viết tài liệu kỹ thuật tốt.Bằng cử nhân chuyên ngành Công nghệ Thông tin, Khoa học Máy tính hoặc các ngành liên quan.Có kiến thức về thuật toán, đã từng tham gia các cuộc thi cấp quốc gia tin học, toán học, vật lý là lợi thế lớn.Có kinh nghiệm triển khai dịch vụ với Docker/Kubernetes là một lợi thế.Thành thạo trong đọc và giao tiếp bằng tiếng Anh.Khả năng sử dụng các ngôn ngữ lập trình như Java, C++ là một lợi thế.Kiến thức cơ bản về hệ điều hành và an ninh mạng là một lợi thế.Kỹ năng giao tiếp/trình bày tốt và tham gia các hoạt động văn hóa công ty là một lợi thế.
# ********************* End
# ********************* Start
# Phó Phòng Phân Tích Nghiệp Vụ
# https://www.topcv.vn/viec-lam/pho-phong-phan-tich-nghiep-vu/1279469.html?ta_source=ITJobs_LinkDetail
# Công ty cổ phần Đầu tư Bất động sản Hapulico
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Trưởng/Phó phòng
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Linh hoạt, nhiệt tình, có tinh thần trách nhiệm cao trong công việc.Chuyên môn nghiệp vụkhả năng tư duy logic, đổi mới sáng tạo tốt.
# ********************* End
# ********************* Start
# Mobile Developer (Java/Kotlin)
# https://www.topcv.vn/viec-lam/mobile-developer-java-kotlin/1282392.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH Công Nghệ và Thương Mại Lifesup
# 13 - 30 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Có trên 2 năm kinh nghiệm phát triển ứng dụng trên AndroidTiếng Anh đọc hiểu tốt.Thành thạo Kotlin/ Java.Có kinh nghiệm với các mẫu kiến trúc ứng dụng như MVC/MVP/MVVM.Có kinh nghiệm về thiết kế UX/ UI application.Am hiểu về JSON và REST APIs.Chịu khó tìm tòi và nhạy bén với các xu hướng và công nghệ phát triển phần mềm hiện đại.Am hiểu toàn bộ quy trình phát triển phần mềm.Tư duy logic và khả năng giải quyết vấn đề nhanh, hiệu quả.
# ********************* End
# ********************* Start
# Product Owner
# https://www.topcv.vn/viec-lam/product-owner/1280184.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN GIAO HÀNG TIẾT KIỆM
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# – Tốt nghiệp Đại học và có định hướng, kinh nghiệm làm việc liên quan (xây dựng hệ thống, phát triển sản phẩm phần mềm...)– Mạnh về kỹ năng kết nối, giao tiếp đặc biệt trong các trường hợp ra quyết định hoặc giải quyết vấn đề.– Có kỹ năng phân tích vấn đề sâu, chi tiết.– Có khả năng làm việc đa nhiệm, đồng thời chịu được áp lực cao.– Tư duy mở, định hướng rõ ràng và tư duy tổ chức cao.– Ưu tiên ứng viên biết sử dụng thành thạo nhiều phần mềm, công cụ liên quan.– Có thể đi công tác xa (nếu được yêu cầu – với cấp senior).
# ********************* End
# ********************* Start
# ERP Specialist
# https://www.topcv.vn/viec-lam/erp-specialist/1282355.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH AL NABOODAH QUỐC TẾ VIỆT NAM
# Thoả thuận
# Hồ Chí Minh
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Quản lý / Giám sát
# 3 năm
# Toàn thời gian
# Không yêu cầu
# Bachelor’s degree in Economics (Finance, Accounting) or Information Technology.At least 2 years’ experience with BC365/NAV, 1-2 full projects implementation, consulting experience is an advantage. Knowledge of SQL/JET Reports, business processes preferred. Great organization and time management skills. Teamwork, and communication abilities. Analytical and problem-solving skills. English proficiency. Willingness to learn and commitment to deadlines.
# ********************* End
# ********************* Start
# Lập Trình Backend Nodejs
# https://www.topcv.vn/viec-lam/lap-trinh-backend-nodejs/631013.html?ta_source=ITJobs_LinkDetail
# Công ty TNHH VNTRIP.VN
# Tới 25 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# Có kinh nghiệm làm Backend với Nodejs, NestJs, Restful API.Có kinh nghiệm làm việc với MongoDB, SQL Database.Tư duy logic tốt, có kỹ năng phân tích, tổng hợp.Có khả năng đọc hiểu tài liệu Tiếng Anh.Tinh thần trách nhiệm cao, có khả năng làm việc nhóm và làm việc độc lập.Có kinh nghiệm làm việc trong quy trình Agile – mô hình Scrum.Sử dụng thành thạo IDE, Git, Jira và các công cụ làm việc khác.Có kinh nghiệm với Microservices, NestJS là một lợi thế.
# ********************* End
# ********************* Start
# Product Lead
# https://www.topcv.vn/viec-lam/product-lead/1281853.html?ta_source=ITJobs_LinkDetail
# Công ty Cổ phần Công nghệ KiotViet
# 35 - 45 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Trưởng nhóm
# 4 năm
# Toàn thời gian
# Không yêu cầu
# Communication:Outstanding communication skills to collaborate with stakeholders to define product requirements and ensure customer satisfaction.Analytical:Analytical eye for details to effectively evaluate customer feedback and data to inform product design.Passion for data analysis and the ability to translate insights into actionable product decisions.Problem-solving:Creative thinker with a knack for solving complex problems.Leadership:Ability to lead teams and coordinate among stakeholders to ensure product success.Experience:Bachelor or Master’s degree in Economics, Computer Science or a related fieldMinimum 2 years of experience in similar rolesStrong grasp of economic and financial concepts (econometrics, market analysis, demand forecasting)
# ********************* End
# ********************* Start
# Front-End Developer (Middle/Senior)
# https://www.topcv.vn/viec-lam/front-end-developer-middle-senior/1218895.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN LUKLAK
# 18 - 30 triệu
# Hà Nội
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Yêu cầu chung- Tốt nghiệp ĐH/CĐ các chuyên ngành: CNTT, Toán Tin, Khoa học máy tính… hoặc các chuyên ngành liên quan.- Có khả năng làm việc độc lập cũng như khả năng làm việc nhóm.- Kỹ năng phân tích giải quyết vấn đề tốt.- Có thái độ tích cực trong việc tự học hỏi và áp dụng công nghệ mới.- Đã từng làm việc với mô hình Agile lợi thế.- Yêu thích làm product, ưu tiên ứng viên từng làm các dự án/công ty product.- Có laptop cá nhân.Cụ thểLevel Middle- Từ 3 năm kinh nghiệm lập trình, 2 năm làm việc với với NextJS.- Thành thạo về JavaScript, bao gồm thao tác DOM và mô hình đối tượng JavaScript.- Hiểu nguyên tắc cốt lõi của React.- Từng sử dụng quản lý trạng thái Flux hoặc ReduxLevel Senior- Có ít nhất 3 năm làm việc với React, 2 năm sử dụng NextJs- Có ít nhất 3 năm nghiệm sử dụng Redux, Redux-Saga hoặc Redux-Thunk- Có kinh nghiệm sử dụng webpack- Có khả năng mạnh mẽ trong việc phát triển UI/UX- Có kinh nghiệm vững chắc trong tất cả các lĩnh vực phát triển web (HTML5, CSS3, JSON) bao gồm các vấn đề về khả năng truy cập, SEO- Có kinh nghiệm trong việc sử dụng Design Pattern (observer, singleton, high order component, ...etc)- Có kinh nghiệm viết test (Jest, Enzyme, etc). Nếu biết viết test selenium là lợi thế- Có kinh nghiệm làm việc với Websocket, Service Worker, Cache
# ********************* End
# ********************* Start
# Java Developer
# https://www.topcv.vn/viec-lam/java-developer/1171937.html?ta_source=ITJobs_LinkDetail
# CÔNG TY CỔ PHẦN VINOVA HCM
# 25 - 40 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 3 năm
# Toàn thời gian
# Không yêu cầu
# Qualification requirementsAt least 3 years of experience in Java DeveloperUnderstanding one of the relational databases (PostgreSQL, MySQL, Oracle, SQL Server, DB2)Good communication in EnglishDegree in Computer Science or related fieldExperience with designing database structuresAnalytical mindset and good problem-solving skillsGood organizational skillsAbility to work both independently and as part of a team
# ********************* End
# ********************* Start
# Full-Stack Engineer (AI Learning Opportunity)
# https://www.topcv.vn/viec-lam/full-stack-engineer-ai-learning-opportunity/1282327.html?ta_source=ITJobs_LinkDetail
# TOA - The Outsourcing Agency
# Thoả thuận
# Hồ Chí Minh
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Trưởng nhóm
# 3 năm
# Toàn thời gian
# Không yêu cầu
# Requirements:2+ years of professional experience with NLP and applying AI to practical technology solutions1+ years of professional experience with Large Language Models (LLM)/GenAI technology like OpenAI API, ChatGPT, GPT-4, Bard, Synthesia, Langchain, HuggingFace Transformers, PyTorch, and similar1+ years of experience with vector databases2+ years of experience with AWS, GCP, or Microsoft Azure2+ years of experience with MLOps, CI/CD pipeline development, containerization, and model deployment in test and production environmentsExperience in REST API development, NoSQL database design, and RDBMS design and optimizationsStrong proficiency in Python and experience with ML frameworks like TensorFlowKnowledge of basic algorithms, object-oriented and functional design principles, and best-practice patternsExcellent problem-solving, communication, and leadership skillsPreferred Qualifications:Proven track record of leading successful AI projects from conception to deploymentFamiliarity with AI ethics and responsible AI development practicesContributions to open-source AI projects or research publications
# ********************* End
# ********************* Start
# Senior Java Developer
# https://www.topcv.vn/viec-lam/senior-java-developer/1281512.html?ta_source=ITJobs_LinkDetail
# TPS Software
# Thoả thuận
# Hồ Chí Minh
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 4 năm
# Toàn thời gian
# Không yêu cầu
# At least 4 years’ experience in Java development, especially Java Core and Java EE technologies (Servlets, JSPs/JSF, WebSocket).Strong database knowledge (MYSQL, PostgreSQL, MongoDB or DB2).Strong knowledge of object-oriented design.Knowledge about some popular design pattern like Factory pattern, Adapter pattern, Strategy pattern.Proven experience with one of front-end frameworks such as Angular, ReactJS, VueJS.Experienced in using a CSS Framework like Bootstrap, Material UI,...Experienced in developing web applications using: Spring Boot or Jersey API, Struts.Proficient understanding of code version tools such as Git, CVS, SVN.Familiarity with build tools such as Maven, Gradle, Ant.Nice to have:Knowledge of these libraries and frameworks: TensorFlow, PyTorch, Scikit-Learn, Keras, Pandas, NumPy, Matplotlib, OpenCV, XGBoost / LightGBM / CatBoost, spaCy,Hugging Face’s TransformersExperience in Agile Practices, including Extreme Programing, pair programming, and TDD
# ********************* End
# ********************* Start
# Data Analyst Manager
# https://www.topcv.vn/viec-lam/data-analyst-manager/1282021.html?ta_source=ITJobs_LinkDetail
# Công ty Cổ Phần Insmart
# Tới 50 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Trưởng/Phó phòng
# 5 năm
# Toàn thời gian
# Không yêu cầu
# Bachelor’s degree from university in computer science, statistics or mathematicsProficiency in data manipulation and analysis tools such as SQL, Python, R, or SAS.Experience with business intelligence and data visualization platforms such as Tableau, Power BI, or QlikView.Work experience as a data analyst or in a related field.Ability to analyze existing tools and databases and provide software solution recommendations.Ability to translate business requirements into nontechnical, lay terms.High-level experience in methodologies and processes for managing large-scale databases.High-level written and verbal communication skills.
# ********************* End
# ********************* Start
# Network Engineer - Fresher
# https://www.topcv.vn/viec-lam/network-engineer-fresher/1228391.html?ta_source=ITJobs_LinkDetail
# NetNam Corp
# 10 - 19 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# Dưới 1 năm
# Toàn thời gian
# Không yêu cầu
# Tốt nghiệp đại học chính quy chuyên ngành điện tử viễn thông/công nghệ thông tin/An toàn thông tin các trường Bách Khoa, Quốc Gia, Quân sự, Mật Mã .... Có kiến thức, kinh nghiệm làm việc với các thiết bị mạng của Cisco/Juniper/HP...Tiếng Anh: đủ khả năng giao tiếp và trao đổi qua thư điện tử với các đối tác nước ngoài.Có chứng chỉ Cisco CWNA, CCNA Security, CCNP là một lợi thế.
# ********************* End
# ********************* Start
# Frontend Developer
# https://www.topcv.vn/viec-lam/frontend-developer/1166383.html?ta_source=ITJobs_LinkDetail
# Công ty cổ phần Sharitek Việt Nam
# Thoả thuận
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 4 năm
# Toàn thời gian
# Không yêu cầu
# Có kinh nghiệm ở vị trí tương đương 4-5 năm;Thành thạo HTML, CSS, Boostrap và ngôn ngữ lập trình TypeScript;Nắm rõ toàn bộ quá trình phát triển web (thiết kế, phát triển và thực thi);Có kiến thức về các quy tắc trong SEO;Có kinh nghiệm làm việc với Figma, xD;Có kiến thức cơ bản về UX/UI;Có kiến thức về Responsive Design;Khả năng làm việc tốt trong môi trường tốc độ cao.
# ********************* End
# ********************* Start
# Nhân Viên Thiết Kế 2D Artist/ UI Design
# https://www.topcv.vn/viec-lam/nhan-vien-thiet-ke-2d-artist-ui-design/1229937.html?ta_source=ITJobs_LinkDetail
# Công ty cổ phần công nghệ Malcom
# Tới 20 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 1 năm
# Toàn thời gian
# Không yêu cầu
# [Ưu tiên]Có kinh nghiệm trong ngành công nghiệp game.Sáng tạo và có đam mê với việc thiết kế sản phẩm.Có khả năng vẽ Digital Painting.Đam mê, yêu thích làm game, chơi game.Có kinh nghiệm với Adobe Photoshop hoặc các phần mềm vẽ máy.Có kiến thức về màu sắc, phối màu.
# ********************* End
# ********************* Start
# Dev Android (Java/Kotlin)
# https://www.topcv.vn/viec-lam/dev-android-java-kotlin/1282315.html?ta_source=ITJobs_LinkDetail
# CÔNG TY TNHH LIFESUP
# 13 - 30 triệu
# Hà Nội
# Too many requests. Retrying after waiting...
# 200
# ********************* Success
# Nhân viên
# 2 năm
# Toàn thời gian
# Không yêu cầu
# Có từ trên 2 năm kinh nghiệm phát triển ứng dụng trên AndroidThành thạo Kotlin/ Java.Có kinh nghiệm với các mẫu kiến trúc ứng dụng như MVC/MVP/MVVM.Có kinh nghiệm về thiết kế UX/ UI application.Am hiểu về JSON và REST APIs.Chịu khó tìm tòi và nhạy bén với các xu hướng và công nghệ phát triển phần mềm hiện đại.Am hiểu toàn bộ quy trình phát triển phần mềm.Tư duy logic và khả năng giải quyết vấn đề nhanh, hiệu quả.Ưu tiên ứng viên có Tiếng Anh đọc hiểu tốt.
# ********************* End
